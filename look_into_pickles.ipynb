# %%
import subprocess
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
import pickle

# %%
with open('kexec-tools.pickle', 'rb') as f:
    loaded_obj = pickle.load(f)

#print(f'loaded_obj is {loaded_obj}')

for elem in loaded_obj:
    print(f'func-signature:{elem[0]}')
    print(f'func-return-type:{elem[1]}')
    print(f'func-name:{elem[2]}')
    print(f'func-filename:{elem[3]}')
    print(f'func-disassembly:{elem[4]}')
    print(f'ubuntu-package-name:{elem[5]}')
    print(f'ubuntu-package-binary:{elem[6]}')
    print("----------")
# Out:
# func-signature:unsigned long add_buffer(struct kexec_info *, const void *, unsigned long, unsigned long, unsigned long, unsigned long, unsigned long, int);
# func-return-type:unsigned long
# func-name:add_buffer
# func-filename:add_buffer.c
# func-disassembly:['jmpq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:void add_segment(struct kexec_info *, const void *, size_t, unsigned long, size_t);
# func-return-type:void
# func-name:add_segment
# func-filename:add_segment.c
# func-disassembly:['xor %r9d , %r9d', 'jmpq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int get_crash_kernel_load_range(uint64_t *, uint64_t *);
# func-return-type:int
# func-name:get_crash_kernel_load_range
# func-filename:crashdump-x86.c
# func-disassembly:['mov 0x ( %rip ) , %eax', 'test %eax , %eax', 'je 0x', 'sub $0x , %eax', 'cltq', 'lea ( %rax , %rax , 2 ) , %rdx', 'lea 0x ( %rip ) , %rax', 'lea ( %rax , %rdx , 8 ) , %rax', 'mov ( %rax ) , %rdx', 'mov %rdx , ( %rdi )', 'mov 0x ( %rax ) , %rax', 'mov %rax , ( %rsi )', 'xor %eax , %eax', 'retq', 'xchg %ax , %ax', 'mov $0x , %eax', 'retq']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int is_crashkernel_mem_reserved(void);
# func-return-type:int
# func-name:is_crashkernel_mem_reserved
# func-filename:crashdump-x86.c
# func-disassembly:['sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'callq 0x', 'test %eax , %eax', 'je 0x', 'lea 0x ( %rsp ) , %rsi', 'lea 0x ( %rsp ) , %rdi', 'callq 0x', 'test %eax , %eax', 'js 0x', 'movl $0x , 0x ( %rip )', 'mov 0x ( %rsp ) , %rax', 'movl $0x , 0x ( %rip )', 'mov %rax , 0x ( %rip )', 'mov 0x ( %rsp ) , %rax', 'mov %rax , 0x ( %rip )', 'mov $0x , %eax', 'mov 0x ( %rsp ) , %rcx', 'xor %fs : 0x , %rcx', 'jne 0x', 'add $0x , %rsp', 'retq', 'nopw %cs : 0x ( %rax , %rax , 1 )', 'xor %edx , %edx', 'lea -0x ( %rip ) , %rsi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'test %eax , %eax', 'mov %eax , 0x ( %rip )', 'setne %al', 'movzbl %al , %eax', 'jmp 0x', 'nopl ( %rax )', 'xor %eax , %eax', 'jmp 0x', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int load_crashdump_segments(struct kexec_info *, char *, unsigned long, unsigned long);
# func-return-type:int
# func-name:load_crashdump_segments
# func-filename:crashdump-x86.c
# func-disassembly:['push %r15', 'pxor %xmm0 , %xmm0', 'mov %rdi , %r15', 'push %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov %rcx , 0x ( %rsp )', 'mov 0x ( %rdi ) , %ecx', 'mov %rsi , ( %rsp )', 'mov %rdx , 0x ( %rsp )', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'movaps %xmm0 , 0x ( %rsp )', 'movl $0x , 0x ( %rsp )', 'movaps %xmm0 , 0x ( %rsp )', 'movaps %xmm0 , 0x ( %rsp )', 'movaps %xmm0 , 0x ( %rsp )', 'movq $0x , 0x ( %rsp )', 'movq $0x , 0x ( %rsp )', 'and $0x , %ecx', 'je 0x', 'cmp $0x , %ecx', 'je 0x', 'cmp $0x , %ecx', 'jne 0x', 'movq $0x , 0x ( %rsp )', 'callq 0x', 'mov %eax , %ebx', 'test %eax , %eax', 'jne 0x', 'mov 0x ( %r15 ) , %rax', 'mov 0x ( %rsp ) , %rbp', 'mov %rax , 0x ( %rsp )', 'callq 0x', 'lea 0x ( %rip ) , %rsi', 'movl $0x , 0x ( %rsp )', 'mov %rax , %rdi', 'mov %rax , %r12', 'callq 0x', 'mov %rax , %r13', 'test %rax , %rax', 'je 0x', 'movl $0x , 0x ( %rsp )', 'lea 0x ( %rsp ) , %r12', 'lea 0x ( %rip ) , %r14', 'movq $0x , 0x ( %rsp )', 'movq $0x , 0x ( %rsp )', 'nopw %cs : 0x ( %rax , %rax , 1 )', 'mov %r13 , %rdx', 'mov $0x , %esi', 'mov %r12 , %rdi', 'callq 0x', 'test %rax , %rax', 'je 0x', 'cmpl $0x , 0x ( %rsp )', 'jg 0x', 'xor %eax , %eax', 'lea 0x ( %rsp ) , %rdx', 'lea 0x ( %rsp ) , %r8', 'mov %r12 , %rdi', 'lea 0x ( %rsp ) , %rcx', 'lea 0x ( %rip ) , %rsi', 'callq 0x', 'cmp $0x , %eax', 'jne 0x', 'movslq 0x ( %rsp ) , %r10', 'mov 0x ( %rip ) , %eax', 'add %r12 , %r10', 'test %eax , %eax', 'jne 0x', 'movabs $0x , %rax', 'cmp %rax , ( %r10 )', 'je 0x', 'movabs $0x , %rax', 'cmp %rax , ( %r10 )', 'je 0x', 'movabs $0x , %rax', 'xor 0x ( %r10 ) , %rax', 'movabs $0x , %rdx', 'xor ( %r10 ) , %rdx', 'or %rdx , %rax', 'jne 0x', 'movabs $0x , %rax', 'cmp %rax , 0x ( %r10 )', 'je 0x', 'movabs $0x , %rdx', 'xor 0x ( %r10 ) , %rdx', 'movabs $0x , %rax', 'xor ( %r10 ) , %rax', 'or %rax , %rdx', 'jne 0x', 'movabs $0x , %rax', 'cmp %rax , 0x ( %r10 )', 'je 0x', 'movabs $0x , %rdx', 'xor 0x ( %r10 ) , %rdx', 'movabs $0x , %rax', 'xor ( %r10 ) , %rax', 'or %rax , %rdx', 'je 0x', 'movabs $0x , %rax', 'cmp %rax , ( %r10 )', 'je 0x', 'movabs $0x , %rax', 'cmp %rax , ( %r10 )', 'je 0x', 'cmpl $0x , ( %r10 )', 'jne 0x', 'cmpb $0x , 0x ( %r10 )', 'jne 0x', 'mov 0x ( %rsp ) , %rax', 'movl $0x , 0x ( %rsp )', 'mov %rax , 0x ( %rsp )', 'mov 0x ( %rsp ) , %rax', 'mov %rax , 0x ( %rsp )', 'jmpq 0x', 'nopl 0x ( %rax )', 'xor %r13d , %r13d', 'movq $0x , 0x ( %r15 )', 'movq $0x , 0x ( %r15 )', 'nopl 0x ( %rax )', 'mov %r13d , %edx', 'lea 0x ( %rip ) , %rsi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rip ) , %edx', 'mov 0x ( %rsp ) , %rax', 'test %edx , %edx', 'je 0x', 'cmp $0x , %edx', 'je 0x', 'movq $0x , 0x ( %rsp )', 'cmp $0x , %rax', 'je 0x', 'cmp $0x , %rax', 'jne 0x', 'mov $0x , %eax', 'mov %rax , 0x ( %rsp )', 'mov $0x , %edi', 'lea 0x ( %rsp ) , %rbp', 'lea 0x ( %rip ) , %r12', 'xor %r14d , %r14d', 'callq 0x', 'mov $0x , %edx', 'xor %esi , %esi', 'mov %rax , %rdi', 'mov %rax , %rbx', 'callq 0x', 'xor %r8d , %r8d', 'mov %rbp , %rsi', 'mov %rbx , %rdi', 'mov 0x ( %r15 ) , %rcx', 'mov 0x ( %r15 ) , %rdx', 'callq 0x', 'mov 0x ( %rip ) , %ecx', 'test %ecx , %ecx', 'jg 0x', 'jmpq 0x', 'nopl 0x ( %rax , %rax , 1 )', 'add $0x , %r14d', 'add $0x , %r12', 'cmp %r14d , 0x ( %rip )', 'jle 0x', 'mov 0x ( %r12 ) , %rax', 'mov ( %r12 ) , %rdx', 'xor %r8d , %r8d', 'mov %rbp , %rsi', 'mov %rbx , %rdi', 'lea 0x ( %rax ) , %rcx', 'sub %rdx , %rcx', 'callq 0x', 'test %eax , %eax', 'jns 0x', 'mov $0x , %eax', 'mov 0x ( %rsp ) , %rbx', 'xor %fs : 0x , %rbx', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'nopl ( %rax )', 'cmpw $0x , 0x ( %r10 )', 'jne 0x', 'xor %r8d , %r8d', 'cmpb $0x , 0x ( %r10 )', 'jne 0x', 'movslq 0x ( %rsp ) , %rax', 'mov 0x ( %rsp ) , %rdi', 'test %rbp , %rbp', 'sete %r9b', 'mov 0x ( %rsp ) , %rsi', 'mov %rax , %rdx', 'lea ( %rax , %rax , 2 ) , %rax', 'cmp %rdi , %rbp', 'lea ( %r14 , %rax ,  ...
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:static int add_memmap(struct memory_range *, int *, unsigned long long, size_t, int);
# func-return-type:static int
# func-name:add_memmap
# func-filename:crashdump-x86.c
# func-disassembly:['test %r8d , %r8d', 'jne 0x', 'mov %rdx , %rax', 'or %rcx , %rax', 'test $0x , %eax', 'jne 0x', 'mov %rdi , %rax', 'xor %r9d , %r9d', 'jmp 0x', 'xchg %ax , %ax', 'add $0x , %r9d', 'add $0x , %rax', 'cmp $0x , %r9d', 'je 0x', 'mov ( %rax ) , %r10', 'or 0x ( %rax ) , %r10', 'jne 0x', 'push %r14', 'mov %rdi , %rax', 'push %rbp', 'lea -0x ( %rdx , %rcx , 1 ) , %rbp', 'mov $0x , %ecx', 'push %rbx', 'xor %ebx , %ebx', 'jmp 0x', 'nopl 0x ( %rax , %rax , 1 )', 'cmp %r11 , %rdx', 'jbe 0x', 'mov %ecx , %ebx', 'add $0x , %ecx', 'add $0x , %rax', 'cmp $0x , %ecx', 'je 0x', 'mov ( %rax ) , %r10', 'mov 0x ( %rax ) , %r11', 'mov %r10 , %r14', 'or %r11 , %r14', 'je 0x', 'cmp %rbp , %r10', 'jbe 0x', 'cmp %r11 , %rdx', 'cmova %ecx , %ebx', 'add $0x , %ecx', 'add $0x , %rax', 'cmp $0x , %ecx', 'jne 0x', 'nopl 0x ( %rax , %rax , 1 )', 'lea -0x ( %r9 ) , %ecx', 'cmp %ecx , %ebx', 'jg 0x', 'movslq %ecx , %rax', 'sub %ebx , %ecx', 'lea ( %rax , %rax , 2 ) , %r10', 'lea ( %rcx , %rcx , 2 ) , %rcx', 'shl $0x , %r10', 'shl $0x , %rcx', 'lea ( %rdi , %r10 , 1 ) , %rax', 'lea -0x ( %rdi , %r10 , 1 ) , %r10', 'sub %rcx , %r10', 'nopl 0x ( %rax )', 'movdqu ( %rax ) , %xmm0', 'mov 0x ( %rax ) , %rcx', 'sub $0x , %rax', 'movups %xmm0 , 0x ( %rax )', 'mov %rcx , 0x ( %rax )', 'cmp %rax , %r10', 'jne 0x', 'movslq %ebx , %rbx', 'lea ( %rbx , %rbx , 2 ) , %rax', 'lea ( %rdi , %rax , 8 ) , %rax', 'mov %rdx , ( %rax )', 'lea 0x ( %r9 ) , %edx', 'mov %rbp , 0x ( %rax )', 'mov %r8d , 0x ( %rax )', 'mov %edx , ( %rsi )', 'mov %rdi , %rsi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'pop %rbx', 'xor %eax , %eax', 'pop %rbp', 'pop %r14', 'retq', 'nopl 0x ( %rax , %rax , 1 )', 'pop %rbx', 'mov $0x , %eax', 'pop %rbp', 'pop %r14', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'mov $0x , %eax', 'retq']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:static int crashkernel_mem_callback(void *, int, char *, unsigned long long, unsigned long long);
# func-return-type:static int
# func-name:crashkernel_mem_callback
# func-filename:crashdump-x86.c
# func-disassembly:['mov $0x , %eax', 'cmp $0x , %esi', 'jg 0x', 'movslq %esi , %rsi', 'lea 0x ( %rip ) , %rax', 'lea ( %rsi , %rsi , 2 ) , %rdx', 'lea ( %rax , %rdx , 8 ) , %rax', 'lea -0x ( %rcx , %r8 , 1 ) , %rdx', 'mov %rcx , ( %rax )', 'mov %rdx , 0x ( %rax )', 'movl $0x , 0x ( %rax )', 'xor %eax , %eax', 'retq']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:static int delete_memmap(struct memory_range *, int *, unsigned long long, size_t);
# func-return-type:static int
# func-name:delete_memmap
# func-filename:crashdump-x86.c
# func-disassembly:['mov %rdx , %rax', 'or %rcx , %rax', 'test $0x , %eax', 'jne 0x', 'mov %rdi , %r8', 'xor %r10d , %r10d', 'jmp 0x', 'nopl 0x ( %rax )', 'add $0x , %r10d', 'add $0x , %r8', 'cmp $0x , %r10d', 'je 0x', 'mov ( %r8 ) , %rax', 'or 0x ( %r8 ) , %rax', 'jne 0x', 'push %r14', 'mov %rdi , %r8', 'push %rbp', 'lea ( %rdx , %rcx , 1 ) , %rbp', 'push %rbx', 'lea -0x ( %rbp ) , %rbx', 'jmp 0x', 'nop', 'cmp %r9 , %rdx', 'jb 0x', 'cmp %r11 , %rbx', 'jbe 0x', 'add $0x , %rax', 'add $0x , %r8', 'cmp $0x , %rax', 'je 0x', 'mov ( %r8 ) , %r9', 'mov 0x ( %r8 ) , %r11', 'movslq %eax , %rcx', 'mov %r9 , %r14', 'or %r11 , %r14', 'jne 0x', 'pop %rbx', 'mov $0x , %eax', 'pop %rbp', 'pop %r14', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'cmp %r9 , %rdx', 'je 0x', 'sub $0x , %rdx', 'mov %rdx , 0x ( %r8 )', 'cmp %r11 , %rbx', 'je 0x', 'lea -0x ( %r10 ) , %edx', 'mov 0x ( %r8 ) , %r9d', 'cmp %ecx , %edx', 'jle 0x', 'movslq %edx , %rdx', 'lea -0x ( %r10 ) , %r8d', 'lea ( %rdx , %rdx , 2 ) , %rcx', 'sub %eax , %r8d', 'shl $0x , %rcx', 'lea ( %r8 , %r8 , 2 ) , %r8', 'lea ( %rdi , %rcx , 1 ) , %rdx', 'shl $0x , %r8', 'lea -0x ( %rdi , %rcx , 1 ) , %rcx', 'sub %r8 , %rcx', 'nopl 0x ( %rax )', 'movdqu ( %rdx ) , %xmm0', 'mov 0x ( %rdx ) , %r8', 'sub $0x , %rdx', 'movups %xmm0 , 0x ( %rdx )', 'mov %r8 , 0x ( %rdx )', 'cmp %rdx , %rcx', 'jne 0x', 'lea 0x ( %rax , %rax , 2 ) , %rax', 'lea 0x ( %r10 ) , %edx', 'lea ( %rdi , %rax , 8 ) , %rax', 'mov %rbp , ( %rax )', 'mov %r11 , 0x ( %rax )', 'mov %r9d , 0x ( %rax )', 'mov %edx , ( %rsi )', 'mov %rdi , %rsi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'pop %rbx', 'xor %eax , %eax', 'pop %rbp', 'pop %r14', 'retq', 'cmp %r11 , %rbx', 'je 0x', 'mov %rbp , ( %r8 )', 'mov ( %rsi ) , %edx', 'jmp 0x', 'nopl ( %rax )', 'lea 0x ( %rcx ) , %edx', 'cmp $0x , %edx', 'je 0x', 'mov $0x , %r8d', 'movslq %edx , %rdx', 'mov %r8d , %ebx', 'lea ( %rdx , %rdx , 2 ) , %rdx', 'sub %eax , %ebx', 'lea ( %rdi , %rdx , 8 ) , %rdx', 'mov %rbx , %rax', 'add %rcx , %rax', 'lea ( %rax , %rax , 2 ) , %rax', 'lea 0x ( %rdi , %rax , 8 ) , %rcx', 'nopl 0x ( %rax , %rax , 1 )', 'movdqu ( %rdx ) , %xmm1', 'mov 0x ( %rdx ) , %rax', 'add $0x , %rdx', 'movups %xmm1 , -0x ( %rdx )', 'mov %rax , -0x ( %rdx )', 'cmp %rdx , %rcx', 'jne 0x', 'movq $0x , 0x ( %rdi )', 'lea -0x ( %r10 ) , %edx', 'movq $0x , 0x ( %rdi )', 'mov %edx , ( %rsi )', 'jmpq 0x', 'nopw 0x ( %rax , %rax , 1 )', 'mov $0x , %eax', 'retq']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:static int exclude_region(int *, uint64_t, uint64_t);
# func-return-type:static int
# func-name:exclude_region
# func-filename:crashdump-x86.c
# func-disassembly:['mov ( %rdi ) , %eax', 'test %eax , %eax', 'jle 0x', 'push %r12', 'lea 0x ( %rip ) , %rax', 'xor %r11d , %r11d', 'xor %ecx , %ecx', 'push %rbp', 'mov $0x , %r10', 'lea 0x ( %rdx ) , %r12', 'lea -0x ( %rsi ) , %rbp', 'push %rbx', 'xor %ebx , %ebx', 'jmp 0x', 'nopl ( %rax )', 'mov %rbp , ( %rax )', 'mov %r12 , %rbx', 'mov %r8 , %r11', 'movslq %ecx , %r10', 'mov ( %rdi ) , %r8d', 'add $0x , %rax', 'cmp %ecx , %r8d', 'jle 0x', 'mov ( %rax ) , %r8', 'mov -0x ( %rax ) , %r9', 'add $0x , %ecx', 'cmp %rsi , %r8', 'jbe 0x', 'cmp %rdx , %r9', 'jae 0x', 'cmp %rsi , %r9', 'je 0x', 'cmp %rdx , %r8', 'jne 0x', 'cmp %rsi , %r9', 'je 0x', 'mov %rbp , ( %rax )', 'mov ( %rdi ) , %r8d', 'add $0x , %rax', 'cmp %ecx , %r8d', 'jg 0x', 'xchg %ax , %ax', 'cmp $0x , %r10d', 'je 0x', 'cmp $0x , %r8d', 'je 0x', 'cmp %r10d , %r8d', 'jle 0x', 'movslq %r8d , %rdx', 'sub $0x , %r8d', 'lea 0x ( %rip ) , %rsi', 'sub %r10d , %r8d', 'lea ( %rdx , %rdx , 2 ) , %rax', 'sub %r8 , %rdx', 'lea ( %rsi , %rax , 8 ) , %rax', 'lea ( %rdx , %rdx , 2 ) , %rcx', 'lea -0x ( %rsi ) , %rdx', 'lea ( %rdx , %rcx , 8 ) , %rcx', 'movdqu -0x ( %rax ) , %xmm0', 'mov -0x ( %rax ) , %rdx', 'sub $0x , %rax', 'movups %xmm0 , 0x ( %rax )', 'mov %rdx , 0x ( %rax )', 'cmp %rcx , %rax', 'jne 0x', 'lea ( %r10 , %r10 , 2 ) , %rax', 'lea ( %rsi , %rax , 8 ) , %rax', 'mov %rbx , ( %rax )', 'mov %r11 , 0x ( %rax )', 'movl $0x , 0x ( %rax )', 'addl $0x , ( %rdi )', 'xor %eax , %eax', 'pop %rbx', 'pop %rbp', 'pop %r12', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'mov %r12 , -0x ( %rax )', 'jmpq 0x', 'lea 0x ( %rip ) , %rsi', 'jmp 0x', 'nopw 0x ( %rax , %rax , 1 )', 'xor %eax , %eax', 'retq', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %edx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov $0x , %eax', 'jmp 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:static int get_crash_notes(int, uint64_t *, uint64_t *);
# func-return-type:static int
# func-name:get_crash_notes
# func-filename:crashdump-x86.c
# func-disassembly:['push %r14', 'push %r13', 'push %r12', 'mov %rdx , %r12', 'push %rbp', 'mov %rsi , %rbp', 'lea 0x ( %rip ) , %rsi', 'push %rbx', 'mov %edi , %ebx', 'lea 0x ( %rip ) , %rdi', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'callq 0x', 'test %rax , %rax', 'je 0x', 'lea 0x ( %rsp ) , %r14', 'mov %rax , %rdx', 'mov $0x , %esi', 'mov %rax , %r13', 'mov %r14 , %rdi', 'callq 0x', 'test %rax , %rax', 'je 0x', 'xor %eax , %eax', 'lea 0x ( %rsp ) , %rdx', 'lea 0x ( %rip ) , %rsi', 'mov %r14 , %rdi', 'callq 0x', 'cmp $0x , %eax', 'jne 0x', 'movabs $0x , %rax', 'shl $0x , %ebx', 'add 0x ( %rsp ) , %rax', 'movslq %ebx , %rbx', 'add %rax , %rbx', 'mov %rbx , 0x ( %rbp )', 'movq $0x , ( %r12 )', 'mov 0x ( %rip ) , %eax', 'test %eax , %eax', 'jne 0x', 'mov %r13 , %rdi', 'callq 0x', 'xor %eax , %eax', 'mov 0x ( %rsp ) , %rcx', 'xor %fs : 0x , %rcx', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'retq', 'nopl ( %rax )', 'mov 0x ( %rbp ) , %rcx', 'mov 0x ( %rip ) , %rdi', 'lea 0x ( %rip ) , %rdx', 'xor %eax , %eax', 'mov $0x , %esi', 'callq 0x', 'jmp 0x', 'mov %r12 , %rdx', 'mov %rbp , %rsi', 'mov %ebx , %edi', 'callq 0x', 'jmp 0x', 'nop', 'callq 0x', 'mov ( %rax ) , %edi', 'callq 0x', 'lea 0x ( %rip ) , %rsi', 'lea 0x ( %rip ) , %rdi', 'mov %rax , %rdx', 'xor %eax , %eax', 'callq 0x', 'jmpq 0x', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:static void ultoa(unsigned long, char *);
# func-return-type:static void
# func-name:ultoa
# func-filename:crashdump-x86.c
# func-disassembly:['movabs $0x , %r8', 'push %rbx', 'mov $0x , %ecx', 'mov %rsi , %rbx', 'jmp 0x', 'nopl ( %rax )', 'mov %rdx , %rdi', 'mov %rdi , %rax', 'mov %rdi , %r9', 'movslq %ecx , %rsi', 'mul %r8', 'shr $0x , %rdx', 'lea ( %rdx , %rdx , 4 ) , %rax', 'add %rax , %rax', 'sub %rax , %r9', 'mov %r9 , %rax', 'add $0x , %eax', 'mov %al , -0x ( %rbx , %rcx , 1 )', 'add $0x , %rcx', 'cmp $0x , %rdi', 'ja 0x', 'movb $0x , ( %rbx , %rsi , 1 )', 'mov %rbx , %rdi', 'callq 0x', 'xor %edx , %edx', 'sub $0x , %eax', 'movslq %eax , %rcx', 'test %eax , %eax', 'jle 0x', 'nopl 0x ( %rax )', 'movzbl ( %rbx , %rcx , 1 ) , %eax', 'movzbl ( %rbx , %rdx , 1 ) , %esi', 'mov %sil , ( %rbx , %rcx , 1 )', 'sub $0x , %rcx', 'mov %al , ( %rbx , %rdx , 1 )', 'add $0x , %rdx', 'cmp %edx , %ecx', 'jg 0x', 'pop %rbx', 'retq']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int beoboot_load(int, char **, const char *, off_t, struct kexec_info *);
# func-return-type:int
# func-name:beoboot_load
# func-filename:kexec-beoboot-x86.c
# func-disassembly:['push %r15', 'xor %r15d , %r15d', 'push %r14', 'mov %r8 , %r14', 'push %r13', 'mov %rdx , %r13', 'push %r12', 'mov $0x , %r12d', 'push %rbp', 'mov %edi , %ebp', 'push %rbx', 'mov %rsi , %rbx', 'sub $0x , %rsp', 'jmp 0x', 'nopl 0x ( %rax )', 'cmp $0x , %eax', 'cmovge %r12d , %r15d', 'xor %r8d , %r8d', 'lea 0x ( %rip ) , %rcx', 'mov %rbx , %rsi', 'lea 0x ( %rip ) , %rdx', 'mov %ebp , %edi', 'callq 0x', 'cmp $0x , %eax', 'jne 0x', 'movdqu 0x ( %r13 ) , %xmm0', 'lea 0x ( %r13 ) , %rcx', 'xor %r9d , %r9d', 'movaps %xmm0 , ( %rsp )', 'movdqa ( %rsp ) , %xmm1', 'mov 0x ( %rsp ) , %edx', 'btq $0x , ( %rsp )', 'pextrw $0x , %xmm1 , %r8d', 'lea ( %rcx , %r8 , 1 ) , %rsi', 'jae 0x', 'lea ( %rsi , %rdx , 1 ) , %r9', 'push %r15', 'mov 0x ( %rsp ) , %rax', 'mov %r14 , %rdi', 'shr $0x , %rax', 'push %rax', 'callq 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int beoboot_probe(const char *, off_t);
# func-return-type:int
# func-name:beoboot_probe
# func-filename:kexec-beoboot-x86.c
# func-disassembly:['sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'cmp $0x , %rsi', 'jbe 0x', 'movdqu ( %rdi ) , %xmm0', 'movaps %xmm0 , ( %rsp )', 'mov ( %rsp ) , %eax', 'movaps %xmm0 , 0x ( %rsp )', 'cmp $0x , %eax', 'jne 0x', 'mov ( %rsp ) , %rax', 'shr $0x , %rax', 'cmp $0x , %al', 'jne 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'movdqa ( %rsp ) , %xmm2', 'mov 0x ( %rsp ) , %esi', 'add $0x , %rsp', 'pextrw $0x , %xmm2 , %eax', 'lea 0x ( %rdi , %rax , 1 ) , %rdi', 'jmpq 0x', 'nopl 0x ( %rax )', 'mov 0x ( %rsp ) , %rdx', 'xor %fs : 0x , %rdx', 'mov $0x , %eax', 'jne 0x', 'add $0x , %rsp', 'retq', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:void beoboot_usage(void);
# func-return-type:void
# func-name:beoboot_usage
# func-filename:kexec-beoboot-x86.c
# func-disassembly:['lea 0x ( %rip ) , %rdi', 'jmpq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int bzImage_load(int, char **, const char *, off_t, struct kexec_info *);
# func-return-type:int
# func-name:bzImage_load
# func-filename:kexec-bzImage.c
# func-disassembly:['push %r15', 'xor %r15d , %r15d', 'push %r14', 'xor %r14d , %r14d', 'push %r13', 'xor %r13d , %r13d', 'push %r12', 'xor %r12d , %r12d', 'push %rbp', 'mov %edi , %ebp', 'push %rbx', 'mov %rsi , %rbx', 'sub $0x , %rsp', 'mov %rdx , 0x ( %rsp )', 'mov %rcx , 0x ( %rsp )', 'mov %r8 , 0x ( %rsp )', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'movq $0x , 0x ( %rsp )', 'nopw 0x ( %rax , %rax , 1 )', 'xor %r8d , %r8d', 'lea 0x ( %rip ) , %rcx', 'mov %rbx , %rsi', 'mov %ebp , %edi', 'lea 0x ( %rip ) , %rdx', 'callq 0x', 'cmp $0x , %eax', 'je 0x', 'cmp $0x , %eax', 'je 0x', 'jle 0x', 'cmp $0x , %eax', 'je 0x', 'cmp $0x , %eax', 'jne 0x', 'mov $0x , %r12d', 'jmp 0x', 'nop', 'cmp $0x , %eax', 'jne 0x', 'mov 0x ( %rip ) , %r15', 'jmp 0x', 'callq 0x', 'mov %rax , %r14', 'jmp 0x', 'nopw 0x ( %rax , %rax , 1 )', 'cmp $0x , %eax', 'jle 0x', 'jmp 0x', 'nopl 0x ( %rax )', 'mov 0x ( %rip ) , %r13', 'jmp 0x', 'nopl 0x ( %rax )', 'mov %r15 , %rsi', 'mov %r14 , %rdi', 'callq 0x', 'mov %rax , %rbx', 'test %r14 , %r14', 'je 0x', 'mov %r14 , %rdi', 'callq 0x', 'test %rbx , %rbx', 'je 0x', 'mov %rbx , %rdi', 'callq 0x', 'lea 0x ( %rax ) , %ebp', 'movslq %ebp , %rbp', 'test %r13 , %r13', 'je 0x', 'mov %r13 , %rdi', 'lea 0x ( %rsp ) , %rsi', 'callq 0x', 'mov %rax , %r13', 'push %r12', 'mov %rbp , %r8', 'mov %r13 , %r9', 'mov %rbx , %rcx', 'pushq 0x ( %rsp )', 'mov 0x ( %rsp ) , %rdx', 'mov 0x ( %rsp ) , %rsi', 'mov 0x ( %rsp ) , %rdi', 'callq 0x', 'mov %rbx , %rdi', 'mov %eax , %ebp', 'callq 0x', 'pop %rax', 'pop %rdx', 'mov %ebp , %eax', 'mov 0x ( %rsp ) , %rdx', 'xor %fs : 0x , %rdx', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'nopl 0x ( %rax , %rax , 1 )', 'lea 0x ( %rip ) , %rdi', 'mov $0x , %ebp', 'callq 0x', 'mov %rax , %rbx', 'jmp 0x', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int bzImage_probe(const char *, off_t);
# func-return-type:int
# func-name:bzImage_probe
# func-filename:kexec-bzImage.c
# func-disassembly:['cmp $0x , %rsi', 'jbe 0x', 'cmpl $0x , 0x ( %rdi )', 'jne 0x', 'cmpw $0x , 0x ( %rdi )', 'jne 0x', 'cmpw $0x , 0x ( %rdi )', 'jbe 0x', 'movzbl 0x ( %rdi ) , %eax', 'not %eax', 'and $0x , %eax', 'neg %eax', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'mov $0x , %eax', 'retq']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:void bzImage_usage(void);
# func-return-type:void
# func-name:bzImage_usage
# func-filename:kexec-bzImage.c
# func-disassembly:['lea 0x ( %rip ) , %rdi', 'jmpq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int do_bzImage_load(struct kexec_info *, const char *, off_t, const char *, off_t, const char *, off_t, int);
# func-return-type:int
# func-name:do_bzImage_load
# func-filename:kexec-bzImage.c
# func-disassembly:['push %r15', 'push %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov %rdx , 0x ( %rsp )', 'mov %rcx , 0x ( %rsp )', 'mov %r8 , 0x ( %rsp )', 'mov %r9 , 0x ( %rsp )', 'mov %fs : 0x , %rbx', 'mov %rbx , 0x ( %rsp )', 'xor %ebx , %ebx', 'cmp $0x , %rdx', 'jbe 0x', 'mov %rdi , %rbp', 'mov %rsi , %r14', 'mov $0x , %ecx', 'lea 0x ( %rsp ) , %rdi', 'rep movsq %ds : ( %rsi ) , %es : ( %rdi )', 'movzwl 0x ( %rsp ) , %eax', 'movzbl 0x ( %rsp ) , %r13d', 'movzwl 0x ( %rsp ) , %ebx', 'movzbl 0x ( %rsp ) , %r15d', 'mov %ax , 0x ( %rsp )', 'test %r13d , %r13d', 'je 0x', 'add $0x , %r13d', 'shl $0x , %r13d', 'movslq %r13d , %rax', 'mov %rax , 0x ( %rsp )', 'mov 0x ( %rsp ) , %rsi', 'cmp %rsi , 0x ( %rsp )', 'jl 0x', 'cmp $0x , %bx', 'jbe 0x', 'mov 0x ( %rip ) , %eax', 'mov 0x ( %rsp ) , %edx', 'cmp 0x ( %rsp ) , %rdx', 'jb 0x', 'test %eax , %eax', 'jne 0x', 'mov 0x ( %rbp ) , %rax', 'test $0x , %al', 'je 0x', 'mov 0x ( %rsp ) , %r10d', 'test %r10d , %r10d', 'jne 0x', 'test %r15d , %r15d', 'je 0x', 'test $0x , %al', 'jne 0x', 'mov 0x ( %rsp ) , %rax', 'mov %rax , 0x ( %rsp )', 'jmpq 0x', 'nopw 0x ( %rax , %rax , 1 )', 'movq $0x , 0x ( %rsp )', 'mov $0x , %r13d', 'jmpq 0x', 'nopl 0x ( %rax )', 'test $0x , %al', 'je 0x', 'xor %r15d , %r15d', 'mov $0x , %edi', 'callq 0x', 'lea 0x ( %rax ) , %rdi', 'mov %rax , %rcx', 'movq $0x , ( %rax )', 'mov %rax , %r12', 'movq $0x , 0x ( %rax )', 'and $0x , %rdi', 'xor %eax , %eax', 'sub %rdi , %rcx', 'add $0x , %ecx', 'shr $0x , %ecx', 'rep stos %rax , %es : ( %rdi )', 'mov 0x ( %rsp ) , %rax', 'test %rax , %rax', 'je 0x', 'mov $0x , %edx', 'mov %rax , %rsi', 'mov %r12 , %rdi', 'callq 0x', 'movb $0x , 0x ( %r12 )', 'xor %ecx , %ecx', 'mov $0x , %rdx', 'mov %r12 , %rsi', 'mov %rbp , %rdi', 'callq 0x', 'test %eax , %eax', 'js 0x', 'mov %r12 , %rdi', 'callq 0x', 'mov %r12 , 0x ( %rsp )', 'add $0x , %rax', 'mov %rax , 0x ( %rsp )', 'mov %rax , 0x ( %rsp )', 'mov 0x ( %rsp ) , %r9d', 'test %r15d , %r15d', 'setne 0x ( %rsp )', 'movzbl 0x ( %rsp ) , %eax', 'test %r9d , %r9d', 'jne 0x', 'test %al , %al', 'je 0x', 'pushq $0x', 'lea 0x ( %rbp ) , %r15', 'mov 0x ( %rip ) , %rcx', 'mov %rbp , %rdi', 'pushq $0x', 'mov $0x , %r8d', 'mov %r15 , %rsi', 'mov $0x , %r9d', 'lea 0x ( %rip ) , %rdx', 'callq 0x', 'mov 0x ( %rip ) , %r8d', 'pop %rsi', 'pop %rdi', 'test %r8d , %r8d', 'movb $0x , 0x ( %rsp )', 'jne 0x', 'cmp $0x , %r13d', 'mov $0x , %eax', 'mov 0x ( %rsp ) , %rbx', 'cmovge %r13d , %eax', 'cltq', 'lea 0x ( %rbx , %rax , 1 ) , %r12', 'mov %rax , 0x ( %rsp )', 'mov %r12 , %rdi', 'callq 0x', 'xor %esi , %esi', 'mov %r12 , %rdx', 'mov %rax , %rdi', 'mov %rax , %rbx', 'callq 0x', 'movsbl 0x ( %r14 ) , %ecx', 'lea 0x ( %rbx ) , %rdx', 'lea 0x ( %r14 ) , %rsi', 'add $0x , %ecx', 'movslq %ecx , %rax', 'mov $0x , %ecx', 'cmp $0x , %rax', 'cmovbe %rax , %rcx', 'cmp $0x , %ecx', 'jae 0x', 'test $0x , %cl', 'jne 0x', 'test %ecx , %ecx', 'jne 0x', 'movq $0x , 0x ( %rsp )', 'movslq %r13d , %r13', 'testb $0x , 0x ( %rbp )', 'jne 0x', 'cmpw $0x , 0x ( %rbx )', 'jbe 0x', 'pushq $0x', 'pushq $0x', 'mov $0x , %r9d', 'mov %r12 , %rcx', 'mov %r12 , %rdx', 'mov %rbx , %rsi', 'mov $0x , %r8d', 'mov %rbp , %rdi', 'callq 0x', 'mov 0x ( %rip ) , %r9d', 'mov %eax , 0x ( %rsp )', 'mov %rax , %r12', 'pop %r10', 'pop %r11', 'test %r9d , %r9d', 'jne 0x', 'cmp %r12 , 0x ( %rbp )', 'jb 0x', 'mov 0x ( %rsp ) , %rdx', 'sub 0x ( %rsp ) , %rdx', 'lea ( %r14 , %r13 , 1 ) , %rsi', 'cmpw $0x , 0x ( %rbx )', 'jbe 0x', 'cmpb $0x , 0x ( %rsp )', 'je 0x', 'mov 0x ( %rbx ) , %eax', 'mov $0x , %ecx', 'mov 0x ( %rbx ) , %r8d', 'pushq $0x', 'mov %rbp , %rdi', 'mov $0x , %r9d', 'cmp $0x , %eax', 'cmovae %rcx , %rax', 'mov %rdx , %rcx', 'push %rax', 'callq 0x', 'mov 0x ( %rip ) , %esi', 'pop %rdi', 'mov %eax , %r14d', 'pop %r8', 'test %esi , %esi', 'jne 0x', 'sub $0x , %rsp', 'mov %r12 , %rdx', 'mov %rbx , %rsi', 'mov %rbp , %rdi', 'pushq $0x', 'pushq 0x ( %rsp )', 'pushq 0x ( %rsp )', 'mov 0x ( %rsp ) , %r13', 'mov  ...
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int elf_x86_load(int, char **, const char *, off_t, struct kexec_info *);
# func-return-type:int
# func-name:elf_x86_load
# func-filename:kexec-elf-x86.c
# func-disassembly:['push %r15', 'mov %r8 , %r15', 'push %r14', 'push %r13', 'xor %r13d , %r13d', 'push %r12', 'mov %edi , %r12d', 'push %rbp', 'mov %rsi , %rbp', 'push %rbx', 'lea 0x ( %rip ) , %rbx', 'sub $0x , %rsp', 'mov %rdx , 0x ( %rsp )', 'mov %rcx , 0x ( %rsp )', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'movl $0x , 0x ( %rsp )', 'movq $0x , 0x ( %rsp )', 'movq $0x , 0x ( %rsp )', 'nopl 0x ( %rax , %rax , 1 )', 'xor %r8d , %r8d', 'lea 0x ( %rip ) , %rcx', 'mov %rbp , %rsi', 'mov %r12d , %edi', 'lea 0x ( %rip ) , %rdx', 'callq 0x', 'cmp $0x , %eax', 'je 0x', 'lea -0x ( %rax ) , %edx', 'cmp $0x , %edx', 'ja 0x', 'movslq ( %rbx , %rdx , 4 ) , %rax', 'add %rbx , %rax', 'jmpq *%rax', 'nopl ( %rax )', 'cmp $0x , %eax', 'jle 0x', 'mov 0x ( %rip ) , %rax', 'mov %rax , 0x ( %rsp )', 'jmp 0x', 'nopl ( %rax )', 'movl $0x , 0x ( %rsp )', 'jmp 0x', 'nopw 0x ( %rax , %rax , 1 )', 'lea 0x ( %rip ) , %rdi', 'xor %eax , %eax', 'callq 0x', 'jmp 0x', 'mov 0x ( %rip ) , %rax', 'mov %rax , 0x ( %rsp )', 'jmp 0x', 'xchg %ax , %ax', 'callq 0x', 'mov %rax , %r13', 'jmpq 0x', 'nopl ( %rax )', 'movl $0x , 0x ( %rsp )', 'jmpq 0x', 'nopl ( %rax )', 'mov 0x ( %rsp ) , %rsi', 'mov %r13 , %rdi', 'mov %eax , %r14d', 'callq 0x', 'mov %rax , %rbx', 'test %r13 , %r13', 'je 0x', 'mov %r13 , %rdi', 'callq 0x', 'mov 0x ( %r15 ) , %rbp', 'and $0x , %ebp', 'test %rbx , %rbx', 'je 0x', 'mov %rbx , %rdi', 'callq 0x', 'add $0x , %eax', 'mov %eax , 0x ( %rsp )', 'test %rbp , %rbp', 'jne 0x', 'lea 0x ( %rsp ) , %r12', 'mov 0x ( %rsp ) , %rcx', 'xor %r8d , %r8d', 'mov %r15 , %rdi', 'mov 0x ( %rsp ) , %rdx', 'mov %r12 , %rsi', 'callq 0x', 'mov 0x ( %rsp ) , %rax', 'mov %r12 , %rdi', 'lea 0x ( %r15 ) , %r12', 'mov %rax , 0x ( %rsp )', 'callq 0x', 'pushq $0x', 'mov %r12 , %rsi', 'mov %r15 , %rdi', 'pushq $0x', 'mov 0x ( %rip ) , %rcx', 'xor %r8d , %r8d', 'mov %rax , %r13', 'mov $0x , %r9', 'lea 0x ( %rip ) , %rdx', 'callq 0x', 'pop %rcx', 'pop %rsi', 'mov 0x ( %rsp ) , %edi', 'test %edi , %edi', 'je 0x', 'mov $0x , %edi', 'callq 0x', 'pushq $0x', 'mov $0x , %edx', 'xor %r9d , %r9d', 'push %r13', 'mov %rax , %rsi', 'mov $0x , %r8d', 'mov $0x , %ecx', 'mov %r15 , %rdi', 'mov %rax , 0x ( %rsp )', 'callq 0x', 'mov 0x ( %rsp ) , %rsi', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'lea 0x ( %rsi ) , %rdi', 'mov %rsi , %rcx', 'movq $0x , ( %rsi )', 'movq $0x , 0x ( %rsi )', 'and $0x , %rdi', 'sub %rdi , %rcx', 'add $0x , %ecx', 'shr $0x , %ecx', 'rep stos %rax , %es : ( %rdi )', 'mov %rsi , %rdi', 'callq 0x', 'movq $0x , 0x ( %rsp )', 'pop %rax', 'pop %rdx', 'mov 0x ( %rsp ) , %rdi', 'test %rdi , %rdi', 'je 0x', 'lea 0x ( %rsp ) , %rsi', 'callq 0x', 'mov %rax , 0x ( %rsp )', 'testb $0x , 0x ( %r15 )', 'je 0x', 'mov %r15 , %rdi', 'xor %ecx , %ecx', 'mov %r13 , %rdx', 'mov %rbp , %rsi', 'callq 0x', 'mov %rbx , %rdi', 'test %eax , %eax', 'js 0x', 'callq 0x', 'mov %rbp , %rdi', 'mov %rbp , %rbx', 'xor %ebp , %ebp', 'callq 0x', 'add $0x , %eax', 'mov %eax , 0x ( %rsp )', 'sub $0x , %rsp', 'mov %rbx , %r8', 'mov $0x , %ecx', 'mov %r15 , %rdi', 'pushq $0x', 'pushq 0x ( %rsp )', 'pushq 0x ( %rsp )', 'mov 0x ( %rsp ) , %r14', 'mov 0x ( %rsp ) , %r13', 'movslq 0x ( %rsp ) , %r9', 'mov %r14 , %rsi', 'mov %r13 , %rdx', 'callq 0x', 'add $0x , %rsp', 'mov %r14 , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'lea 0x ( %rsp ) , %r14', 'mov $0x , %ecx', 'mov %r12 , %rdi', 'mov %r14 , %rdx', 'lea 0x ( %rip ) , %rsi', 'callq 0x', 'mov 0x ( %rsp ) , %eax', 'mov %r12 , %rdi', 'lea 0x ( %rip ) , %rsi', 'movl $0x , 0x ( %rsp )', 'mov %r13d , 0x ( %rsp )', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov $0x , %ecx', 'mov %r14 , %rdx', 'mov %r12 , %rdi', 'lea 0x ( %rip ) , %rsi', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov %rbx , %rdi', 'callq 0x', 'mov %rbp , %rdi', 'callq 0x', 'movl $0x , 0x ( %rsp )', 'jmpq 0x', 'nopw %cs : 0x ( %rax , %rax , 1 )', 'mov 0x ( %rsp ) , %ecx', 'mov %r13 , %rsi', 'mov %rbx , %rdx', 'mov %r15 , %rdi', 'lea 0x ( %rsp ) , %r13', 'callq 0x', 'lea 0x ( %rsp ) , ...
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int elf_x86_probe(const char *, off_t);
# func-return-type:int
# func-name:elf_x86_probe
# func-filename:kexec-elf-x86.c
# func-disassembly:['push %rbp', 'xor %ecx , %ecx', 'push %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'mov %rsp , %rbp', 'mov %rbp , %rdx', 'callq 0x', 'mov %eax , %ebx', 'test %eax , %eax', 'js 0x', 'mov 0x ( %rsp ) , %edx', 'cmp $0x , %edx', 'setne %al', 'xor %ebx , %ebx', 'cmp $0x , %edx', 'setne %bl', 'and %eax , %ebx', 'neg %ebx', 'mov %rbp , %rdi', 'callq 0x', 'mov %ebx , %eax', 'mov 0x ( %rsp ) , %rcx', 'xor %fs : 0x , %rcx', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:void elf_x86_usage(void);
# func-return-type:void
# func-name:elf_x86_usage
# func-filename:kexec-elf-x86.c
# func-disassembly:['lea 0x ( %rip ) , %rdi', 'jmpq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int multiboot_x86_load(int, char **, const char *, off_t, struct kexec_info *);
# func-return-type:int
# func-name:multiboot_x86_load
# func-filename:kexec-multiboot-x86.c
# func-disassembly:['push %r15', 'push %r14', 'mov %rdx , %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'mov %rsi , %rbx', 'sub $0x , %rsp', 'mov %edi , 0x ( %rsp )', 'mov %rcx , 0x ( %rsp )', 'mov %r8 , 0x ( %rsp )', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'cmpq $0x , 0x ( %rip )', 'je 0x', 'movl $0x , ( %rsp )', 'xor %r13d , %r13d', 'xor %r12d , %r12d', 'lea 0x ( %rip ) , %rbp', 'movl $0x , 0x ( %rsp )', 'nopw 0x ( %rax , %rax , 1 )', 'mov 0x ( %rsp ) , %edi', 'xor %r8d , %r8d', 'mov %rbp , %rcx', 'mov %rbx , %rsi', 'lea 0x ( %rip ) , %rdx', 'callq 0x', 'cmp $0x , %eax', 'je 0x', 'cmp $0x , %eax', 'je 0x', 'cmp $0x , %eax', 'je 0x', 'cmp $0x , %eax', 'je 0x', 'cmp $0x , %eax', 'jle 0x', 'mov 0x ( %rip ) , %r13', 'jmp 0x', 'nopl 0x ( %rax , %rax , 1 )', 'callq 0x', 'mov %rax , %r12', 'jmp 0x', 'nopw 0x ( %rax , %rax , 1 )', 'mov 0x ( %rip ) , %rdi', 'addl $0x , 0x ( %rsp )', 'callq 0x', 'mov ( %rsp ) , %esi', 'lea 0x ( %rsi , %rax , 1 ) , %eax', 'mov %eax , ( %rsp )', 'jmp 0x', 'nopl ( %rax )', 'mov %eax , %r15d', 'movslq 0x ( %rip ) , %rax', 'mov %r13 , %rsi', 'mov %r12 , %rdi', 'mov ( %rbx , %rax , 8 ) , %rbp', 'callq 0x', 'mov %rax , %r13', 'test %r12 , %r12', 'je 0x', 'mov %r12 , %rdi', 'callq 0x', 'mov %r13 , %rsi', 'mov %rbp , %rdi', 'callq 0x', 'mov %rax , 0x ( %rsp )', 'test %r13 , %r13', 'je 0x', 'mov %r13 , %rdi', 'callq 0x', 'mov 0x ( %rsp ) , %rdi', 'callq 0x', 'mov 0x ( %rsp ) , %r13', 'xor %r8d , %r8d', 'mov %r14 , %rdx', 'mov 0x ( %rsp ) , %rcx', 'lea 0x ( %rsp ) , %rsi', 'mov %rax , %rbp', 'mov %r13 , %rdi', 'lea 0x ( %rbp ) , %r12d', 'add $0x , %ebp', 'callq 0x', 'lea 0x ( %r13 ) , %rax', 'xor %r8d , %r8d', 'mov %r13 , %rdi', 'mov %rax , 0x ( %rsp )', 'mov 0x ( %rip ) , %rcx', 'mov %rax , %rsi', 'movslq %r12d , %r12', 'pushq $0x', 'mov $0x , %r9', 'lea 0x ( %rip ) , %rdx', 'pushq $0x', 'callq 0x', 'lea 0x ( %r12 ) , %rax', 'and $0x , %rax', 'mov %rax , %rdi', 'mov %rax , 0x ( %rsp )', 'callq 0x', 'lea 0x ( %rax ) , %rdi', 'mov %rax , %rcx', 'lea 0x ( %rax ) , %rdx', 'mov %rax , %r14', 'and $0x , %rdi', 'movq $0x , ( %rax )', 'sub %rdi , %rcx', 'movq $0x , 0x ( %rax )', 'xor %eax , %eax', 'add $0x , %ecx', 'shr $0x , %ecx', 'rep stos %rax , %es : ( %rdi )', 'mov %rdx , %rdi', 'mov 0x ( %rsp ) , %rsi', 'callq 0x', 'lea 0x ( %r14 , %r12 , 1 ) , %rax', 'movabs $0x , %rsi', 'mov %rsi , ( %rax )', 'movl $0x , 0x ( %rax )', 'movb $0x , 0x ( %rax )', 'movl $0x , ( %r14 )', 'movl $0x , 0x ( %r14 )', 'mov %ebp , 0x ( %r14 )', 'movslq 0x ( %r13 ) , %rax', 'mov 0x ( %r13 ) , %rbp', 'mov %eax , 0x ( %rsp )', 'lea ( %rax , %rax , 2 ) , %rax', 'lea 0x ( , %rax , 8 ) , %r11', 'mov %r11 , %rdi', 'mov %r11 , 0x ( %rsp )', 'callq 0x', 'pop %r8', 'pop %r9', 'mov 0x ( %rsp ) , %r10d', 'mov 0x ( %rsp ) , %r11', 'test %r10d , %r10d', 'jle 0x', 'lea -0x ( %r10 ) , %ecx', 'mov %rax , %rdx', 'xor %r12d , %r12d', 'xor %r13d , %r13d', 'lea ( %rcx , %rcx , 2 ) , %rcx', 'lea 0x ( %rbp , %rcx , 8 ) , %rsi', 'jmp 0x', 'movl $0x , 0x ( %rdx )', 'mov 0x ( %rbp ) , %rcx', 'cmp $0x , %rcx', 'ja 0x', 'mov 0x ( %rbp ) , %rcx', 'cmp %r13 , %rcx', 'jbe 0x', 'movq $0x , 0x ( %rbp )', 'mov %rcx , %r13', 'lea 0x ( %r12 ) , %r8', 'lea -0x ( %rcx ) , %rdi', 'cmp %rcx , %r8', 'cmovb %rdi , %r12', 'add $0x , %rbp', 'add $0x , %rdx', 'cmp %rbp , %rsi', 'je 0x', 'mov 0x ( %rbp ) , %rdi', 'lea 0x ( %rdi ) , %rcx', 'sub 0x ( %rbp ) , %rcx', 'movl $0x , ( %rdx )', 'mov 0x ( %rbp ) , %rdi', 'mov %edi , 0x ( %rdx )', 'mov 0x ( %rbp ) , %rdi', 'mov %ecx , 0x ( %rdx )', 'shr $0x , %rcx', 'shr $0x , %rdi', 'mov %ecx , 0x ( %rdx )', 'mov %edi , 0x ( %rdx )', 'mov 0x ( %rbp ) , %edi', 'test %edi , %edi', 'je 0x', 'add $0x , %rbp', 'movl $0x , 0x ( %rdx )', 'add $0x , %rdx', 'cmp %rbp , %rsi', 'jne 0x', 'mov 0x ( %rip ) , %rdx', 'testb $0x , 0x ( %rdx )', 'jne 0x', 'mov 0x ( %rsp ) , %ebp', 'test %ebp , %ebp', 'jne 0x', 'mov 0x ( %rsp ) , %rbx', 'mov %rbx , %rdi', 'callq 0x', 'test %eax , %eax', 'js 0x', 'mov $0x , %eax', 'pushq  ...
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int multiboot_x86_probe(const char *, off_t);
# func-return-type:int
# func-name:multiboot_x86_probe
# func-filename:kexec-multiboot-x86.c
# func-disassembly:['push %r12', 'mov %rdi , %r12', 'push %rbp', 'push %rbx', 'mov %rsi , %rbx', 'callq 0x', 'mov %eax , %ebp', 'test %eax , %eax', 'js 0x', 'cmp $0x , %rbx', 'jle 0x', 'lea 0x ( %rip ) , %rax', 'mov $0x , %ecx', 'mov %r12 , %rsi', 'mov $0x , %ebx', 'mov %rax , %rdi', 'rep movsq %ds : ( %rsi ) , %es : ( %rdi )', 'lea 0x ( %rip ) , %rax', 'sub $0x , %ebx', 'shr $0x , %ebx', 'lea 0x ( %rax ) , %rdx', 'lea ( %rdx , %rbx , 4 ) , %rcx', 'cmpl $0x , ( %rax )', 'mov %rax , %rsi', 'jne 0x', 'mov 0x ( %rax ) , %edx', 'mov 0x ( %rax ) , %edi', 'add %edx , %edi', 'cmp $0x , %edi', 'jne 0x', 'mov %rax , 0x ( %rip )', 'test $0x , %edx', 'jne 0x', 'test $0x , %edx', 'jne 0x', 'xor %ebp , %ebp', 'and $0x , %edx', 'je 0x', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %edx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov %ebp , %eax', 'pop %rbx', 'pop %rbp', 'pop %r12', 'retq', 'xchg %ax , %ax', 'movslq %ebx , %rdx', 'mov $0x , %ecx', 'mov %r12 , %rsi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'cmp $0x , %ebx', 'jle 0x', 'sub $0x , %ebx', 'jmpq 0x', 'nopl 0x ( %rax )', 'add $0x , %rax', 'cmp %rax , %rcx', 'jne 0x', 'mov %rsi , 0x ( %rip )', 'mov $0x , %ebp', 'jmp 0x', 'mov $0x , %ebp', 'jmp 0x', 'mov $0x , %edx', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'mov $0x , %ebp', 'callq 0x', 'jmp 0x', 'mov $0x , %edx', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'mov $0x , %ebp', 'callq 0x', 'jmpq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:void multiboot_x86_usage(void);
# func-return-type:void
# func-name:multiboot_x86_usage
# func-filename:kexec-multiboot-x86.c
# func-disassembly:['sub $0x , %rsp', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'lea 0x ( %rip ) , %rdi', 'add $0x , %rsp', 'jmpq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int nbi_load(int, char **, const char *, off_t, struct kexec_info *);
# func-return-type:int
# func-name:nbi_load
# func-filename:kexec-nbi.c
# func-disassembly:['push %r15', 'push %r14', 'mov %edi , %r14d', 'push %r13', 'mov %rsi , %r13', 'push %r12', 'lea 0x ( %rip ) , %r12', 'push %rbp', 'push %rbx', 'mov %rdx , %rbx', 'sub $0x , %rsp', 'mov %r8 , 0x ( %rsp )', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'nopl 0x ( %rax )', 'xor %r8d , %r8d', 'mov %r12 , %rcx', 'lea 0x ( %rip ) , %rdx', 'mov %r13 , %rsi', 'mov %r14d , %edi', 'callq 0x', 'cmp $0x , %eax', 'jne 0x', 'movdqu ( %rbx ) , %xmm0', 'mov 0x ( %rsp ) , %rdi', 'mov $0x , %edx', 'mov %rbx , %rsi', 'mov $0x , %r8d', 'mov $0x , %r13d', 'movaps %xmm0 , 0x ( %rsp )', 'movdqa 0x ( %rsp ) , %xmm1', 'movzwl 0x ( %rsp ) , %eax', 'pextrw $0x , %xmm1 , %r15d', 'shl $0x , %r15d', 'add %eax , %r15d', 'movslq %r15d , %rcx', 'callq 0x', 'mov 0x ( %rsp ) , %rax', 'lea 0x ( %r15 ) , %r11d', 'shr $0x , %rax', 'mov %eax , %r14d', 'mov %rax , 0x ( %rsp )', 'and $0x , %eax', 'shr $0x , %r14d', 'and $0x , %r14d', 'add %eax , %r14d', 'shl $0x , %r14d', 'jmp 0x', 'nopl 0x ( %rax , %rax , 1 )', 'shr $0x , %rcx', 'mov %rcx , %r15', 'mov %rdx , %r11', 'mov %edx , %ebp', 'mov 0x ( %rsp ) , %rdi', 'lea ( %rbx , %r13 , 1 ) , %rsi', 'shr $0x , %r11', 'mov %r15d , %ecx', 'mov %rbp , %rdx', 'add %rbp , %r13', 'mov %r11 , %r8', 'mov %r11 , 0x ( %rsp )', 'callq 0x', 'mov 0x ( %rsp ) , %r11', 'add %r15d , %r11d', 'and $0x , %r12d', 'jne 0x', 'mov ( %rbx , %r14 , 1 ) , %rcx', 'mov 0x ( %rbx , %r14 , 1 ) , %rdx', 'mov %ecx , %esi', 'mov %ecx , %eax', 'mov %rcx , %r12', 'shr $0x , %sil', 'and $0x , %eax', 'shr $0x , %r12', 'movzbl %sil , %esi', 'add %esi , %eax', 'shl $0x , %eax', 'cltq', 'add %rax , %r14', 'mov %r12d , %eax', 'and $0x , %eax', 'je 0x', 'cmp $0x , %al', 'je 0x', 'cmp $0x , %al', 'jne 0x', 'shr $0x , %rcx', 'sub %ecx , %r15d', 'jmp 0x', 'nopl 0x ( %rax , %rax , 1 )', 'shr $0x , %rcx', 'lea ( %r11 , %rcx , 1 ) , %r15d', 'jmpq 0x', 'nopl ( %rax )', 'mov 0x ( %rsp ) , %rbp', 'mov 0x ( %rsp ) , %eax', 'lea 0x ( %rsp ) , %rbx', 'add $0x , %rbp', 'test %eax , %eax', 'js 0x', 'mov %rbx , %rdx', 'mov $0x , %ecx', 'lea 0x ( %rip ) , %rsi', 'mov %rbp , %rdi', 'callq 0x', 'mov %rbx , %rdx', 'mov $0x , %ecx', 'mov %rbp , %rdi', 'movdqa 0x ( %rsp ) , %xmm2', 'lea 0x ( %rip ) , %rsi', 'lea 0x ( %rsp ) , %rbx', 'pextrw $0x , %xmm2 , %eax', 'mov %ax , 0x ( %rsp )', 'pextrw $0x , %xmm2 , %eax', 'mov %ax , 0x ( %rsp )', 'callq 0x', 'mov $0x , %ecx', 'mov %rbx , %rdx', 'mov %rbp , %rdi', 'lea 0x ( %rip ) , %rsi', 'callq 0x', 'lea 0x ( %rip ) , %rsi', 'mov %rbp , %rdi', 'callq 0x', 'mov $0x , %ecx', 'mov %rbx , %rdx', 'mov %rbp , %rdi', 'lea 0x ( %rip ) , %rsi', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'xor %eax , %eax', 'mov 0x ( %rsp ) , %rdi', 'xor %fs : 0x , %rdi', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'nopl 0x ( %rax )', 'mov $0x , %edx', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'mov %r11d , 0x ( %rsp )', 'callq 0x', 'mov 0x ( %rsp ) , %r11d', 'jmpq 0x', 'nop', 'mov %rbx , %rdx', 'mov %rbp , %rdi', 'mov $0x , %ecx', 'lea 0x ( %rip ) , %rsi', 'callq 0x', 'mov 0x ( %rsp ) , %rax', 'mov %rbx , %rdx', 'mov %rbp , %rdi', 'mov $0x , %ecx', 'lea 0x ( %rip ) , %rsi', 'shr $0x , %rax', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'jmpq 0x', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int nbi_probe(const char *, off_t);
# func-return-type:int
# func-name:nbi_probe
# func-filename:kexec-nbi.c
# func-disassembly:['sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'cmp $0x , %rsi', 'jle 0x', 'mov ( %rdi ) , %rax', 'mov 0x ( %rdi ) , %rdx', 'mov %rax , ( %rsp )', 'mov %rdx , 0x ( %rsp )', 'cmp $0x , %eax', 'jne 0x', 'shr $0x , %rax', 'mov %rax , %rcx', 'and $0x , %eax', 'cmp $0x , %eax', 'jne 0x', 'mov %ecx , %edx', 'shr $0x , %edx', 'and $0x , %edx', 'test $0x , %ecx', 'jne 0x', 'add %eax , %edx', 'shl $0x , %edx', 'jmp 0x', 'xchg %ax , %ax', 'mov %eax , %ecx', 'shr $0x , %rax', 'shr $0x , %cl', 'lea 0x ( , %rcx , 4 ) , %rcx', 'and $0x , %ecx', 'add %rcx , %rdx', 'test $0x , %al', 'jne 0x', 'mov %eax , %ecx', 'and $0x , %ecx', 'cmp $0x , %cl', 'je 0x', 'cmp $0x , %rdx', 'jg 0x', 'test $0x , %al', 'jne 0x', 'mov ( %rdi , %rdx , 1 ) , %rax', 'mov %eax , %ecx', 'and $0x , %ecx', 'cmp $0x , %cl', 'je 0x', 'mov $0x , %eax', 'mov 0x ( %rsp ) , %rsi', 'xor %fs : 0x , %rsi', 'jne 0x', 'add $0x , %rsp', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'xor %eax , %eax', 'jmp 0x', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:void nbi_usage(void);
# func-return-type:void
# func-name:nbi_usage
# func-filename:kexec-nbi.c
# func-disassembly:['mov $0x , %edi', 'jmpq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int efi_map_added(void);
# func-return-type:int
# func-name:efi_map_added
# func-filename:kexec-x86-common.c
# func-disassembly:['push %rbp', 'lea 0x ( %rip ) , %rsi', 'lea 0x ( %rip ) , %rdi', 'push %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'callq 0x', 'mov %rax , %rbx', 'xor %eax , %eax', 'test %rbx , %rbx', 'je 0x', 'mov %rsp , %rbp', 'mov %rbx , %rdx', 'mov $0x , %esi', 'mov %rbp , %rdi', 'callq 0x', 'mov %rbx , %rdi', 'callq 0x', 'lea 0x ( %rip ) , %rsi', 'mov %rbp , %rdi', 'callq 0x', 'test %rax , %rax', 'setne %al', 'movzbl %al , %eax', 'mov 0x ( %rsp ) , %rcx', 'xor %fs : 0x , %rcx', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int get_memory_ranges(struct memory_range **, int *, unsigned long);
# func-return-type:int
# func-name:get_memory_ranges
# func-filename:kexec-x86-common.c
# func-disassembly:['push %r13', 'push %r12', 'mov %rdx , %r12', 'push %rbp', 'mov %rdi , %rbp', 'push %rbx', 'mov %rsi , %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'callq 0x', 'test %eax , %eax', 'jne 0x', 'callq 0x', 'test %eax , %eax', 'je 0x', 'callq 0x', 'mov %rbx , %rsi', 'test %eax , %eax', 'jne 0x', 'mov %rbp , %rdi', 'callq 0x', 'mov %eax , %r13d', 'test %r13d , %r13d', 'jne 0x', 'mov ( %rbx ) , %edx', 'test %edx , %edx', 'jle 0x', 'mov 0x ( %rbp ) , %rax', 'sub $0x , %edx', 'lea ( %rdx , %rdx , 2 ) , %rdx', 'lea 0x ( %rax , %rdx , 8 ) , %rdx', 'nop', 'mov 0x ( %rax ) , %ecx', 'test %ecx , %ecx', 'jne 0x', 'cmpq $0x , ( %rax )', 'jbe 0x', 'add $0x , %rax', 'cmp %rdx , %rax', 'jne 0x', 'and $0x , %r12d', 'cmp $0x , %r12', 'je 0x', 'mov ( %rbx ) , %edx', 'mov 0x ( %rbp ) , %rsi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rsp ) , %rcx', 'xor %fs : 0x , %rcx', 'mov %r13d , %eax', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'retq', 'nopl 0x ( %rax , %rax , 1 )', 'mov 0x ( %rbp ) , %rdi', 'callq 0x', 'mov %eax , %r13d', 'jmpq 0x', 'nopl 0x ( %rax )', 'lea 0x ( %rsp ) , %rsi', 'lea 0x ( %rsp ) , %rdi', 'callq 0x', 'test %eax , %eax', 'jne 0x', 'mov 0x ( %rsp ) , %rax', 'cmp 0x ( %rip ) , %rax', 'jbe 0x', 'mov %rax , 0x ( %rip )', 'mov 0x ( %rsp ) , %rax', 'cmp 0x ( %rip ) , %rax', 'jae 0x', 'mov %rax , 0x ( %rip )', 'jmpq 0x', 'nopw 0x ( %rax , %rax , 1 )', 'movq $0x , ( %rax )', 'jmpq 0x', 'nopl 0x ( %rax )', 'callq 0x', 'test %eax , %eax', 'je 0x', 'lea 0x ( %rsp ) , %rsi', 'lea 0x ( %rip ) , %rdi', 'movq $0x , 0x ( %rsp )', 'callq 0x', 'test %eax , %eax', 'jne 0x', 'lea 0x ( %rip ) , %rax', 'mov %rax , 0x ( %rbp )', 'mov 0x ( %rsp ) , %rax', 'mov %eax , ( %rbx )', 'mov 0x ( %rbp ) , %rdi', 'mov %rbx , %rsi', 'callq 0x', 'mov %eax , %r13d', 'jmpq 0x', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %edx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov %rbx , %rsi', 'mov %rbp , %rdi', 'callq 0x', 'mov %eax , %r13d', 'test %eax , %eax', 'jne 0x', 'jmp 0x', 'mov $0x , %edx', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'mov $0x , %r13d', 'callq 0x', 'jmpq 0x', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:static int fixup_memory_ranges(int *, struct memory_range **);
# func-return-type:static int
# func-name:fixup_memory_ranges
# func-filename:kexec-x86-common.c
# ...
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/kexec
# ----------
# func-signature:int main(int, char **);
# func-return-type:int
# func-name:main
# func-filename:vmcore-dmesg.c
# func-disassembly:['push %r15', 'push %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'cmp $0x , %edi', 'je 0x', 'mov ( %rsi ) , %rcx', 'mov 0x ( %rip ) , %rdi', 'lea 0x ( %rip ) , %rdx', 'mov $0x , %esi', 'callq 0x', 'mov $0x , %eax', 'mov 0x ( %rsp ) , %rbx', 'xor %fs : 0x , %rbx', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'mov 0x ( %rsi ) , %rdi', 'xor %eax , %eax', 'xor %esi , %esi', 'mov %rdi , 0x ( %rip )', 'callq 0x', 'mov %eax , %ebx', 'test %eax , %eax', 'js 0x', 'xor %ecx , %ecx', 'mov $0x , %edx', 'lea 0x ( %rip ) , %rsi', 'mov %eax , %edi', 'callq 0x', 'cmp $0x , %rax', 'jne 0x', 'cmpl $0x , 0x ( %rip )', 'jne 0x', 'cmpb $0x , 0x ( %rip )', 'jne 0x', 'movzbl 0x ( %rip ) , %ecx', 'lea -0x ( %rcx ) , %eax', 'cmp $0x , %al', 'ja 0x', 'movzbl 0x ( %rip ) , %eax', 'lea -0x ( %rax ) , %edx', 'cmp $0x , %dl', 'ja 0x', 'sub $0x , %cl', 'lea 0x ( %rsp ) , %rsi', 'mov $0x , %ecx', 'je 0x', 'mov $0x , %edx', 'mov %ebx , %edi', 'callq 0x', 'cmp $0x , %rax', 'jne 0x', 'mov 0x ( %rsp ) , %rax', 'cmpb $0x , 0x ( %rip )', 'movzwl 0x ( %rsp ) , %r14d', 'movzwl 0x ( %rsp ) , %r9d', 'movzwl 0x ( %rsp ) , %edx', 'mov 0x ( %rsp ) , %r15', 'mov %rax , 0x ( %rsp )', 'mov 0x ( %rsp ) , %eax', 'movzwl 0x ( %rsp ) , %r10d', 'movzwl 0x ( %rsp ) , %edi', 'movzwl 0x ( %rsp ) , %r11d', 'mov 0x ( %rsp ) , %r12d', 'mov 0x ( %rsp ) , %rsi', 'mov %eax , 0x ( %rsp )', 'mov 0x ( %rsp ) , %rbp', 'movzwl 0x ( %rsp ) , %eax', 'mov 0x ( %rsp ) , %r8', 'mov 0x ( %rsp ) , %ecx', 'movzwl 0x ( %rsp ) , %r13d', 'je 0x', 'rol $0x , %ax', 'rol $0x , %di', 'bswap %ecx', 'bswap %r8', 'rol $0x , %r14w', 'rol $0x , %r13w', 'bswap %rbp', 'bswap %rsi', 'rol $0x , %r11w', 'rol $0x , %dx', 'bswap %r12d', 'mov %r14w , 0x ( %rip )', 'rol $0x , %r10w', 'mov %r13w , 0x ( %rip )', 'rol $0x , %r9w', 'mov %ecx , 0x ( %rip )', 'mov %r8 , 0x ( %rip )', 'mov %rbp , 0x ( %rip )', 'mov %rsi , 0x ( %rip )', 'mov %r12d , 0x ( %rip )', 'mov %r11w , 0x ( %rip )', 'mov %ax , 0x ( %rip )', 'mov %di , 0x ( %rip )', 'mov %r10w , 0x ( %rip )', 'mov %dx , 0x ( %rip )', 'mov %r9w , 0x ( %rip )', 'cmp $0x , %ecx', 'jne 0x', 'cmp $0x , %ax', 'jne 0x', 'movzwl %di , %r13d', 'mov $0x , %esi', 'mov %r13 , %rdi', 'imul $0x , %r13 , %r14', 'callq 0x', 'mov %rax , %r12', 'test %rax , %rax', 'je 0x', 'mov $0x , %esi', 'mov %r13 , %rdi', 'callq 0x', 'mov %rax , 0x ( %rip )', 'test %rax , %rax', 'je 0x', 'mov %rbp , %rcx', 'mov %r14 , %rdx', 'mov %r12 , %rsi', 'mov %ebx , %edi', 'callq 0x', 'test %rax , %rax', 'js 0x', 'cmp %rax , %r14', 'jne 0x', 'cmpw $0x , 0x ( %rip )', 'je 0x', 'movzbl 0x ( %rip ) , %edi', 'mov %r12 , %rdx', 'mov 0x ( %rip ) , %rax', 'xor %esi , %esi', 'jmp 0x', 'bswap %rcx', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'bswap %rcx', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'bswap %rcx', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'bswap %rcx', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'bswap %rcx', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'bswap %rcx', 'mov %rcx , 0x ( %rax )', 'add $0x , %rsi', 'add $0x , %rdx', 'add $0x , %rax', 'movzwl 0x ( %rip ) , %ecx', 'cmp %rcx , %rsi', 'jge 0x', 'mov ( %rdx ) , %ecx', 'cmp $0x , %dil', 'mov %ecx , %r8d', 'bswap %r8d', 'cmovne %r8d , %ecx', 'mov %ecx , ( %rax )', 'cmpb $0x , 0x ( %rip )', 'mov 0x ( %rdx ) , %ecx', 'je 0x', 'bswap %ecx', 'mov %ecx , 0x ( %rax )', 'movzbl 0x ( %rip ) , %edi', 'mov 0x ( %rdx ) , %rcx', 'cmp $0x , %dil', 'jne 0x', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'mov %rcx , 0x ( %rax )', 'mov 0x ( %rdx ) , %rcx', 'jmpq 0x', 'callq 0x', 'mov ( %rax ) , %edi', 'callq 0x', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %esi', 'mov 0x ( %rip ) , %rdi', 'mov %rax  ...
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/vmcore-dmesg
# ----------
# func-signature:static void dump_dmesg_structured(int);
# func-return-type:static void
# func-name:dump_dmesg_structured
# func-filename:vmcore-dmesg.c
# func-disassembly:['push %r15', 'push %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov %edi , 0x ( %rsp )', 'mov 0x ( %rip ) , %rdi', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'test %rdi , %rdi', 'je 0x', 'cmpq $0x , 0x ( %rip )', 'je 0x', 'cmpq $0x , 0x ( %rip )', 'je 0x', 'cmpq $0x , 0x ( %rip )', 'je 0x', 'cmpq $0x , 0x ( %rip )', 'je 0x', 'cmpq $0x , 0x ( %rip )', 'je 0x', 'cmpw $0x , 0x ( %rip )', 'je 0x', 'cmpw $0x , 0x ( %rip )', 'je 0x', 'callq 0x', 'mov 0x ( %rsp ) , %r15d', 'mov %rax , %rsi', 'mov %r15d , %edi', 'callq 0x', 'mov 0x ( %rip ) , %rdi', 'mov %rax , %rbx', 'callq 0x', 'mov %r15d , %edi', 'mov %rax , %rsi', 'callq 0x', 'mov 0x ( %rip ) , %rdi', 'mov %eax , %r14d', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov %r15d , %edi', 'mov %rax , %rsi', 'callq 0x', 'mov %rbx , %rdi', 'mov %eax , %r15d', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov 0x ( %rip ) , %rdx', 'mov $0x , %edi', 'mov %rax , 0x ( %rsp )', 'mov %rdx , %rsi', 'mov %rdx , 0x ( %rsp )', 'callq 0x', 'mov 0x ( %rsp ) , %rdx', 'test %rax , %rax', 'mov %rax , 0x ( %rsp )', 'je 0x', 'xor %ebx , %ebx', 'cmp %r15d , %r14d', 'je 0x', 'lea 0x ( %rsp ) , %r12', 'nopw 0x ( %rax , %rax , 1 )', 'mov 0x ( %rsp ) , %ebp', 'mov 0x ( %rsp ) , %rsi', 'add 0x ( %rsp ) , %rbp', 'mov 0x ( %rsp ) , %edi', 'mov %rbp , %rcx', 'callq 0x', 'mov 0x ( %rip ) , %r13', 'cmp %rax , %r13', 'jne 0x', 'mov 0x ( %rip ) , %eax', 'mov 0x ( %rsp ) , %rcx', 'cmpb $0x , 0x ( %rip )', 'mov ( %rcx , %rax , 1 ) , %rdi', 'je 0x', 'bswap %rdi', 'mov $0x , %esi', 'callq 0x', 'mov $0x , %esi', 'mov %rdx , %rdi', 'mov %rax , %r13', 'callq 0x', 'mov %ebx , %edi', 'mov $0x , %esi', 'mov %r13 , %r8', 'mov %rax , %r9', 'add %r12 , %rdi', 'xor %eax , %eax', 'mov $0x , %rdx', 'lea 0x ( %rip ) , %rcx', 'callq 0x', 'mov 0x ( %rsp ) , %rsi', 'cmpb $0x , 0x ( %rip )', 'lea ( %rax , %rbx , 1 ) , %r14d', 'movzwl 0x ( %rip ) , %eax', 'movzwl ( %rsi , %rax , 1 ) , %ebx', 'je 0x', 'rol $0x , %bx', 'movzwl %bx , %r15d', 'mov $0x , %edi', 'mov %r15 , %rsi', 'callq 0x', 'mov %rax , %r13', 'test %rax , %rax', 'je 0x', 'mov 0x ( %rip ) , %rcx', 'mov 0x ( %rsp ) , %edi', 'mov %r15 , %rdx', 'mov %rax , %rsi', 'add %rbp , %rcx', 'callq 0x', 'cmp %rax , %r15', 'jne 0x', 'movzwl %bx , %ebx', 'test %ebx , %ebx', 'je 0x', 'callq 0x', 'mov %r13 , %rbp', 'mov %rax , %r15', 'lea -0x ( %rbx ) , %eax', 'lea 0x ( %r13 , %rax , 1 ) , %rbx', 'jmp 0x', 'nopl 0x ( %rax )', 'mov %r14d , %eax', 'add $0x , %r14d', 'mov %dl , 0x ( %rsp , %rax , 1 )', 'cmp $0x , %r14d', 'ja 0x', 'add $0x , %rbp', 'cmp %rbp , %rbx', 'je 0x', 'movzbl 0x ( %rbp ) , %edx', 'mov ( %r15 ) , %rax', 'mov %rdx , %r8', 'testw $0x , ( %rax , %rdx , 2 )', 'jne 0x', 'mov %r14d , %edi', 'mov $0x , %esi', 'xor %eax , %eax', 'add $0x , %r14d', 'add %r12 , %rdi', 'lea 0x ( %rip ) , %rcx', 'mov $0x , %rdx', 'callq 0x', 'cmp $0x , %r14d', 'jbe 0x', 'mov %r14d , %esi', 'mov %r12 , %rdi', 'add $0x , %rbp', 'xor %r14d , %r14d', 'callq 0x', 'cmp %rbp , %rbx', 'jne 0x', 'mov %r14d , %r9d', 'mov %r13 , %rdi', 'lea 0x ( %r14 ) , %ebx', 'movb $0x , 0x ( %rsp , %r9 , 1 )', 'callq 0x', 'movzwl 0x ( %rip ) , %eax', 'mov 0x ( %rsp ) , %rcx', 'cmpb $0x , 0x ( %rip )', 'movzwl ( %rcx , %rax , 1 ) , %eax', 'je 0x', 'rol $0x , %ax', 'movzwl %ax , %edx', 'add 0x ( %rsp ) , %edx', 'test %ax , %ax', 'mov $0x , %eax', 'cmove %eax , %edx', 'mov %edx , 0x ( %rsp )', 'cmp 0x ( %rsp ) , %edx', 'je 0x', 'mov 0x ( %rip ) , %rdx', 'jmpq 0x', 'mov 0x ( %rsp ) , %rdi', 'callq 0x', 'test %ebx , %ebx', 'je 0x', 'mov %ebx , %esi', 'mov %r12 , %rdi', 'callq 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'mov 0x ( %rsp ) , %rdi', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'jmpq 0x', 'callq 0x', 'mov ( %rax ) , %edi', 'callq 0x', 'mov 0x ...
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/vmcore-dmesg
# ----------
# func-signature:static void scan_vmcoreinfo(char *, size_t);
# func-return-type:static void
# func-name:scan_vmcoreinfo
# func-filename:vmcore-dmesg.c
# func-disassembly:['push %r15', 'push %r14', 'push %r13', 'mov %rdi , %r13', 'push %r12', 'push %rbp', 'push %rbx', 'lea -0x ( %rdi , %rsi , 1 ) , %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'cmp %rbx , %rdi', 'ja 0x', 'nopl ( %rax )', 'mov %r13 , %r14', 'nopl 0x ( %rax , %rax , 1 )', 'cmpb $0x , ( %r14 )', 'je 0x', 'add $0x , %r14', 'cmp %r14 , %rbx', 'jae 0x', 'mov %rbx , %r8', 'mov $0x , %eax', 'lea 0x ( %rsp ) , %r10', 'mov %r13 , %rsi', 'sub %r13 , %r8', 'mov $0x , %ecx', 'mov %r10 , %rdi', 'add $0x , %r8', 'cmp $0x , %r8', 'cmovbe %r8 , %rax', 'mov %rax , %r14', 'mov %rax , %rdx', 'callq 0x', 'lea 0x ( %r14 ) , %rbp', 'movb $0x , 0x ( %rsp )', 'movb $0x , 0x ( %rsp , %rbp , 1 )', 'add %rax , %r14', 'mov %rax , %r13', 'movb $0x , ( %r14 )', 'cmp $0x , %rbp', 'jbe 0x', 'movabs $0x , %rax', 'cmp %rax , 0x ( %r13 )', 'je 0x', 'lea 0x ( %rip ) , %r12', 'mov $0x , %r15d', 'jmp 0x', 'nopl 0x ( %rax )', 'mov 0x ( %r12 ) , %r15', 'cmp %rbp , %r15', 'jae 0x', 'mov ( %r12 ) , %rdi', 'mov %r15 , %rdx', 'mov %r13 , %rsi', 'callq 0x', 'test %eax , %eax', 'jne 0x', 'mov $0x , %edx', 'lea 0x ( %r13 , %r15 , 1 ) , %rdi', 'xor %esi , %esi', 'callq 0x', 'mov 0x ( %r12 ) , %rdx', 'mov %rax , ( %rdx )', 'add $0x , %r12', 'lea 0x ( %rip ) , %rax', 'cmp %rax , %r12', 'jne 0x', 'movabs $0x , %rax', 'cmp %rax , 0x ( %r13 )', 'je 0x', 'movabs $0x , %rdx', 'xor 0x ( %r13 ) , %rdx', 'movabs $0x , %rax', 'xor 0x ( %r13 ) , %rax', 'or %rax , %rdx', 'jne 0x', 'cmpb $0x , 0x ( %r13 )', 'jne 0x', 'lea 0x ( %r13 ) , %rdi', 'mov $0x , %edx', 'xor %esi , %esi', 'callq 0x', 'mov %rax , 0x ( %rip )', 'nopl 0x ( %rax )', 'movabs $0x , %rax', 'xor 0x ( %r13 ) , %rax', 'movabs $0x , %rdx', 'xor 0x ( %r13 ) , %rdx', 'or %rdx , %rax', 'jne 0x', 'cmpl $0x , 0x ( %r13 )', 'jne 0x', 'lea 0x ( %r13 ) , %rdi', 'mov $0x , %edx', 'xor %esi , %esi', 'callq 0x', 'mov %rax , 0x ( %rip )', 'nopw 0x ( %rax , %rax , 1 )', 'movabs $0x , %rdx', 'xor 0x ( %r13 ) , %rdx', 'movabs $0x , %rax', 'xor 0x ( %r13 ) , %rax', 'or %rax , %rdx', 'jne 0x', 'movabs $0x , %rax', 'cmp %rax , 0x ( %r13 )', 'je 0x', 'movabs $0x , %rax', 'xor 0x ( %r13 ) , %rax', 'movabs $0x , %rdx', 'xor 0x ( %r13 ) , %rdx', 'or %rdx , %rax', 'jne 0x', 'lea 0x ( %r13 ) , %rdi', 'mov $0x , %edx', 'xor %esi , %esi', 'callq 0x', 'mov %ax , 0x ( %rip )', 'movabs $0x , %rdx', 'xor 0x ( %r13 ) , %rdx', 'movabs $0x , %rax', 'xor 0x ( %r13 ) , %rax', 'or %rax , %rdx', 'jne 0x', 'cmpl $0x , 0x ( %r13 )', 'je 0x', 'movabs $0x , %rax', 'xor 0x ( %r13 ) , %rax', 'movabs $0x , %rdx', 'xor 0x ( %r13 ) , %rdx', 'or %rdx , %rax', 'jne 0x', 'cmpl $0x , 0x ( %r13 )', 'je 0x', 'movabs $0x , %rdx', 'xor 0x ( %r13 ) , %rdx', 'movabs $0x , %rax', 'xor 0x ( %r13 ) , %rax', 'or %rax , %rdx', 'jne 0x', 'movabs $0x , %rax', 'cmp %rax , 0x ( %r13 )', 'je 0x', 'cmpb $0x , 0x ( %rsp )', 'jne 0x', 'lea 0x ( %r14 ) , %r13', 'cmp %r13 , %rbx', 'jae 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'nopl ( %rax )', 'cmp %r14 , %rbx', 'jb 0x', 'mov %r14 , %rbp', 'movb $0x , 0x ( %rsp )', 'sub %r13 , %rbp', 'add $0x , %rbp', 'jmpq 0x', 'nopl ( %rax )', 'cmpw $0x , 0x ( %r13 )', 'jne 0x', 'lea 0x ( %r13 ) , %rdi', 'mov $0x , %edx', 'xor %esi , %esi', 'callq 0x', 'mov %rax , 0x ( %rip )', 'jmpq 0x', 'nopl 0x ( %rax )', 'cmpw $0x , 0x ( %r13 )', 'jne 0x', 'lea -0x ( %rbp ) , %r10', 'mov $0x , %eax', 'lea 0x ( %r13 ) , %rsi', 'mov $0x , %ecx', 'cmp $0x , %r10', 'lea 0x ( %rip ) , %rdi', 'cmovbe %r10 , %rax', 'mov %rax , %rdx', 'mov %rax , %r12', 'callq 0x', 'lea 0x ( %rip ) , %rax', 'movb $0x , ( %rax , %r12 , 1 )', 'jmpq 0x', 'nopl ( %rax )', 'cmpw $0x , 0x ( %r13 )', 'jne 0x', 'cmpb $0x , 0x ( %r13 )', 'jne 0x', 'lea 0x ( %r13 ) , %rdi', 'mov $0x , %edx', 'xor %esi , %esi', 'callq 0x', 'mov %rax , 0x ( %rip )', 'jmpq 0x', 'nopl 0x ( %rax )', 'cmpw $0x , 0x ( %r13 )', 'jne 0x', 'cmpb $0x , 0x ...
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/vmcore-dmesg
# ----------
# func-signature:static void write_to_stdout(char *, unsigned int);
# func-return-type:static void
# func-name:write_to_stdout
# func-filename:vmcore-dmesg.c
# func-disassembly:['push %rbx', 'mov %esi , %ebx', 'mov %rdi , %rsi', 'mov $0x , %edi', 'mov %rbx , %rdx', 'callq 0x', 'cmp %rax , %rbx', 'jne 0x', 'pop %rbx', 'retq', 'callq 0x', 'mov ( %rax ) , %edi', 'callq 0x', 'mov 0x ( %rip ) , %rdi', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdx', 'mov %rax , %rcx', 'xor %eax , %eax', 'callq 0x', 'mov $0x , %edi', 'callq 0x']
# ubuntu-package-name:kexec-tools
# ubuntu-package-binary:/sbin/vmcore-dmesg
# ----------

# %%
with open('keepalived.pickle', 'rb') as f:
    loaded_obj = pickle.load(f)

#print(f'loaded_obj is {loaded_obj}')

for elem in loaded_obj:
    print(f'func-signature:{elem[0]}')
    print(f'func-return-type:{elem[1]}')
    print(f'func-name:{elem[2]}')
    print(f'func-filename:{elem[3]}')
    print(f'func-disassembly:{elem[4]}')
    print(f'ubuntu-package-name:{elem[5]}')
    print(f'ubuntu-package-binary:{elem[6]}')
    print("----------")
# Out:
# func-signature:size_t extract_content_length(const char *, size_t);
# func-return-type:unsigned long
# func-name:extract_content_length
# func-filename:html.c
# func-disassembly:['endbr64', 'push %rbp', 'mov %rsi , %rbp', 'lea 0x ( %rip ) , %rsi', 'push %rbx', 'mov %rdi , %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'callq 0x', 'test %rax , %rax', 'je 0x', 'add %rbp , %rbx', 'cmp %rbx , %rax', 'ja 0x', 'mov $0x , %edx', 'mov %rsp , %rsi', 'lea 0x ( %rax ) , %rdi', 'callq 0x', 'mov ( %rsp ) , %rdx', 'cmpb $0x , ( %rdx )', 'jne 0x', 'mov 0x ( %rsp ) , %rcx', 'xor %fs : 0x , %rcx', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'mov $0x , %rax', 'jmp 0x', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:int extract_status_code(const char *, size_t);
# func-return-type:int
# func-name:extract_status_code
# func-filename:html.c
# func-disassembly:['endbr64', 'push %rbx', 'add %rdi , %rsi', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'movzbl ( %rdi ) , %eax', 'cmp %rsi , %rdi', 'jb 0x', 'jmp 0x', 'nopw %cs : 0x ( %rax , %rax , 1 )', 'cmp $0x , %al', 'je 0x', 'add $0x , %rdi', 'movzbl ( %rdi ) , %eax', 'cmp %rdi , %rsi', 'je 0x', 'cmp $0x , %al', 'jne 0x', 'cmp $0x , %al', 'je 0x', 'xor %eax , %eax', 'mov 0x ( %rsp ) , %rcx', 'xor %fs : 0x , %rcx', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'retq', 'lea 0x ( %rdi ) , %rbx', 'cmp %rsi , %rbx', 'jae 0x', 'cmpb $0x , 0x ( %rdi )', 'je 0x', 'cmpb $0x , 0x ( %rdi )', 'jne 0x', 'add $0x , %rdi', 'mov %rsp , %rsi', 'mov $0x , %edx', 'callq 0x', 'cmp ( %rsp ) , %rbx', 'jne 0x', 'jmp 0x', 'xchg %ax , %ax', 'mov %rsi , %rdi', 'cmp $0x , %al', 'jne 0x', 'jmp 0x', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:int epilog(thread_ref_t);
# func-return-type:int
# func-name:epilog
# func-filename:http.c
# func-disassembly:['endbr64', 'sub $0x , %rsp', 'mov 0x ( %rdi ) , %rsi', 'add $0x , %rdi', 'callq 0x', 'xor %eax , %eax', 'add $0x , %rsp', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:int finalize(thread_ref_t);
# func-return-type:int
# func-name:finalize
# func-filename:http.c
# func-disassembly:['endbr64', 'push %r15', 'push %r14', 'push %r13', 'mov %rdi , %r13', 'push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov 0x ( %rdi ) , %r15', 'mov 0x ( %r15 ) , %rax', 'movzbl 0x ( %rax ) , %r12d', 'mov %r12 , %rdi', 'mov %r12 , %rbp', 'callq 0x', 'lea 0x ( %r15 ) , %rsi', 'mov %rax , %r14', 'mov 0x ( %r15 ) , %rax', 'mov %r14 , %rdi', 'callq 0x ( %rax )', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %eax', 'test %eax , %eax', 'jne 0x', 'mov 0x ( %r15 ) , %rax', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'mov 0x ( %rax ) , %rdx', 'xor %eax , %eax', 'callq 0x', 'test %bpl , %bpl', 'je 0x', 'lea -0x ( %rbp ) , %eax', 'mov %r14 , %rbx', 'lea 0x ( %rip ) , %rbp', 'lea 0x ( %r14 , %rax , 1 ) , %r12', 'nopw 0x ( %rax , %rax , 1 )', 'movzbl ( %rbx ) , %edx', 'mov %rbp , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'add $0x , %rbx', 'callq 0x', 'cmp %r12 , %rbx', 'jne 0x', 'mov 0x ( %r15 ) , %rdx', 'cmp $0x , %rdx', 'je 0x', 'mov 0x ( %r15 ) , %rcx', 'cmp %rcx , %rdx', 'jne 0x', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %r13 ) , %rsi', 'lea 0x ( %r13 ) , %rdi', 'callq 0x', 'mov %r14 , %rdi', 'callq 0x', 'add $0x , %rsp', 'xor %eax , %eax', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'xchg %ax , %ax', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'callq 0x', 'jmp 0x', 'nopl ( %rax )', 'mov $0x , %edi', 'callq 0x', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov %r14 , %rdi', 'xor %ecx , %ecx', 'mov %r12 , %rsi', 'mov 0x ( %rip ) , %rdx', 'callq 0x', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'jmpq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:int http_process_stream(SOCK *, int);
# func-return-type:int
# func-name:http_process_stream
# func-filename:http.c
# func-disassembly:['endbr64', 'push %r13', 'push %r12', 'push %rbp', 'mov %esi , %ebp', 'push %rbx', 'mov %rdi , %rbx', 'sub $0x , %rsp', 'mov 0x ( %rdi ) , %r12d', 'add %ebp , 0x ( %rdi )', 'add %r12d , %esi', 'cmpq $0x , 0x ( %rdi )', 'mov %esi , 0x ( %rdi )', 'je 0x', 'test %esi , %esi', 'je 0x', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %eax', 'test %eax , %eax', 'jne 0x', 'mov 0x ( %rbx ) , %rdx', 'cmp $0x , %rdx', 'je 0x', 'mov 0x ( %rbx ) , %rax', 'movslq %esi , %rsi', 'mov %rsi , %rcx', 'cmp %rax , %rdx', 'jle 0x', 'mov 0x ( %rbx ) , %rcx', 'sub %rax , %rdx', 'mov 0x ( %rcx ) , %rcx', 'cmp %rsi , %rdx', 'jl 0x', 'mov %rsi , %rdx', 'mov 0x ( %rbx ) , %rsi', 'lea 0x ( %rbx ) , %rdi', 'callq *%rcx', 'mov 0x ( %rbx ) , %rax', 'movslq 0x ( %rbx ) , %rcx', 'add %rcx , %rax', 'mov %rax , 0x ( %rbx )', 'movl $0x , 0x ( %rbx )', 'add $0x , %rsp', 'xor %eax , %eax', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'retq', 'nop', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %edi', 'test %edi , %edi', 'jne 0x', 'mov 0x ( %rbx ) , %r13', 'movslq %esi , %rsi', 'movslq %r12d , %r12', 'mov %r13 , %rdi', 'callq 0x', 'lea 0x ( %r13 , %r12 , 1 ) , %rdi', 'mov %rax , 0x ( %rbx )', 'test %rax , %rax', 'je 0x', 'sub %r13 , %rax', 'sub %r12 , %rax', 'mov %rax , %rsi', 'callq 0x', 'mov %rax , 0x ( %rbx )', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %esi', 'test %esi , %esi', 'jne 0x', 'mov 0x ( %rbx ) , %rsi', 'mov 0x ( %rbx ) , %rdi', 'mov 0x ( %rbx ) , %ebp', 'mov %rsi , %rax', 'sub %rdi , %rax', 'sub %eax , %ebp', 'je 0x', 'movslq %ebp , %rbp', 'mov %rbp , %r12', 'mov %rbp , %rdx', 'callq 0x', 'mov 0x ( %rbx ) , %rdx', 'cmp $0x , %rdx', 'je 0x', 'mov 0x ( %rbx ) , %rax', 'cmp %rax , %rdx', 'jle 0x', 'sub %rax , %rdx', 'mov 0x ( %rbx ) , %rcx', 'cmp %rbp , %rdx', 'cmovge %rbp , %rdx', 'mov 0x ( %rcx ) , %rcx', 'mov %rdx , %r12', 'mov 0x ( %rbx ) , %rsi', 'lea 0x ( %rbx ) , %rdi', 'mov %r12 , %rdx', 'callq *%rcx', 'mov 0x ( %rbx ) , %rax', 'add %rax , %rbp', 'mov %rbp , 0x ( %rbx )', 'jmpq 0x', 'nopl 0x ( %rax , %rax , 1 )', 'mov 0x ( %rbx ) , %edi', 'mov 0x ( %rbx ) , %rax', 'mov 0x ( %rbx ) , %rsi', 'sub %ebp , %edi', 'sub %rax , %rsi', 'movslq %edi , %rdi', 'sub %rdi , %rsi', 'add %rax , %rdi', 'callq 0x', 'mov 0x ( %rbx ) , %rsi', 'mov 0x ( %rbx ) , %rdi', 'mov 0x ( %rbx ) , %ebp', 'mov %rsi , %rax', 'sub %rdi , %rax', 'sub %eax , %ebp', 'je 0x', 'mov 0x ( %rip ) , %rax', 'movslq %ebp , %rbp', 'mov %rbp , %r12', 'mov 0x ( %rax ) , %ecx', 'test %ecx , %ecx', 'je 0x', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rbx ) , %rdi', 'mov 0x ( %rip ) , %rdx', 'xor %ecx , %ecx', 'mov %rbp , %rsi', 'callq 0x', 'mov 0x ( %rbx ) , %rsi', 'mov 0x ( %rbx ) , %rdi', 'jmpq 0x', 'nopl 0x ( %rax , %rax , 1 )', 'mov 0x ( %rip ) , %rdx', 'mov 0x ( %rdi ) , %rdi', 'movslq %ebp , %rsi', 'xor %ecx , %ecx', 'callq 0x', 'mov 0x ( %rbx ) , %rdx', 'mov 0x ( %rbx ) , %esi', 'cmp $0x , %rdx', 'jne 0x', 'mov 0x ( %rbx ) , %rax', 'movslq %esi , %rsi', 'mov 0x ( %rax ) , %rcx', 'jmpq 0x', 'nop', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rbx ) , %esi', 'mov %esi , %r12d', 'sub %ebp , %r12d', 'jmpq 0x', 'nopl ( %rax )', 'movslq %ebp , %r12', 'mov %r12 , %rsi', 'callq 0x', 'mov %rax , 0x ( %rbx )', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %edx', 'test %edx , %edx', 'jne 0x', 'movslq 0x ( %rbx ) , %rax', 'cmp $0x , %eax', 'jle 0x', 'mov 0x ( %rbx ) , %rdx', 'mov -0x ( %rdx , %rax , 1 ) , %eax', 'mov %eax , ( %rdx )', 'movl $0x , 0x ( %rbx )', 'jmpq 0x', 'nopl 0x ( %rax )', 'mov 0x ( %rbx ) , %edi', 'mov %r12 , %rsi', 'sub %ebp , %edi', 'movslq %edi , %rdi', 'add 0x ( %rbx ) , %rdi', 'callq 0x', 'jmp 0x', 'nopl 0x ( %rax )', 'mov 0x ( %rbx ) , %rax', 'mov 0x ( %rax ) , %rcx', 'jmpq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:int http_request_thread(thread_ref_t);
# func-return-type:int
# func-name:http_request_thread
# func-filename:http.c
# func-disassembly:['endbr64', 'push %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'cmpl $0x , 0x ( %rdi )', 'mov %rdi , %rbx', 'mov 0x ( %rdi ) , %r12', 'je 0x', 'mov $0x , %edi', 'callq 0x', 'mov %rax , %rbp', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %r14', 'test %r14 , %r14', 'je 0x', 'mov $0x , %edi', 'callq 0x', 'movb $0x , ( %rax )', 'mov %rax , %r13', 'mov 0x ( %rip ) , %rsi', 'lea 0x ( %rip ) , %rdx', 'mov 0x ( %rsi ) , %eax', 'mov %eax , %ecx', 'and $0x , %ecx', 'cmp $0x , %ecx', 'jne 0x', 'sub $0x , %eax', 'xor %ecx , %ecx', 'mov 0x ( %rsi ) , %r9', 'lea 0x ( %rip ) , %r8', 'cmp $0x , %eax', 'mov ( %rsi ) , %rax', 'setbe %cl', 'test %rax , %rax', 'je 0x', 'cmpl $0x , 0x ( %rax )', 'je 0x', 'push %r13', 'mov $0x , %esi', 'mov %rbp , %rdi', 'xor %eax , %eax', 'push %r14', 'push %rdx', 'mov $0x , %edx', 'push %rcx', 'mov $0x , %rcx', 'callq 0x', 'mov %r13 , %rdi', 'add $0x , %rsp', 'callq 0x', 'mov 0x ( %rip ) , %rax', 'mov %rbp , %rdi', 'mov 0x ( %rax ) , %ecx', 'test %ecx , %ecx', 'jne 0x', 'callq 0x', 'mov ( %r12 ) , %edi', 'xor %ecx , %ecx', 'mov %rbp , %rsi', 'mov %rax , %rdx', 'xor %r13d , %r13d', 'callq 0x', 'mov %rbp , %rdi', 'cmp $0x , %rax', 'setne %r13b', 'callq 0x', 'test %r13d , %r13d', 'je 0x', 'mov $0x , %edi', 'callq 0x', 'lea 0x ( %rip ) , %rdx', 'lea 0x ( %r12 ) , %rdi', 'mov %rax , 0x ( %r12 )', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %eax', 'lea ( %rax , %rax , 2 ) , %rax', 'shl $0x , %rax', 'add %rdx , %rax', 'mov %rax , 0x ( %r12 )', 'callq * ( %rax )', 'mov 0x ( %rip ) , %rax', 'mov ( %r12 ) , %ecx', 'movq $0x , 0x ( %r12 )', 'mov $0x , %r9d', 'mov 0x ( %rbx ) , %rdi', 'mov 0x ( %rax ) , %edx', 'mov 0x ( %rax ) , %r8d', 'test %edx , %edx', 'mov %r12 , %rdx', 'je 0x', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %r13d', 'callq 0x', 'pop %rbx', 'mov %r13d , %eax', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'retq', 'nopl 0x ( %rax )', 'callq 0x', 'mov 0x ( %r12 ) , %rdi', 'mov %rbp , %rsi', 'mov %rax , %rdx', 'callq 0x', 'mov %rbp , %rdi', 'mov %eax , %r13d', 'callq 0x', 'test %r13d , %r13d', 'jne 0x', 'mov 0x ( %rip ) , %rcx', 'mov 0x ( %rip ) , %rdi', 'lea 0x ( %rip ) , %rdx', 'xor %eax , %eax', 'mov $0x , %esi', 'movzwl 0x ( %rcx ) , %r8d', 'add $0x , %rcx', 'rol $0x , %r8w', 'movzwl %r8w , %r8d', 'callq 0x', 'mov 0x ( %rbx ) , %rsi', 'lea 0x ( %rbx ) , %rdi', 'movl $0x , 0x ( %rip )', 'callq 0x', 'pop %rbx', 'mov %r13d , %eax', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'lea -0x ( %rax ) , %edx', 'lea 0x ( %rip ) , %rcx', 'and $0x , %edx', 'lea 0x ( %rip ) , %rdx', 'cmovne %rcx , %rdx', 'jmpq 0x', 'nopl ( %rax )', 'mov $0x , %r13d', 'lea -0x ( %rip ) , %rsi', 'callq 0x', 'pop %rbx', 'mov %r13d , %eax', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'retq', 'xchg %ax , %ax', 'mov $0x , %edi', 'lea 0x ( %rax ) , %r14', 'callq 0x', 'mov $0x , %edx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %r8', 'mov %rax , %r13', 'mov 0x ( %rip ) , %rax', 'mov $0x , %rcx', 'mov %r13 , %rdi', 'movzwl 0x ( %rax ) , %r9d', 'xor %eax , %eax', 'rol $0x , %r9w', 'movzwl %r9w , %r9d', 'callq 0x', 'jmpq 0x', 'nopl ( %rax )', 'mov %r12 , %rsi', 'xor %r13d , %r13d', 'lea 0x ( %rdi ) , %rdi', 'movl $0x , 0x ( %rip )', 'callq 0x', 'pop %rbx', 'mov %r13d , %eax', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'retq', 'nopl ( %rax )', 'cmpq $0x , 0x ( %rsi )', 'lea 0x ( %rip ) , %rax', 'cmove %rax , %r8', 'jmpq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:static void free_all(thread_ref_t, thread_ref_t);
# func-return-type:static void
# func-name:free_all
# func-filename:http.c
# func-disassembly:['push %rbp', 'mov %rdi , %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov 0x ( %rsi ) , %rdi', 'test %rdi , %rdi', 'je 0x', 'mov %rsi , %rbx', 'callq 0x', 'movq $0x , 0x ( %rbx )', 'callq 0x', 'imul $0x , %rax , %rax', 'add %rdx , %rax', 'mov 0x ( %rip ) , %rdx', 'mov %rax , 0x ( %rdx )', 'mov 0x ( %rbp ) , %rdi', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'jmpq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:static void http_dump_header(char *, size_t);
# func-return-type:static void
# func-name:http_dump_header
# func-filename:http.c
# func-disassembly:['push %r12', 'xor %ecx , %ecx', 'mov %rdi , %r12', 'push %rbx', 'mov %rsi , %rbx', 'sub $0x , %rsp', 'mov 0x ( %rip ) , %rdx', 'callq 0x', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'add $0x , %rsp', 'mov %r12 , %rcx', 'mov %ebx , %edx', 'lea 0x ( %rip ) , %rsi', 'pop %rbx', 'mov $0x , %edi', 'xor %eax , %eax', 'pop %r12', 'jmpq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:static int http_read_thread(thread_ref_t);
# func-return-type:static int
# func-name:http_read_thread
# func-filename:http.c
# func-disassembly:['endbr64', 'push %r13', 'push %r12', 'push %rbp', 'cmpl $0x , 0x ( %rdi )', 'mov %rdi , %rbp', 'mov 0x ( %rdi ) , %r13', 'je 0x', 'movslq 0x ( %r13 ) , %rdi', 'mov $0x , %r12d', 'sub %edi , %r12d', 'movslq %r12d , %r12', 'test %r12 , %r12', 'jle 0x', 'add 0x ( %r13 ) , %rdi', 'xor %esi , %esi', 'mov %r12 , %rdx', 'callq 0x', 'mov 0x ( %rbp ) , %edi', 'movslq 0x ( %r13 ) , %rsi', 'mov %r12 , %rdx', 'add 0x ( %r13 ) , %rsi', 'callq 0x', 'test %rax , %rax', 'je 0x', 'cmp $0x , %rax', 'je 0x', 'mov %r13 , %rdi', 'mov %eax , %esi', 'callq 0x', 'mov 0x ( %rbp ) , %ecx', 'mov 0x ( %rbp ) , %rdi', 'mov %r13 , %rdx', 'mov 0x ( %rip ) , %rax', 'mov $0x , %r9d', 'lea -0x ( %rip ) , %rsi', 'mov 0x ( %rax ) , %r8d', 'callq 0x', 'pop %rbp', 'xor %eax , %eax', 'pop %r12', 'pop %r13', 'retq', 'mov %rbp , %rdi', 'callq 0x', 'pop %rbp', 'xor %eax , %eax', 'pop %r12', 'pop %r13', 'retq', 'mov $0x , %edx', 'mov $0x , %esi', 'mov 0x ( %rip ) , %rcx', 'lea 0x ( %rip ) , %rdi', 'mov $0x , %r12d', 'callq 0x', 'movslq 0x ( %r13 ) , %rdi', 'jmpq 0x', 'nop', 'mov 0x ( %rbp ) , %rsi', 'lea 0x ( %rbp ) , %rdi', 'movl $0x , 0x ( %rip )', 'callq 0x', 'pop %rbp', 'xor %eax , %eax', 'pop %r12', 'pop %r13', 'retq', 'nop', 'mov %r13 , %rsi', 'lea 0x ( %rdi ) , %rdi', 'movl $0x , 0x ( %rip )', 'callq 0x', 'pop %rbp', 'xor %eax , %eax', 'pop %r12', 'pop %r13', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:int tcp_connect_thread(thread_ref_t);
# func-return-type:int
# func-name:tcp_connect_thread
# func-filename:layer4.c
# func-disassembly:['endbr64', 'push %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'mov %rdi , %rbx', 'sub $0x , %rsp', 'mov 0x ( %rdi ) , %r12', 'mov $0x , %edi', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'mov 0x ( %rip ) , %rax', 'mov ( %rax ) , %rax', 'test %rax , %rax', 'je 0x', 'mov 0x ( %rax ) , %edi', 'mov $0x , %eax', 'cmp $0x , %edi', 'cmovne %eax , %edi', 'mov $0x , %edx', 'mov $0x , %esi', 'callq 0x', 'mov %eax , ( %r12 )', 'mov %eax , %ebp', 'cmp $0x , %eax', 'je 0x', 'lea 0x ( %rsp ) , %rcx', 'mov $0x , %r8d', 'mov $0x , %edx', 'mov %ebp , %edi', 'movabs $0x , %rax', 'mov $0x , %esi', 'mov 0x ( %rip ) , %r13', 'mov %rax , 0x ( %rsp )', 'callq 0x', 'test %eax , %eax', 'jne 0x', 'mov 0x ( %rip ) , %rcx', 'mov 0x ( %rcx ) , %esi', 'test %esi , %esi', 'jne 0x', 'mov 0x ( %r13 ) , %rax', 'lea 0x ( %r13 ) , %rsi', 'test %rax , %rax', 'je 0x', 'cmpl $0x , 0x ( %rax )', 'je 0x', 'pxor %xmm0 , %xmm0', 'mov $0x , %eax', 'lea 0x ( %rsp ) , %rdx', 'mov $0x , %edi', 'movaps %xmm0 , 0x ( %rsp )', 'lea 0x ( %rsp ) , %r14', 'mov %ax , 0x ( %rsp )', 'movzwl 0x ( %r13 ) , %eax', 'mov %ax , 0x ( %rsp )', 'callq 0x', 'mov $0x , %edx', 'mov %r14 , %rsi', 'mov %ebp , %edi', 'callq 0x', 'mov $0x , %edx', 'test %eax , %eax', 'je 0x', 'callq 0x', 'xor %edx , %edx', 'cmpl $0x , ( %rax )', 'sete %dl', 'mov 0x ( %rip ) , %rax', 'mov %edx , 0x ( %rax )', 'mov 0x ( %r12 ) , %eax', 'mov ( %r12 ) , %ecx', 'mov %eax , %edx', 'and $0x , %edx', 'cmp $0x , %edx', 'je 0x', 'test %eax , %eax', 'je 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'xor %eax , %eax', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'retq', 'nopl ( %rax )', 'add $0x , %rcx', 'mov $0x , %r8d', 'mov $0x , %edx', 'mov %ebp , %edi', 'mov $0x , %esi', 'callq 0x', 'test %eax , %eax', 'je 0x', 'callq 0x', 'mov ( %rax ) , %edi', 'callq 0x', 'mov 0x ( %rip ) , %rdi', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdx', 'mov %rax , %r8', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %ecx', 'xor %eax , %eax', 'callq 0x', 'xor %edx , %edx', 'jmpq 0x', 'nopl 0x ( %rax , %rax , 1 )', 'mov 0x ( %rip ) , %rdi', 'mov %ebp , %ecx', 'mov $0x , %esi', 'xor %eax , %eax', 'lea 0x ( %rip ) , %rdx', 'callq 0x', 'jmpq 0x', 'nopl 0x ( %rax )', 'mov 0x ( %rbx ) , %rdx', 'mov 0x ( %rbx ) , %rdi', 'mov $0x , %r9d', 'lea -0x ( %rip ) , %rsi', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %r8d', 'callq 0x', 'jmpq 0x', 'nopw 0x ( %rax , %rax , 1 )', 'mov %ecx , %edi', 'callq 0x', 'mov 0x ( %rbx ) , %rdi', 'callq 0x', 'jmpq 0x', 'nopl ( %rax )', 'movzwl 0x ( %r13 ) , %eax', 'pxor %xmm0 , %xmm0', 'mov $0x , %edx', 'lea 0x ( %rsp ) , %r14', 'movaps %xmm0 , 0x ( %rsp )', 'mov $0x , %edi', 'mov %dx , 0x ( %rsp )', 'lea 0x ( %rsp ) , %rdx', 'movq $0x , 0x ( %rsp )', 'movl $0x , 0x ( %rsp )', 'mov %ax , 0x ( %rsp )', 'callq 0x', 'mov $0x , %edx', 'mov %r14 , %rsi', 'mov %ebp , %edi', 'callq 0x', 'jmpq 0x', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:static int tcp_check_thread(thread_ref_t);
# func-return-type:static int
# func-name:tcp_check_thread
# func-filename:layer4.c
# func-disassembly:['endbr64', 'push %r12', 'push %rbp', 'mov %rdi , %rbp', 'sub $0x , %rsp', 'mov 0x ( %rdi ) , %r12', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'cmpl $0x , 0x ( %rdi )', 'je 0x', 'mov 0x ( %rdi ) , %edi', 'mov %rsp , %rcx', 'lea 0x ( %rsp ) , %r8', 'mov $0x , %edx', 'mov $0x , %esi', 'movl $0x , 0x ( %rsp )', 'callq 0x', 'test %eax , %eax', 'js 0x', 'mov ( %rsp ) , %eax', 'cmp $0x , %eax', 'je 0x', 'test %eax , %eax', 'jne 0x', 'mov 0x ( %rip ) , %rax', 'movl $0x , 0x ( %r12 )', 'mov 0x ( %rax ) , %edx', 'test %edx , %edx', 'jne 0x', 'lea 0x ( %rip ) , %rsi', 'xor %ecx , %ecx', 'mov %r12 , %rdx', 'movl $0x , 0x ( %r12 )', 'mov 0x ( %rbp ) , %rdi', 'callq 0x', 'mov %rbp , %rdi', 'callq 0x', 'mov $0x , %eax', 'mov 0x ( %rsp ) , %rsi', 'xor %fs : 0x , %rsi', 'jne 0x', 'add $0x , %rsp', 'pop %rbp', 'pop %r12', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'callq 0x', 'mov ( %rax ) , %ecx', 'test %ecx , %ecx', 'je 0x', 'mov %rbp , %rdi', 'callq 0x', 'movl $0x , 0x ( %r12 )', 'mov 0x ( %rbp ) , %rdi', 'callq 0x', 'mov $0x , %eax', 'jmp 0x', 'nopl 0x ( %rax , %rax , 1 )', 'callq 0x', 'movl $0x , 0x ( %r12 )', 'mov 0x ( %rbp ) , %rdi', 'callq 0x', 'mov $0x , %eax', 'jmp 0x', 'nopl 0x ( %rax )', 'mov 0x ( %rbp ) , %rax', 'mov 0x ( %rbp ) , %rdx', 'sub 0x ( %rip ) , %rax', 'sub 0x ( %rip ) , %rdx', 'jns 0x', 'sub $0x , %rax', 'add $0x , %rdx', 'imul $0x , %rax , %rax', 'mov 0x ( %rbp ) , %r10', 'mov 0x ( %rbp ) , %ecx', 'mov $0x , %r9d', 'mov 0x ( %rbp ) , %rdi', 'lea -0x ( %rip ) , %rsi', 'lea ( %rax , %rdx , 1 ) , %r8', 'mov %r10 , %rdx', 'callq 0x', 'mov $0x , %eax', 'movl $0x , 0x ( %r12 )', 'jmpq 0x', 'nopl 0x ( %rax )', 'mov %rbp , %rdi', 'callq 0x', 'test %al , %al', 'je 0x', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %eax', 'test %eax , %eax', 'je 0x', 'mov $0x , %eax', 'jmpq 0x', 'movl $0x , 0x ( %r12 )', 'jmpq 0x', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:list alloc_list_r(void (*)(void *), void (*)(FILE *, const void *));
# func-return-type:struct
# func-name:alloc_list_r
# func-filename:list.c
# func-disassembly:['endbr64', 'push %rbp', 'mov %rdi , %rbp', 'mov $0x , %edi', 'push %rbx', 'mov %rsi , %rbx', 'sub $0x , %rsp', 'callq 0x', 'mov %rbp , 0x ( %rax )', 'mov %rbx , 0x ( %rax )', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:list alloc_mlist_r(void (*)(void *), void (*)(FILE *, const void *), size_t);
# func-return-type:struct
# func-name:alloc_mlist_r
# func-filename:list.c
# func-disassembly:['endbr64', 'push %rbp', 'mov %rdi , %rbp', 'lea ( %rdx , %rdx , 4 ) , %rdi', 'push %rbx', 'shl $0x , %rdi', 'mov %rsi , %rbx', 'sub $0x , %rsp', 'callq 0x', 'mov %rbp , 0x ( %rax )', 'mov %rbx , 0x ( %rax )', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void dump_list(FILE *, const list);
# func-return-type:void
# func-name:dump_list
# func-filename:list.c
# func-disassembly:['endbr64', 'test %rsi , %rsi', 'je 0x', 'push %r12', 'mov %rdi , %r12', 'push %rbp', 'mov %rsi , %rbp', 'push %rbx', 'mov ( %rsi ) , %rbx', 'test %rbx , %rbx', 'je 0x', 'nopl 0x ( %rax , %rax , 1 )', 'mov 0x ( %rbp ) , %rax', 'test %rax , %rax', 'je 0x', 'mov 0x ( %rbx ) , %rsi', 'mov %r12 , %rdi', 'callq *%rax', 'mov ( %rbx ) , %rbx', 'test %rbx , %rbx', 'jne 0x', 'pop %rbx', 'pop %rbp', 'pop %r12', 'retq', 'nop', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void free_list_data_r(list, const void *);
# func-return-type:void
# func-name:free_list_data_r
# func-filename:list.c
# func-disassembly:['endbr64', 'mov %rsi , %rax', 'test %rdi , %rdi', 'je 0x', 'mov ( %rdi ) , %rsi', 'test %rsi , %rsi', 'jne 0x', 'jmp 0x', 'nopw %cs : 0x ( %rax , %rax , 1 )', 'mov ( %rsi ) , %rsi', 'test %rsi , %rsi', 'je 0x', 'cmp %rax , 0x ( %rsi )', 'jne 0x', 'jmpq 0x', 'nopl 0x ( %rax , %rax , 1 )', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void free_list_element_r(list, const element);
# func-return-type:void
# func-name:free_list_element_r
# func-filename:list.c
# func-disassembly:['push %rbp', 'mov %rsi , %rbp', 'push %rbx', 'mov %rdi , %rbx', 'sub $0x , %rsp', 'mov ( %rsi ) , %rax', 'cmp %rsi , ( %rdi )', 'je 0x', 'mov 0x ( %rsi ) , %rdx', 'mov %rax , ( %rdx )', 'mov 0x ( %rbp ) , %rax', 'cmp 0x ( %rbx ) , %rbp', 'je 0x', 'mov 0x ( %rbp ) , %rdx', 'mov %rax , 0x ( %rdx )', 'mov 0x ( %rbx ) , %rax', 'test %rax , %rax', 'je 0x', 'mov 0x ( %rbp ) , %rdi', 'callq *%rax', 'subl $0x , 0x ( %rbx )', 'add $0x , %rsp', 'mov %rbp , %rdi', 'pop %rbx', 'pop %rbp', 'jmpq 0x', 'xchg %ax , %ax', 'mov %rax , ( %rdi )', 'mov 0x ( %rbp ) , %rax', 'cmp 0x ( %rbx ) , %rbp', 'jne 0x', 'mov %rax , 0x ( %rbx )', 'jmp 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void free_list_element_simple(void *);
# func-return-type:void
# func-name:free_list_element_simple
# func-filename:list.c
# func-disassembly:['endbr64', 'jmpq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void free_list_elements_r(list);
# func-return-type:void
# func-name:free_list_elements_r
# func-filename:list.c
# func-disassembly:['endbr64', 'push %rbx', 'mov %rdi , %rbx', 'callq 0x', 'movq $0x , ( %rbx )', 'movq $0x , 0x ( %rbx )', 'pop %rbx', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void free_list_r(list *);
# func-return-type:void
# func-name:free_list_r
# func-filename:list.c
# func-disassembly:['endbr64', 'push %rbp', 'mov ( %rdi ) , %rbp', 'test %rbp , %rbp', 'je 0x', 'movq $0x , ( %rdi )', 'mov %rbp , %rdi', 'callq 0x', 'mov %rbp , %rdi', 'pop %rbp', 'jmpq 0x', 'nopl ( %rax )', 'pop %rbp', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void free_mlist_r(list, size_t);
# func-return-type:void
# func-name:free_mlist_r
# func-filename:list.c
# func-disassembly:['endbr64', 'test %rdi , %rdi', 'je 0x', 'push %r15', 'push %r14', 'mov %rdi , %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'test %rsi , %rsi', 'je 0x', 'lea ( %rsi , %rsi , 4 ) , %rax', 'mov %rdi , %rbp', 'lea ( %rdi , %rax , 8 ) , %r15', 'nopw 0x ( %rax , %rax , 1 )', 'mov 0x ( %rbp ) , %rbx', 'mov 0x ( %r14 ) , %r13', 'test %rbx , %rbx', 'je 0x', 'nopl ( %rax )', 'mov %rbx , %r12', 'mov ( %rbx ) , %rbx', 'test %r13 , %r13', 'je 0x', 'mov 0x ( %r12 ) , %rdi', 'callq *%r13', 'mov %r12 , %rdi', 'callq 0x', 'test %rbx , %rbx', 'jne 0x', 'add $0x , %rbp', 'cmp %rbp , %r15', 'jne 0x', 'add $0x , %rsp', 'mov %r14 , %rdi', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'jmpq 0x', 'nop', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void list_add_head_r(list, void *);
# func-return-type:void
# func-name:list_add_head_r
# func-filename:list.c
# func-disassembly:['endbr64', 'push %rbp', 'mov %rsi , %rbp', 'push %rbx', 'mov %rdi , %rbx', 'mov $0x , %edi', 'sub $0x , %rsp', 'callq 0x', 'mov %rbp , 0x ( %rax )', 'mov ( %rbx ) , %rdx', 'movq $0x , 0x ( %rax )', 'mov %rdx , ( %rax )', 'cmpq $0x , 0x ( %rbx )', 'je 0x', 'mov ( %rbx ) , %rdx', 'mov %rax , 0x ( %rdx )', 'mov %rax , ( %rbx )', 'addl $0x , 0x ( %rbx )', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq', 'nopl 0x ( %rax , %rax , 1 )', 'addl $0x , 0x ( %rbx )', 'mov %rax , 0x ( %rbx )', 'mov %rax , ( %rbx )', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void list_add_r(list, void *);
# func-return-type:void
# func-name:list_add_r
# func-filename:list.c
# func-disassembly:['endbr64', 'push %rbp', 'mov %rsi , %rbp', 'push %rbx', 'mov %rdi , %rbx', 'mov $0x , %edi', 'sub $0x , %rsp', 'callq 0x', 'mov %rbp , 0x ( %rax )', 'mov 0x ( %rbx ) , %rdx', 'movq $0x , ( %rax )', 'mov %rdx , 0x ( %rax )', 'cmpq $0x , ( %rbx )', 'je 0x', 'mov 0x ( %rbx ) , %rdx', 'mov %rax , ( %rdx )', 'mov %rax , 0x ( %rbx )', 'addl $0x , 0x ( %rbx )', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq', 'nopl 0x ( %rax )', 'addl $0x , 0x ( %rbx )', 'mov %rax , ( %rbx )', 'mov %rax , 0x ( %rbx )', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void list_del_r(list, const void *);
# func-return-type:void
# func-name:list_del_r
# func-filename:list.c
# func-disassembly:['endbr64', 'mov %rsi , %rax', 'test %rdi , %rdi', 'je 0x', 'mov ( %rdi ) , %rsi', 'test %rsi , %rsi', 'jne 0x', 'jmp 0x', 'nopw %cs : 0x ( %rax , %rax , 1 )', 'mov ( %rsi ) , %rsi', 'test %rsi , %rsi', 'je 0x', 'cmp %rax , 0x ( %rsi )', 'jne 0x', 'jmpq 0x', 'nopl 0x ( %rax , %rax , 1 )', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void *list_element(const list, size_t);
# func-return-type:void *
# func-name:list_element
# func-filename:list.c
# func-disassembly:['endbr64', 'xor %eax , %eax', 'test %rdi , %rdi', 'je 0x', 'mov ( %rdi ) , %rax', 'test %rsi , %rsi', 'je 0x', 'test %rax , %rax', 'je 0x', 'xor %edx , %edx', 'jmp 0x', 'nopl 0x ( %rax )', 'test %rax , %rax', 'je 0x', 'add $0x , %rdx', 'mov ( %rax ) , %rax', 'cmp %rdx , %rsi', 'jne 0x', 'test %rax , %rax', 'je 0x', 'mov 0x ( %rax ) , %rax', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void list_extract(list, const element);
# func-return-type:void
# func-name:list_extract
# func-filename:list.c
# func-disassembly:['endbr64', 'mov 0x ( %rsi ) , %rax', 'mov ( %rsi ) , %rdx', 'test %rax , %rax', 'je 0x', 'mov %rdx , ( %rax )', 'mov ( %rsi ) , %rax', 'mov 0x ( %rsi ) , %rdx', 'test %rax , %rax', 'je 0x', 'mov %rdx , 0x ( %rax )', 'subl $0x , 0x ( %rdi )', 'retq', 'nopl 0x ( %rax , %rax , 1 )', 'mov %rdx , ( %rdi )', 'mov ( %rsi ) , %rax', 'mov 0x ( %rsi ) , %rdx', 'test %rax , %rax', 'jne 0x', 'subl $0x , 0x ( %rdi )', 'mov %rdx , 0x ( %rdi )', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void list_remove_r(list, const element);
# func-return-type:void
# func-name:list_remove_r
# func-filename:list.c
# func-disassembly:['endbr64', 'push %rbp', 'mov %rsi , %rbp', 'push %rbx', 'mov %rdi , %rbx', 'sub $0x , %rsp', 'mov 0x ( %rdi ) , %rax', 'test %rax , %rax', 'je 0x', 'mov 0x ( %rsi ) , %rdi', 'callq *%rax', 'mov 0x ( %rbp ) , %rax', 'mov 0x ( %rbp ) , %rdx', 'test %rax , %rax', 'je 0x', 'mov %rdx , ( %rax )', 'mov 0x ( %rbp ) , %rax', 'mov 0x ( %rbp ) , %rdx', 'test %rax , %rax', 'je 0x', 'mov %rdx , 0x ( %rax )', 'subl $0x , 0x ( %rbx )', 'add $0x , %rsp', 'mov %rbp , %rdi', 'pop %rbx', 'pop %rbp', 'jmpq 0x', 'nopw 0x ( %rax , %rax , 1 )', 'mov %rdx , ( %rbx )', 'mov 0x ( %rbp ) , %rax', 'mov 0x ( %rbp ) , %rdx', 'test %rax , %rax', 'jne 0x', 'mov %rdx , 0x ( %rbx )', 'jmp 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void list_transfer(element, list, list);
# func-return-type:void
# func-name:list_transfer
# func-filename:list.c
# func-disassembly:['endbr64', 'mov 0x ( %rdi ) , %rax', 'mov ( %rdi ) , %rcx', 'test %rax , %rax', 'je 0x', 'mov %rcx , ( %rax )', 'mov ( %rdi ) , %rax', 'mov 0x ( %rdi ) , %rcx', 'test %rax , %rax', 'je 0x', 'mov %rcx , 0x ( %rax )', 'subl $0x , 0x ( %rsi )', 'mov 0x ( %rdx ) , %rax', 'movq $0x , ( %rdi )', 'mov %rax , 0x ( %rdi )', 'cmpq $0x , ( %rdx )', 'je 0x', 'mov 0x ( %rdx ) , %rax', 'mov %rdi , ( %rax )', 'mov %rdi , 0x ( %rdx )', 'addl $0x , 0x ( %rdx )', 'retq', 'nopl 0x ( %rax )', 'mov %rcx , ( %rsi )', 'mov ( %rdi ) , %rax', 'mov 0x ( %rdi ) , %rcx', 'test %rax , %rax', 'jne 0x', 'mov %rcx , 0x ( %rsi )', 'jmp 0x', 'nopl ( %rax )', 'addl $0x , 0x ( %rdx )', 'mov %rdi , ( %rdx )', 'mov %rdi , 0x ( %rdx )', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:static void free_elements(list);
# func-return-type:static void
# func-name:free_elements
# func-filename:list.c
# func-disassembly:['test %rdi , %rdi', 'je 0x', 'push %r12', 'push %rbp', 'mov %rdi , %rbp', 'push %rbx', 'mov ( %rdi ) , %rbx', 'test %rbx , %rbx', 'je 0x', 'nopl 0x ( %rax )', 'mov 0x ( %rbp ) , %rax', 'mov %rbx , %r12', 'mov ( %rbx ) , %rbx', 'test %rax , %rax', 'je 0x', 'mov 0x ( %r12 ) , %rdi', 'callq *%rax', 'subl $0x , 0x ( %rbp )', 'mov %r12 , %rdi', 'callq 0x', 'test %rbx , %rbx', 'jne 0x', 'pop %rbx', 'pop %rbp', 'pop %r12', 'retq', 'nopl 0x ( %rax )', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void conf_write(FILE *, const char *, ...);
# func-return-type:void
# func-name:conf_write
# func-filename:logger.c
# func-disassembly:['endbr64', 'push %rbp', 'mov %rdi , %rbp', 'sub $0x , %rsp', 'mov %rdx , 0x ( %rsp )', 'mov %rcx , 0x ( %rsp )', 'mov %r8 , 0x ( %rsp )', 'mov %r9 , 0x ( %rsp )', 'test %al , %al', 'je 0x', 'movaps %xmm0 , 0x ( %rsp )', 'movaps %xmm1 , 0x ( %rsp )', 'movaps %xmm2 , 0x ( %rsp )', 'movaps %xmm3 , 0x ( %rsp )', 'movaps %xmm4 , 0x ( %rsp )', 'movaps %xmm5 , 0x ( %rsp )', 'movaps %xmm6 , 0x ( %rsp )', 'movaps %xmm7 , 0x ( %rsp )', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'lea 0x ( %rsp ) , %rax', 'movl $0x , ( %rsp )', 'mov %rax , 0x ( %rsp )', 'lea 0x ( %rsp ) , %rax', 'movl $0x , 0x ( %rsp )', 'mov %rax , 0x ( %rsp )', 'test %rbp , %rbp', 'je 0x', 'mov %rsi , %rdx', 'mov %rbp , %rdi', 'mov $0x , %esi', 'mov %rsp , %rcx', 'callq 0x', 'mov %rbp , %rsi', 'mov $0x , %edi', 'callq 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'pop %rbp', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'mov %rsp , %rdx', 'mov $0x , %edi', 'callq 0x', 'jmp 0x', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void enable_console_log(void);
# func-return-type:void
# func-name:enable_console_log
# func-filename:logger.c
# func-disassembly:['endbr64', 'movb $0x , 0x ( %rip )', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void log_message(const int, const char *, ...);
# func-return-type:void
# func-name:log_message
# func-filename:logger.c
# func-disassembly:['endbr64', 'sub $0x , %rsp', 'mov %rdx , 0x ( %rsp )', 'mov %rcx , 0x ( %rsp )', 'mov %r8 , 0x ( %rsp )', 'mov %r9 , 0x ( %rsp )', 'test %al , %al', 'je 0x', 'movaps %xmm0 , 0x ( %rsp )', 'movaps %xmm1 , 0x ( %rsp )', 'movaps %xmm2 , 0x ( %rsp )', 'movaps %xmm3 , 0x ( %rsp )', 'movaps %xmm4 , 0x ( %rsp )', 'movaps %xmm5 , 0x ( %rsp )', 'movaps %xmm6 , 0x ( %rsp )', 'movaps %xmm7 , 0x ( %rsp )', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'lea 0x ( %rsp ) , %rax', 'mov %rsp , %rdx', 'movl $0x , ( %rsp )', 'mov %rax , 0x ( %rsp )', 'lea 0x ( %rsp ) , %rax', 'mov %rax , 0x ( %rsp )', 'movl $0x , 0x ( %rsp )', 'callq 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'retq', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void vlog_message(const int, const char *, struct __va_list_tag *);
# func-return-type:void
# func-name:vlog_message
# func-filename:logger.c
# func-disassembly:['endbr64', 'push %r15', 'push %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'mov 0x ( %rip ) , %rax', 'test $0x , %ah', 'jne 0x', 'mov %edi , %ebp', 'mov %rsi , %r13', 'mov %rdx , %r12', 'test $0x , %al', 'je 0x', 'cmpb $0x , 0x ( %rip )', 'jne 0x', 'test $0x , %al', 'je 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'nopw %cs : 0x ( %rax , %rax , 1 )', 'mov %r12 , %rcx', 'mov %r13 , %rdx', 'mov $0x , %esi', 'mov %ebp , %edi', 'callq 0x', 'jmp 0x', 'nopl 0x ( %rax )', 'movdqu ( %rdx ) , %xmm0', 'lea 0x ( %rsp ) , %rbx', 'mov %rsi , %r8', 'lea 0x ( %rsp ) , %r9', 'mov $0x , %ecx', 'mov $0x , %esi', 'mov %rbx , %rdi', 'movups %xmm0 , 0x ( %rsp )', 'mov 0x ( %rdx ) , %rax', 'mov $0x , %edx', 'lea 0x ( %rsp ) , %r14', 'lea 0x ( %rsp ) , %r15', 'mov %rax , 0x ( %rsp )', 'callq 0x', 'xor %edi , %edi', 'callq 0x', 'lea 0x ( %rsp ) , %rdi', 'mov %r14 , %rsi', 'mov %rax , 0x ( %rsp )', 'callq 0x', 'mov %r14 , %rcx', 'mov $0x , %esi', 'mov %r15 , %rdi', 'lea 0x ( %rip ) , %rdx', 'callq 0x', 'cmpb $0x , 0x ( %rip )', 'mov 0x ( %rip ) , %rax', 'je 0x', 'test $0x , %al', 'je 0x', 'mov 0x ( %rip ) , %rdi', 'mov %rbx , %r8', 'mov %r15 , %rcx', 'xor %eax , %eax', 'lea 0x ( %rip ) , %rdx', 'mov $0x , %esi', 'callq 0x', 'mov 0x ( %rip ) , %rax', 'jmpq 0x', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:int main(int, char **);
# func-return-type:int
# func-name:main
# func-filename:main.c
# func-disassembly:['endbr64', 'push %r12', 'mov %rsi , %r12', 'push %rbp', 'mov %edi , %ebp', 'mov $0x , %edi', 'sub $0x , %rsp', 'callq 0x', 'mov %r12 , %rsi', 'mov %ebp , %edi', 'movl $0x , 0x ( %rax )', 'mov %rax , %rdx', 'mov %rax , 0x ( %rip )', 'movabs $0x , %rax', 'mov %rax , 0x ( %rdx )', 'callq 0x', 'test %eax , %eax', 'je 0x', 'mov 0x ( %rip ) , %rax', 'cmpq $0x , ( %rax )', 'mov 0x ( %rax ) , %rdx', 'je 0x', 'test %rdx , %rdx', 'je 0x', 'callq 0x', 'imul $0x , %rax , %rax', 'add %rdx , %rax', 'mov 0x ( %rip ) , %rdx', 'mov %rax , 0x ( %rdx )', 'callq 0x', 'callq 0x', 'xor %edx , %edx', 'mov $0x , %edi', 'lea 0x ( %rip ) , %rsi', 'mov %rax , 0x ( %rip )', 'callq 0x', 'xor %edx , %edx', 'mov $0x , %edi', 'lea 0x ( %rip ) , %rsi', 'callq 0x', 'xor %edx , %edx', 'mov $0x , %edi', 'lea 0x ( %rip ) , %rsi', 'callq 0x', 'mov $0x , %edi', 'callq 0x', 'callq 0x', 'mov 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rip ) , %rax', 'cmpl $0x , 0x ( %rax )', 'jne 0x', 'mov 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rip ) , %rax', 'mov 0x ( %rax ) , %rdi', 'callq 0x', 'mov 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rip ) , %rax', 'mov ( %rax ) , %rdi', 'callq 0x', 'mov 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rip ) , %edi', 'movq $0x , 0x ( %rip )', 'callq 0x', 'mov 0x ( %rax ) , %rdx', 'mov 0x ( %rax ) , %rcx', 'mov $0x , %edi', 'lea 0x ( %rip ) , %rsi', 'sub 0x ( %rax ) , %rcx', 'xor %eax , %eax', 'callq 0x', 'jmp 0x', 'cmpw $0x , 0x ( %rax )', 'jne 0x', 'test %rdx , %rdx', 'jne 0x', 'xor %edi , %edi', 'callq 0x', 'mov 0x ( %rip ) , %rdi', 'callq 0x', 'mov $0x , %edi', 'movq $0x , 0x ( %rip )', 'callq 0x', 'lea 0x ( %rip ) , %rcx', 'mov %rcx , 0x ( %rax )', 'jmpq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:static int parse_cmdline(int, char **, REQ *);
# func-return-type:static int
# func-name:parse_cmdline
# func-filename:main.c
# func-disassembly:['push %r15', 'mov $0x , %ecx', 'pxor %xmm0 , %xmm0', 'push %r14', 'mov %rdx , %r14', 'push %r13', 'push %r12', 'mov %edi , %r12d', 'push %rbp', 'mov %rsi , %rbp', 'lea 0x ( %rip ) , %rsi', 'push %rbx', 'lea 0x ( %rip ) , %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'lea 0x ( %rsp ) , %r13', 'movq $0x , ( %rsp )', 'mov %r13 , %rdi', 'movups %xmm0 , 0x ( %rsp )', 'rep movsq %ds : ( %rsi ) , %es : ( %rdi )', 'movups %xmm0 , 0x ( %rsp )', 'movq $0x , 0x ( %rsp )', 'movq $0x , 0x ( %rsp )', 'nopl 0x ( %rax , %rax , 1 )', 'xor %r8d , %r8d', 'mov %r13 , %rcx', 'lea 0x ( %rip ) , %rdx', 'mov %rbp , %rsi', 'mov %r12d , %edi', 'callq 0x', 'cmp $0x , %eax', 'je 0x', 'sub $0x , %eax', 'cmp $0x , %eax', 'ja 0x', 'movslq ( %rbx , %rax , 4 ) , %rax', 'add %rbx , %rax', 'notrack jmpq *%rax', 'movl $0x , 0x ( %r14 )', 'jmp 0x', 'mov 0x ( %rip ) , %rax', 'mov %rax , 0x ( %r14 )', 'jmp 0x', 'mov 0x ( %rip ) , %r15', 'lea 0x ( %rip ) , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'mov $0x , %edx', 'lea 0x ( %rsp ) , %rsi', 'add %rax , %r15', 'mov %r15 , %rdi', 'callq 0x', 'mov 0x ( %rsp ) , %rdx', 'mov %eax , 0x ( %r14 )', 'cmpb $0x , ( %rdx )', 'jne 0x', 'movzbl ( %r15 ) , %edx', 'test %dl , %dl', 'je 0x', 'cmp $0x , %dl', 'je 0x', 'imul $0x , %eax , %eax', 'mov %eax , 0x ( %r14 )', 'jmpq 0x', 'mov 0x ( %rip ) , %rdi', 'mov %rsp , %rcx', 'lea 0x ( %rsp ) , %rdx', 'xor %esi , %esi', 'callq 0x', 'mov %eax , %r15d', 'test %eax , %eax', 'jne 0x', 'mov ( %rsp ) , %rax', 'mov 0x ( %rax ) , %edx', 'cmp $0x , %edx', 'je 0x', 'cmp $0x , %edx', 'jne 0x', 'mov %rax , ( %r14 )', 'mov 0x ( %rax ) , %rcx', 'lea 0x ( %r14 ) , %rdx', 'mov 0x ( %rax ) , %edi', 'lea 0x ( %rcx ) , %rsi', 'mov $0x , %ecx', 'callq 0x', 'jmpq 0x', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %edx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'callq 0x', 'jmpq 0x', 'mov 0x ( %rip ) , %rdi', 'mov $0x , %edx', 'lea 0x ( %rsp ) , %rsi', 'callq 0x', 'mov 0x ( %rsp ) , %rdx', 'cmpb $0x , ( %rdx )', 'jne 0x', 'lea -0x ( %rax ) , %rdx', 'cmp $0x , %rdx', 'ja 0x', 'rol $0x , %ax', 'mov %ax , 0x ( %r14 )', 'jmpq 0x', 'mov 0x ( %rip ) , %r15', 'lea 0x ( %rip ) , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'lea 0x ( %rsp ) , %rsi', 'mov $0x , %edx', 'add %rax , %r15', 'mov %r15 , %rdi', 'callq 0x', 'mov %eax , 0x ( %r14 )', 'mov 0x ( %rsp ) , %rax', 'cmpb $0x , ( %rax )', 'jne 0x', 'movzbl ( %r15 ) , %eax', 'cmp $0x , %al', 'je 0x', 'cmp $0x , %al', 'jne 0x', 'mov 0x ( %rip ) , %rcx', 'lea 0x ( %rip ) , %rdx', 'jmpq 0x', 'mov 0x ( %rbp ) , %rdi', 'callq 0x', 'jmpq 0x', 'mov 0x ( %rip ) , %rax', 'mov %rax , 0x ( %r14 )', 'jmpq 0x', 'movl $0x , 0x ( %r14 )', 'jmpq 0x', 'mov 0x ( %rip ) , %r15', 'lea 0x ( %rip ) , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'test %eax , %eax', 'jne 0x', 'movl $0x , 0x ( %r14 )', 'jmpq 0x', 'movl $0x , 0x ( %r14 )', 'jmpq 0x', 'mov 0x ( %rip ) , %r15', 'mov 0x ( %rip ) , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'test %eax , %eax', 'je 0x', 'mov 0x ( %rip ) , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'test %eax , %eax', 'je 0x', 'mov %r15 , %rcx', 'lea 0x ( %rip ) , %rdx', 'mov 0x ( %rip ) , %rdi', 'mov $0x , %esi', 'xor %eax , %eax', 'xor %r15d , %r15d', 'callq 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'mov %r15d , %eax', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'mov 0x ( %rbp ) , %rdi', 'xor %r15d , %r15d', 'callq 0x', 'jmp 0x', 'lea 0x ( %rip ) , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'test %eax , %eax', 'je 0x', 'lea 0x ( %rip ) , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'test %eax , %eax', 'je 0x', 'lea 0x ( %rip ) , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'test %eax , %eax', 'je 0x', 'lea 0x ( %rip ) , %rsi', 'mov %r15 , %rdi', 'callq 0x', 'test %eax , %eax', 'jne 0x', 'movl $0x , 0x ( %r14 )', 'jmpq 0x', 'movl $0x , 0x ( %r14 )', 'jmpq 0x', 'cmp 0x ( %rip ) , %r12d', 'mov $0x , %r15d', 'jle 0x', 'mov 0 ...
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:static void sigend(void *, int);
# func-return-type:static void
# func-name:sigend
# func-filename:main.c
# func-disassembly:['endbr64', 'mov 0x ( %rip ) , %rdi', 'jmpq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:static void usage(const char *);
# func-return-type:static void
# func-name:usage
# func-filename:main.c
# func-disassembly:['push %r12', 'mov 0x ( %rip ) , %rcx', 'mov %rdi , %r12', 'mov $0x , %edx', 'push %rbp', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'lea 0x ( %rip ) , %rbp', 'push %rbx', 'xor %ebx , %ebx', 'callq 0x', 'mov 0x ( %rip ) , %rdi', 'mov $0x , %esi', 'xor %eax , %eax', 'lea 0x ( %rip ) , %rcx', 'lea 0x ( %rip ) , %rdx', 'callq 0x', 'mov %r12 , %rcx', 'mov $0x , %esi', 'xor %eax , %eax', 'mov 0x ( %rip ) , %rdi', 'lea 0x ( %rip ) , %rdx', 'lea 0x ( %rip ) , %r12', 'callq 0x', 'mov $0x , %edx', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov $0x , %edx', 'mov 0x ( %rip ) , %rcx', 'mov $0x , %esi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'test %ebx , %ebx', 'je 0x', 'mov %ebx , %eax', 'mov $0x , %esi', 'add $0x , %ebx', 'mov 0x ( %rip ) , %rdi', 'lea ( %rax , %rax , 2 ) , %rax', 'lea 0x ( %rip ) , %r8', 'shl $0x , %rax', 'lea 0x ( %rip ) , %rdx', 'mov 0x ( %r12 , %rax , 1 ) , %rcx', 'xor %eax , %eax', 'callq 0x', 'cmp $0x , %ebx', 'jbe 0x', 'pop %rbx', 'pop %rbp', 'pop %r12', 'retq', 'nopl ( %rax )', 'mov %rbp , %r8', 'mov $0x , %esi', 'xor %eax , %eax', 'mov $0x , %ebx', 'mov 0x ( %rip ) , %rcx', 'mov 0x ( %rip ) , %rdi', 'lea 0x ( %rip ) , %rdx', 'callq 0x', 'jmp 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void *zalloc(unsigned long);
# func-return-type:void *
# func-name:zalloc
# func-filename:memory.c
# func-disassembly:['endbr64', 'sub $0x , %rsp', 'mov $0x , %esi', 'callq 0x', 'test %rax , %rax', 'je 0x', 'add $0x , %rsp', 'retq', 'testb $0x , 0x ( %rip )', 'je 0x', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov $0x , %edi', 'callq 0x', 'callq 0x', 'mov ( %rax ) , %edi', 'callq 0x', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'mov %rax , %rdx', 'xor %eax , %eax', 'callq 0x', 'jmp 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:void add_script_param(notify_script_t *, const char *);
# func-return-type:void
# func-name:add_script_param
# func-filename:notify.c
# func-disassembly:['endbr64', 'movslq 0x ( %rdi ) , %rax', 'mov ( %rdi ) , %r8', 'mov %rax , %rdx', 'add $0x , %rax', 'cmpq $0x , ( %r8 , %rax , 8 )', 'lea 0x ( , %rax , 8 ) , %rcx', 'jne 0x', 'add $0x , %edx', 'mov %edx , 0x ( %rdi )', 'mov %rsi , -0x ( %r8 , %rcx , 1 )', 'retq', 'nopl ( %rax )', 'mov ( %r8 ) , %rdx', 'mov %rsi , %rcx', 'mov $0x , %edi', 'xor %eax , %eax', 'lea 0x ( %rip ) , %rsi', 'jmpq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:int check_notify_script_secure(notify_script_t **, magic_t);
# func-return-type:int
# func-name:check_notify_script_secure
# func-filename:notify.c
# func-disassembly:['endbr64', 'push %r12', 'xor %r12d , %r12d', 'push %rbx', 'mov %rdi , %rbx', 'sub $0x , %rsp', 'mov ( %rdi ) , %rdi', 'test %rdi , %rdi', 'je 0x', 'callq 0x', 'mov %eax , %r12d', 'and $0x , %eax', 'cmp $0x , %eax', 'jne 0x', 'add $0x , %rsp', 'mov %r12d , %eax', 'pop %rbx', 'pop %r12', 'retq', 'nopl 0x ( %rax )', 'mov ( %rbx ) , %rdi', 'test %rdi , %rdi', 'je 0x', 'mov ( %rdi ) , %r8', 'test %r8 , %r8', 'je 0x', 'mov %r8 , %rdi', 'callq 0x', 'mov ( %rbx ) , %rax', 'movq $0x , ( %rax )', 'mov ( %rbx ) , %rdi', 'test %rdi , %rdi', 'jne 0x', 'movq $0x , ( %rbx )', 'add $0x , %rsp', 'mov %r12d , %eax', 'pop %rbx', 'pop %r12', 'retq', 'nopl 0x ( %rax )', 'callq 0x', 'jmp 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/bin/genhash
# ----------
# func-signature:int check_script_secure(notify_script_t *, magic_t);
# func-return-type:int
# func-name:check_script_secure
# func-filename:notify.c
# ...
# func-filename:vrrp_vmac.c
# func-disassembly:['endbr64', 'push %r15', 'push %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'cmpq $0x , 0x ( %rdi )', 'je 0x', 'mov 0x ( %rdi ) , %r12', 'mov %rdi , %rbx', 'shr %r12', 'and $0x , %r12d', 'jne 0x', 'cmpb $0x , 0x ( %rdi )', 'jne 0x', 'xor %r12d , %r12d', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'mov %r12d , %eax', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'lea 0x ( %rsp ) , %rbp', 'xor %eax , %eax', 'lea 0x ( %rbx ) , %r13', 'mov $0x , %ecx', 'mov %rbp , %rdi', 'mov $0x , %esi', 'rep stos %rax , %es : ( %rdi )', 'mov %r13 , %rdi', 'callq 0x', 'mov 0x ( %rax ) , %edi', 'movb $0x , 0x ( %rax )', 'mov %rax , %r14', 'test %edi , %edi', 'je 0x', 'movl $0x , 0x ( %rax )', 'movzwl ( %rbx ) , %eax', 'cmp $0x , %ax', 'je 0x', 'cmp $0x , %ax', 'je 0x', 'cmpb $0x , 0x ( %rbx )', 'jne 0x', 'orq $0x , 0x ( %rbx )', 'lea 0x ( %rbx ) , %rdi', 'callq 0x', 'callq 0x', 'mov 0x ( %rbx ) , %rdi', 'test %rdi , %rdi', 'je 0x', 'mov $0x , %esi', 'callq 0x', 'cmp $0x , %eax', 'jne 0x', 'mov $0x , %r12d', 'jmpq 0x', 'mov 0x ( %rbx ) , %rax', 'mov 0x ( %rax ) , %rdx', 'mov 0x ( %rdx ) , %esi', 'test %esi , %esi', 'jne 0x', 'movl $0x , 0x ( %r14 )', 'jmpq 0x', 'nopw 0x ( %rax , %rax , 1 )', 'mov $0x , %esi', 'mov %r14 , %rdi', 'callq 0x', 'jmp 0x', 'nopw 0x ( %rax , %rax , 1 )', 'mov 0x ( %rbx ) , %rdx', 'mov %r14 , %rcx', 'lea 0x ( %rip ) , %rsi', 'xor %eax , %eax', 'mov $0x , %edi', 'callq 0x', 'jmp 0x', 'nopl 0x ( %rax )', 'cmpb $0x , 0x ( %rbx )', 'je 0x', 'mov $0x , %esi', 'mov %r14 , %rdi', 'callq 0x', 'movzwl ( %rbx ) , %eax', 'jmpq 0x', 'nopw 0x ( %rax , %rax , 1 )', 'lea 0x ( %rsp ) , %r10', 'movb $0x , 0x ( %rsp )', 'mov 0x ( %rax ) , %eax', 'mov %rbp , %rdi', 'mov %r10 , %rcx', 'mov $0x , %r8d', 'mov $0x , %edx', 'movabs $0x , %rsi', 'mov %rsi , 0x ( %rsp )', 'mov $0x , %esi', 'mov %r10 , 0x ( %rsp )', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov %r13 , %rdi', 'callq 0x', 'mov %r13 , %rcx', 'mov $0x , %edx', 'mov %rbp , %rdi', 'mov %rax , %r8', 'mov $0x , %esi', 'callq 0x', 'mov 0x ( %rsp ) , %eax', 'xor %r8d , %r8d', 'xor %ecx , %ecx', 'mov $0x , %edx', 'mov $0x , %esi', 'mov %rbp , %rdi', 'add $0x , %eax', 'and $0x , %eax', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov $0x , %r8d', 'mov $0x , %edx', 'mov %rbp , %rdi', 'lea 0x ( %rip ) , %rcx', 'mov $0x , %esi', 'callq 0x', 'mov 0x ( %rsp ) , %ecx', 'xor %r8d , %r8d', 'mov %rbp , %rdi', 'mov $0x , %edx', 'mov $0x , %esi', 'lea 0x ( %rcx ) , %r15d', 'xor %ecx , %ecx', 'callq 0x', 'mov 0x ( %rsp ) , %r10', 'xor %ecx , %ecx', 'mov %rbp , %rdi', 'mov %cx , 0x ( %rsp )', 'mov $0x , %edx', 'mov $0x , %r8d', 'mov $0x , %esi', 'mov %r10 , %rcx', 'and $0x , %r15d', 'callq 0x', 'mov 0x ( %rsp ) , %edx', 'lea 0x ( %rdx ) , %eax', 'mov 0x ( %rsp ) , %edx', 'and $0x , %eax', 'sub %r15 , %rax', 'mov %ax , 0x ( %rsp , %r15 , 1 )', 'mov 0x ( %rsp ) , %eax', 'add $0x , %eax', 'and $0x , %eax', 'sub %rdx , %rax', 'mov %ax , 0x ( %rsp , %rdx , 1 )', 'mov 0x ( %rbx ) , %rax', 'mov 0x ( %rax ) , %rax', 'test %rax , %rax', 'je 0x', 'mov 0x ( %rsp ) , %r10', 'mov 0x ( %rax ) , %eax', 'mov $0x , %edx', 'mov %rbp , %rdi', 'mov $0x , %r8d', 'mov $0x , %esi', 'mov %r10 , %rcx', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov %rbp , %rsi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rbx ) , %rdx', 'mov %r13 , %rcx', 'test %rax , %rax', 'js 0x', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'callq 0x', 'mov %r13 , %rdi', 'callq 0x', 'mov 0x ( %r14 ) , %edx', 'test %edx , %edx', 'je 0x', 'cmpq $0x , 0x ( %r14 )', 'je 0x', 'callq 0x', 'mov 0x ( %r14 ) , %eax', 'movl $0x , 0x ( %r14 )', 'test %eax , %eax', 'je 0x', 'movzwl ( %rbx ) , %eax', 'cmp $0x , %ax', 'jne 0x', 'cmpb $0x , 0x ( %rbx )', 'jne 0x', 'nopl 0x ( %rax )', 'xor %esi , %esi', 'mov %r14 , %rdi', 'callq 0x', 'movzwl ( %rbx ) , %eax ...
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/sbin/keepalived
# ----------
# func-signature:_Bool netlink_link_add_vmac(vrrp_t *);
# func-return-type:_Bool
# func-name:netlink_link_add_vmac
# func-filename:vrrp_vmac.c
# func-disassembly:['endbr64', 'push %r15', 'push %r14', 'push %r13', 'push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'cmpq $0x , 0x ( %rdi )', 'je 0x', 'mov 0x ( %rdi ) , %r12', 'mov %rdi , %rbp', 'shr %r12', 'and $0x , %r12d', 'jne 0x', 'movzbl 0x ( %rdi ) , %eax', 'test %al , %al', 'je 0x', 'cmpw $0x , ( %rdi )', 'lea 0x ( %rsp ) , %r13', 'mov %al , 0x ( %rip )', 'mov $0x , %ecx', 'sete %dl', 'mov %r13 , %rdi', 'xor %eax , %eax', 'mov $0x , %esi', 'rep stos %rax , %es : ( %rdi )', 'lea 0x ( %rbp ) , %r14', 'add $0x , %edx', 'mov %r14 , %rdi', 'mov %dl , 0x ( %rip )', 'callq 0x', 'mov 0x ( %rax ) , %r10d', 'mov %rax , %rbx', 'test %r10d , %r10d', 'jne 0x', 'movb $0x , 0x ( %rax )', 'mov 0x ( %rbp ) , %rax', 'mov 0x ( %rax ) , %rax', 'mov 0x ( %rax ) , %r9d', 'test %r9d , %r9d', 'jne 0x', 'movl $0x , 0x ( %rbx )', 'mov 0x ( %rbx ) , %esi', 'test %esi , %esi', 'je 0x', 'movzwl 0x ( %rbp ) , %eax', 'cmp $0x , %ax', 'je 0x', 'mov $0x , %r12d', 'cmp $0x , %ax', 'je 0x', 'cmpb $0x , 0x ( %rbp )', 'jne 0x', 'mov 0x ( %rbp ) , %rax', 'or $0x , %rax', 'lea 0x ( %rbp ) , %rdi', 'mov $0x , %r12d', 'mov %rax , 0x ( %rbp )', 'callq 0x', 'callq 0x', 'callq 0x', 'mov %rbp , %rdi', 'callq 0x', 'jmpq 0x', 'nop', 'xor %r8d , %r8d', 'xor %ecx , %ecx', 'mov $0x , %edx', 'mov $0x , %esi', 'movabs $0x , %rax', 'mov %r13 , %rdi', 'movb $0x , 0x ( %rsp )', 'mov %rax , 0x ( %rsp )', 'callq 0x', 'mov $0x , %r8d', 'mov $0x , %edx', 'mov %r13 , %rdi', 'lea 0x ( %rip ) , %rcx', 'mov $0x , %esi', 'callq 0x', 'xor %r8d , %r8d', 'xor %ecx , %ecx', 'mov $0x , %edx', 'mov 0x ( %rsp ) , %eax', 'mov $0x , %esi', 'mov %r13 , %rdi', 'lea 0x ( %rax ) , %r15d', 'callq 0x', 'lea 0x ( %rsp ) , %r9', 'mov $0x , %r8d', 'mov %r13 , %rdi', 'mov %r9 , %rcx', 'mov $0x , %edx', 'mov $0x , %esi', 'mov %r9 , 0x ( %rsp )', 'movl $0x , 0x ( %rsp )', 'and $0x , %r15d', 'callq 0x', 'mov 0x ( %rsp ) , %eax', 'mov 0x ( %rsp ) , %r9', 'mov $0x , %r8d', 'mov $0x , %edx', 'mov $0x , %esi', 'mov %r13 , %rdi', 'add $0x , %eax', 'mov %r9 , %rcx', 'and $0x , %eax', 'sub %r15 , %rax', 'mov %ax , 0x ( %rsp , %r15 , 1 )', 'mov 0x ( %rsp ) , %eax', 'add $0x , %eax', 'and $0x , %eax', 'sub $0x , %rax', 'mov %ax , 0x ( %rsp )', 'mov 0x ( %rbp ) , %rax', 'mov 0x ( %rax ) , %eax', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov %r14 , %rdi', 'callq 0x', 'mov %r14 , %rcx', 'mov $0x , %edx', 'mov %r13 , %rdi', 'mov %rax , %r8', 'mov $0x , %esi', 'callq 0x', 'mov $0x , %r8d', 'mov $0x , %edx', 'mov %r13 , %rdi', 'lea 0x ( %rip ) , %rcx', 'mov $0x , %esi', 'callq 0x', 'mov 0x ( %rbp ) , %rax', 'mov 0x ( %rax ) , %rax', 'test %rax , %rax', 'je 0x', 'mov 0x ( %rsp ) , %r9', 'mov 0x ( %rax ) , %eax', 'mov $0x , %edx', 'mov %r13 , %rdi', 'mov $0x , %r8d', 'mov $0x , %esi', 'mov %r9 , %rcx', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov %r13 , %rsi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov 0x ( %rbp ) , %rdx', 'mov %r14 , %rcx', 'test %rax , %rax', 'js 0x', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'callq 0x', 'mov %r14 , %rdi', 'callq 0x', 'mov 0x ( %rbx ) , %r8d', 'test %r8d , %r8d', 'jne 0x', 'nopl ( %rax )', 'xor %r12d , %r12d', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'mov %r12d , %eax', 'pop %rbx', 'pop %rbp', 'pop %r12', 'pop %r13', 'pop %r14', 'pop %r15', 'retq', 'nop', 'mov 0x ( %rip ) , %esi', 'cmp %esi , 0x ( %rax )', 'je 0x', 'mov $0x , %edx', 'mov 0x ( %rbx ) , %eax', 'test %edx , %edx', 'jne 0x', 'mov 0x ( %rbp ) , %rdx', 'mov 0x ( %rdx ) , %esi', 'cmp %esi , 0x ( %rbx )', 'je 0x', 'test %eax , %eax', 'je 0x', 'mov 0x ( %rbp ) , %rcx', 'xor %eax , %eax', 'lea 0x ( %rip ) , %rsi', 'mov %r14 , %rdx', 'mov $0x , %edi', 'callq 0x', 'xor %eax , %eax', 'mov $0x , %ecx', 'mov %r13 , %rdi', 'rep stos %rax , %es : ( %rdi )', 'movb $0x , 0x ( %rsp )', 'mov %r13 , %rsi', 'movabs $0x , %rax', 'mov %rax , 0x ( %rsp )', 'lea 0x ( %rip ) , %rdi', 'mov 0x ( %rbx ) , %eax', 'mov %ea ...
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/sbin/keepalived
# ----------
# func-signature:void netlink_link_del_vmac(vrrp_t *);
# func-return-type:void
# func-name:netlink_link_del_vmac
# func-filename:vrrp_vmac.c
# func-disassembly:['endbr64', 'push %r12', 'push %rbx', 'sub $0x , %rsp', 'mov 0x ( %rdi ) , %rdx', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'test %rdx , %rdx', 'je 0x', 'cmpb $0x , 0x ( %rdx )', 'je 0x', 'cmpw $0x , ( %rdi )', 'mov %rdi , %rbx', 'je 0x', 'mov 0x ( %rdx ) , %eax', 'test %eax , %eax', 'jne 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %r12', 'retq', 'nopl ( %rax )', 'mov %rsp , %rsi', 'xor %eax , %eax', 'lea 0x ( %rbx ) , %r12', 'mov $0x , %ecx', 'mov %rsi , %rdi', 'rep stos %rax , %es : ( %rdi )', 'movb $0x , 0x ( %rsp )', 'lea 0x ( %rip ) , %rdi', 'movabs $0x , %rax', 'mov %rax , ( %rsp )', 'mov 0x ( %rdx ) , %eax', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'test %rax , %rax', 'js 0x', 'testb $0x , 0x ( %rbx )', 'jne 0x', 'mov 0x ( %rbx ) , %rcx', 'mov %r12 , %rdx', 'lea 0x ( %rip ) , %rsi', 'xor %eax , %eax', 'mov $0x , %edi', 'callq 0x', 'jmpq 0x', 'nopl 0x ( %rax , %rax , 1 )', 'mov 0x ( %rdx ) , %rdi', 'test %rdi , %rdi', 'je 0x', 'callq 0x', 'mov 0x ( %rbx ) , %rdx', 'mov 0x ( %rdx ) , %eax', 'test %eax , %eax', 'je 0x', 'jmpq 0x', 'nopl ( %rax )', 'mov %rbx , %rdi', 'callq 0x', 'jmp 0x', 'nopw 0x ( %rax , %rax , 1 )', 'mov 0x ( %rbx ) , %rdx', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'callq 0x', 'mov 0x ( %rbx ) , %rdx', 'jmpq 0x', 'nopl 0x ( %rax , %rax , 1 )', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'callq 0x', 'jmpq 0x', 'nopw %cs : 0x ( %rax , %rax , 1 )', 'mov 0x ( %rbx ) , %rcx', 'mov %r12 , %rdx', 'lea 0x ( %rip ) , %rsi', 'xor %eax , %eax', 'mov $0x , %edi', 'callq 0x', 'jmpq 0x', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/sbin/keepalived
# ----------
# func-signature:_Bool replace_link_local_address(interface_t *);
# func-return-type:_Bool
# func-name:replace_link_local_address
# func-filename:vrrp_vmac.c
# func-disassembly:['endbr64', 'push %rbp', 'mov $0x , %ecx', 'movabs $0x , %rsi', 'mov $0x , %r8d', 'push %rbx', 'mov %rdi , %rbx', 'sub $0x , %rsp', 'mov 0x ( %rbx ) , %rdx', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'lea 0x ( %rsp ) , %rbp', 'movq $0x , ( %rsp )', 'movq $0x , 0x ( %rsp )', 'mov %rbp , %rdi', 'rep stos %rax , %es : ( %rdi )', 'mov ( %rsp ) , %rax', 'movabs $0x , %rcx', 'and %rcx , %rax', 'or $0x , %rax', 'mov %rax , ( %rsp )', 'movzbl 0x ( %rdx ) , %eax', 'xor $0x , %eax', 'mov %al , 0x ( %rsp )', 'movzwl 0x ( %rdx ) , %eax', 'shl $0x , %rax', 'mov %rax , %rcx', 'mov 0x ( %rsp ) , %rax', 'and $0x , %rax', 'or %rcx , %rax', 'movabs $0x , %rcx', 'and %rcx , %rax', 'movabs $0x , %rcx', 'or %rcx , %rax', 'movzbl 0x ( %rdx ) , %ecx', 'and %rsi , %rax', 'shl $0x , %rcx', 'or %rcx , %rax', 'mov %rax , 0x ( %rsp )', 'movdqa ( %rsp ) , %xmm0', 'pinsrw $0x , 0x ( %rdx ) , %xmm0', 'movaps %xmm0 , 0x ( %rsp )', 'mov 0x ( %rsp ) , %eax', 'mov 0x ( %rsp ) , %edx', 'xor 0x ( %rbx ) , %eax', 'xor 0x ( %rbx ) , %edx', 'or %edx , %eax', 'mov 0x ( %rsp ) , %rdx', 'movdqa 0x ( %rsp ) , %xmm1', 'or 0x ( %rbx ) , %eax', 'shr $0x , %rdx', 'xor 0x ( %rbx ) , %edx', 'movaps %xmm1 , ( %rsp )', 'or %edx , %eax', 'jne 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'mov %r8d , %eax', 'pop %rbx', 'pop %rbp', 'retq', 'nopw 0x ( %rax , %rax , 1 )', 'mov $0x , %eax', 'movdqu 0x ( %rbx ) , %xmm2', 'xor %esi , %esi', 'mov %rbp , %rdi', 'mov %ax , 0x ( %rsp )', 'mov 0x ( %rbx ) , %eax', 'mov %rbx , 0x ( %rsp )', 'mov %eax , 0x ( %rsp )', 'movups %xmm2 , 0x ( %rsp )', 'callq 0x', 'cmp $0x , %eax', 'je 0x', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'callq 0x', 'mov 0x ( %rsp ) , %rax', 'mov $0x , %esi', 'mov %rbp , %rdi', 'mov %eax , %eax', 'mov %rax , ( %rsp )', 'movdqa ( %rsp ) , %xmm3', 'movups %xmm3 , 0x ( %rsp )', 'callq 0x', 'cmp $0x , %eax', 'jne 0x', 'movdqu 0x ( %rsp ) , %xmm4', 'mov $0x , %r8d', 'movups %xmm4 , 0x ( %rbx )', 'jmpq 0x', 'nopw %cs : 0x ( %rax , %rax , 1 )', 'movl $0x , 0x ( %rbx )', 'jmp 0x', 'nopl 0x ( %rax )', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'callq 0x', 'movl $0x , 0x ( %rbx )', 'xor %r8d , %r8d', 'jmpq 0x', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/sbin/keepalived
# ----------
# func-signature:void update_vmac_vrfs(interface_t *);
# func-return-type:void
# func-name:update_vmac_vrfs
# func-filename:vrrp_vmac.c
# func-disassembly:['endbr64', 'mov 0x ( %rdi ) , %rax', 'test %rax , %rax', 'je 0x', 'push %rbp', 'mov %rdi , %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov ( %rax ) , %rbx', 'test %rbx , %rbx', 'jne 0x', 'jmp 0x', 'nopl 0x ( %rax , %rax , 1 )', 'mov ( %rbx ) , %rbx', 'test %rbx , %rbx', 'je 0x', 'mov 0x ( %rbx ) , %rax', 'mov 0x ( %rax ) , %rdi', 'cmp %rbp , 0x ( %rdi )', 'jne 0x', 'mov 0x ( %rdi ) , %rax', 'cmpb $0x , 0x ( %rax )', 'je 0x', 'mov 0x ( %rbp ) , %rdx', 'mov %rdx , 0x ( %rax )', 'mov 0x ( %rdi ) , %rax', 'mov 0x ( %rax ) , %eax', 'test %eax , %eax', 'je 0x', 'lea 0x ( %rdi ) , %rsi', 'add $0x , %rdi', 'callq 0x', 'mov ( %rbx ) , %rbx', 'test %rbx , %rbx', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'retq', 'retq']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/sbin/keepalived
# ----------
# func-signature:static int netlink_link_up(vrrp_t *);
# func-return-type:static int
# func-name:netlink_link_up
# func-filename:vrrp_vmac.c
# func-disassembly:['sub $0x , %rsp', 'pxor %xmm0 , %xmm0', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'movups %xmm0 , 0x ( %rsp )', 'mov %rsp , %rsi', 'movabs $0x , %rax', 'mov %rax , ( %rsp )', 'mov ( %rdi ) , %rax', 'lea 0x ( %rip ) , %rdi', 'movq $0x , 0x ( %rsp )', 'movb $0x , 0x ( %rsp )', 'mov 0x ( %rax ) , %eax', 'mov %eax , 0x ( %rsp )', 'movabs $0x , %rax', 'mov %rax , 0x ( %rsp )', 'callq 0x', 'sar $0x , %rax', 'or $0x , %eax', 'mov 0x ( %rsp ) , %rdx', 'xor %fs : 0x , %rdx', 'jne 0x', 'add $0x , %rsp', 'retq', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/sbin/keepalived
# ----------
# func-signature:static void netlink_update_vrf(vrrp_t *, vrrp_t *);
# func-return-type:static void
# func-name:netlink_update_vrf
# func-filename:vrrp_vmac.c
# func-disassembly:['push %r12', 'push %rbp', 'push %rbx', 'sub $0x , %rsp', 'mov ( %rsi ) , %rdx', 'mov %fs : 0x , %rax', 'mov %rax , 0x ( %rsp )', 'xor %eax , %eax', 'test %rdx , %rdx', 'je 0x', 'cmpb $0x , 0x ( %rdx )', 'je 0x', 'lea 0x ( %rsp ) , %rbp', 'xor %eax , %eax', 'mov %rdi , %r12', 'mov $0x , %ecx', 'mov %rbp , %rdi', 'mov %rsi , %rbx', 'rep stos %rax , %es : ( %rdi )', 'movb $0x , 0x ( %rsp )', 'movabs $0x , %rax', 'mov %rax , 0x ( %rsp )', 'mov 0x ( %rdx ) , %eax', 'mov 0x ( %rdx ) , %rdx', 'mov %eax , 0x ( %rsp )', 'xor %eax , %eax', 'test %rdx , %rdx', 'je 0x', 'mov 0x ( %rdx ) , %eax', 'lea 0x ( %rsp ) , %rcx', 'mov $0x , %edx', 'mov $0x , %esi', 'mov %rbp , %rdi', 'mov $0x , %r8d', 'mov %eax , 0x ( %rsp )', 'callq 0x', 'mov %rbp , %rsi', 'lea 0x ( %rip ) , %rdi', 'callq 0x', 'mov ( %r12 ) , %rcx', 'mov ( %rbx ) , %rdx', 'test %rax , %rax', 'js 0x', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'callq 0x', 'callq 0x', 'mov 0x ( %rsp ) , %rax', 'xor %fs : 0x , %rax', 'jne 0x', 'add $0x , %rsp', 'pop %rbx', 'pop %rbp', 'pop %r12', 'retq', 'xchg %ax , %ax', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'callq 0x', 'jmp 0x', 'nopl 0x ( %rax , %rax , 1 )', 'lea 0x ( %rip ) , %rsi', 'mov $0x , %edi', 'xor %eax , %eax', 'callq 0x', 'jmp 0x', 'callq 0x']
# ubuntu-package-name:keepalived
# ubuntu-package-binary:/usr/sbin/keepalived
# ----------

# %%
# Out:
# funclist:aaa
# funclist:bbbb
