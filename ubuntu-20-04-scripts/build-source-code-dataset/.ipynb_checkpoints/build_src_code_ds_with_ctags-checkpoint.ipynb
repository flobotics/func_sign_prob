# %%
###konclude, mysql*, ovn*, cmake


import subprocess
import pickle
import glob
import os
import pexpect

# %%
gcloud = False

# %%
def get_pickle_list(path):
    file_list = []
    file_list = glob.glob(path + '*.pickle.tar.bz2')
    #print(file_list)
    return file_list

# %%
def open_pickle(filename):
    #filename = "/tmp/test/tree.pickle"
    infile = open(filename,'rb')
    pickle_list = pickle.load(infile, encoding="latin1")
    infile.close()
    
    return pickle_list

# %%
def get_start_end_line_of_func(source_file, func_name, verbose=False):
    start = ''
    end = ''
    
    if verbose:
        print(f'source_file:{source_file} and func_name:{func_name}')
        
    #source_file = "/home/ubu/Documents/src-tree/tree-1.8.0/" + source_file

    ###ctags -x --c-kinds=f /home/ubu/Documents/src-tree/tree-1.8.0/color.c
    ctags_funcs = subprocess.run(['ctags',
                                 "-x",
                                 "--c-kinds=f",
                                 source_file],
                                capture_output=True,
                                universal_newlines=True)
    
    ctags_funcs_out = ctags_funcs.stdout
    ctags_funcs_out_split = ctags_funcs_out.split("\n")
    
    if verbose:
        #print(f'ctags_funcs_out:{ctags_funcs_out_split}')
        pass
    
    ### searching for function and get the start-line, to compare later with ctags output
    for ctags_funcs_split in ctags_funcs_out_split:
        #if verbose:
            #print(f'\n\nsplit:{ctags_funcs_split}  funcname:{func_name}')
        ctags_funcs_split_split = ctags_funcs_split.split()
        #print(f'split-split:{ctags_funcs_split_split}')
        if (len(ctags_funcs_split_split) >= 3) and (ctags_funcs_split_split[0] == func_name):
            #print(f'split-func:{ctags_funcs_split_split[2]}')
            start = ctags_funcs_split_split[2]
            if verbose:
                print(f'found >{func_name}< start-line >{start}<')
            break
      
    if start == '':
        print("func start-line not found-------------")
        return (start, end)
    
    ## ctags --fields=+ne -o - --sort=no tree.c|grep usage
    ctags = subprocess.run(["ctags", 
                                "--fields=+ne", 
                                "-o", 
                                "-", 
                                "--sort=no", 
                                source_file], 
                               capture_output=True, 
                               universal_newlines=True)

    ctags_out = ctags.stdout
    
    if verbose:
        #print(f'ctags_out: {ctags_out}')
        pass
        
    ctags_out_split = ctags_out.split('\n')
    
    for items in ctags_out_split:
        #print(f'items: {items}\n')
        if func_name in items:
            if verbose:
                print(f'func_name in items: {items}\n')
            if "line:" + start in items:
                if verbose:
                    print(f'start-line found, so end: should be here')
                for subItem in items.split():
                    if verbose:
                        print(f'subItem:{subItem}')
                    if "end:" in subItem:
                        end = subItem.replace('end:','')
                        if verbose:
                            print(f'found end-line:{end}')
                        return (start,end)

    
    return (start,end)

# %% [markdown]
# # get full path of a file inside a directory

# %%
def get_full_path(base_source_path, filename):
    #filename = 'format'
    out = subprocess.run(["find", base_source_path, "-type", "f", "-name", filename], capture_output=True, universal_newlines=True)
    find_out = out.stdout

    full_path = list()
    
    for file in find_out.split('\n')[0:-1]:
        full_path.append(file)
        
    return full_path

# %%
def get_source_code(src_file, func_name, gdb_func_sign):
    src_code = list()
    gdb_func_sign_ret_type = ''
    
    print(f'src_file:{src_file}')
    print(f'func_name:{func_name}')
    print(f'gdb_func_sign:{gdb_func_sign}')
    idx = gdb_func_sign.index('(')
        if idx:
            print('found gdb (')
            gdb_func_sign_ret_type = gdb_func_sign[:idx]
            print(f'gdb_func_sign_ret_type:{gdb_func_sign_ret_type}')
            
    
    start_end_lines = list()
    
    start, end = get_start_end_line_of_func(src_file, func_name, False)
    print(f'source-file: {src_file} func-name: {func_name} start:{start}   end:{end}')
    start_end_lines.append((src_file, func_name, start, end))

        
    ### now that we got start and end line numbers, we copy the src code
    ### we need to check here if we need to copy some lines above the start-line
    ### because ctags does not find the correct start line if return-type is above line
    if start and end:
        with open(src_file) as f:
            lines = [line.rstrip() for line in f]

        ##get first line ctags thinks
        first_line = lines[start]
        print(f'first_line:{first_line}')
        ### get return-type
        ## get first occurece of (
        idx = first_line.index('(')
        if idx:
            print(f'found (')
            pre_first_line = first_line[:idx]
            print(f'pre_first_line:{pre_first_line}')
            ### check if its full return type
            if gdb_func_sign_ret_type == pre_first_line:
                print('found full ret_type')
        
        
        
        
            
        l = 1
        for line in lines:
            if l >= int(start) and l <= int(end):
                #print(f'line:{l} content:{line}')
                src_code.append(line)
            l+=1
     
    return src_code
# Out:
#   File "<ipython-input-17-70ea1c557fa0>", line 9
#     if idx:
#     ^
# IndentationError: unexpected indent

# %%
def install_source_package(src_package):
    print(f'install_source_package: {src_package}')
    try:
        os.mkdir("/tmp/" + src_package)
    except OSError:
        print (f"Creation of the directory /tmp/{src_package} failed")
    else:
        print (f"Successfully created the directory /tmp/{src_package}")
    
        os.chdir("/tmp/" + src_package)

        ###install the package
        #child = pexpect.spawn('apt source -y {0}'.format(src_package), timeout=None)
        #if not gcloud:
        #    child.expect('ubu:', timeout=None)
            # enter the password
       #    child.sendline('ubu\n')
        #print(child.read())
        #tmp = child.read()
        
        out = subprocess.run(["apt", 
                          "source",
                          src_package],
                          capture_output=True, 
                          universal_newlines=True)
        gdb_out = out.stdout

# %%
def get_dirname_of_src(pickle_file_name):
    #print(f'get_dirname_of_src: {pickle_file_name}')
    src_dir_name = ''
    
    for file_ in os.listdir("/tmp/" + pickle_file_name):
        #print(f'file:{file_}')
        if os.path.isdir("/tmp/" + pickle_file_name + '/' + file_):
            #print(f'dir:{file_}')
            src_dir_name = file_
            
    return src_dir_name

# %%
def check_if_src_match_binary(pickle_file_name, dir_name):
            
    ###get inside src dir and exec gdb
    os.chdir("/tmp/" + pickle_file_name + '/' + dir_name)
    out = subprocess.run(["gdb", 
                          "-ex",
                          "file {}".format(pickle_file_name),
                          "-ex",
                          "info functions"],
                          capture_output=True, 
                          universal_newlines=True)
    gdb_out = out.stdout
    #print(f'gdb_out:{gdb_out}') 
    
    ### select the first file
    src_file = ''
    for line in gdb_out.split('\n'):
        linesplit = line.split()
        if (len(linesplit) >= 2) and linesplit[0] == 'File':
            print(f'found file: {linesplit[1]}')
            src_file = linesplit[1]
            break
        
    ## check how many times ../ tokens are there
    if src_file:
        nr_tokens = src_file.count('../')
        print(f'found ../ >{nr_tokens}< times')
        
    ### create as many dirs as nr_tokens
    import pathlib
    path_to_create = "/tmp/" + pickle_file_name + "/" + dir_name + "/"
    for i in range(nr_tokens):
        path_to_create = path_to_create + "aaaaa/"

    pathlib.Path(path_to_create).mkdir(parents=True, exist_ok=True)
    
    ### change to new dir
    os.chdir(path_to_create)
    
    src_file_base = os.path.basename(src_file)
    print(f'src_file_base:{src_file_base}')
    
    out = subprocess.run(["gdb", 
                          "-ex",
                          "file {}".format(pickle_file_name),
                          "-ex",
                          "list {}".format('glob_filename'),],
                          capture_output=True, 
                          universal_newlines=True)
    gdb_out = out.stdout
    gdb_stderr = out.stderr
    
    #print(f'gdb_stderr:{gdb_stderr}')
    #print(f'gdb_out:{gdb_out}')
    if "warning: Source file is more recent than executable." in gdb_stderr:
        print(f'src more recent than exe')  
        return False
    else:
        return True

#res = check_if_src_match_binary("bash", "bash-5.0")
#print(f'result:{res}')

# %%
def unpack_second_src(pickle_file_name):
    tarfile = ''
    tar_option = ''
    first_src_dir = ''
    
    ### check the ending e.g. .tar.bz2 .tar.gz .tar.xz
    for file_ in os.listdir("/tmp/" + pickle_file_name):
        #print(f'file:{file_}')
        if os.path.isfile("/tmp/" + pickle_file_name + '/' + file_):
            if "orig" in file_:
                print(f'file:{file_}')
                tarfile = file_
        if os.path.isdir("/tmp/" + pickle_file_name + '/' + file_):
            first_src_dir = file_
            
    tarfile_split = tarfile.split(".")
    if tarfile_split[-1] == "xz":
        print(f'found xz ending')
        tar_option = '-xJf'
    else:
        print(f'ERRROR no recognized ending')
        exit()
            
            
    ###remove first src folder, because name is (mostly??) the same of untarred pkg     
    #os.rmdir("/tmp/" + pickle_file_name + '/' + first_src_dir)
    os.rename("/tmp/" + pickle_file_name + '/' + first_src_dir, "/tmp/" + pickle_file_name + '/' + "backup-" + first_src_dir)

    print(f'tarfile:{tarfile} pickle_file_name:{pickle_file_name} tar_option:{tar_option}')    
        
    os.chdir("/tmp/" + pickle_file_name)
    out = subprocess.run(["tar",
                          tar_option,
                          tarfile], capture_output=True, universal_newlines=True)
    tar_out = out.stdout
    print(f'tar_out:{tar_out}')
    
    
#unpack_second_src("bash")

# %%
##### main
pickle_path = "/home/ubu/git/test2/func_sign_prob/ubuntu-20-04-pickles/"

#pickle_list = get_pickle_list(pickle_path)
#print(pickle_list)


pickle_list = ["/home/ubu/git/test2/func_sign_prob/ubuntu-20-04-pickles/slapd.pickle.tar.bz2"]

###loop through all pickle.tar.bz2 files
for pickle_file in pickle_list:
    print(f'Untar pickle-file:{pickle_file}')
    
    ###untar
    out = subprocess.run(["tar", 
                          "xjf",
                          pickle_file,
                          "-C",
                          pickle_path,
                          ], capture_output=True, universal_newlines=True)
    tar_out = out.stdout
    
    
    
    ###install source-package of pickle-file-content
    pickle_file_name = os.path.basename(pickle_file)
    pickle_file_name = pickle_file_name.replace('.pickle.tar.bz2', '')
    print(f'Install src pkg of:{pickle_file_name}')
    
    install_source_package(pickle_file_name)
    
    ###check with gdb (list cmd) if the sources are newer/older than binary
    ## warning: Source file is more recent than executable.
    ###get dir name
    dir_name = ''  
    dir_name = get_dirname_of_src(pickle_file_name)
    print(f'Dir with src is:{dir_name}')
    res = check_if_src_match_binary(pickle_file_name, dir_name)
    
    ##src and binary dont match, unpack the second src in the dir
    if not res:
        unpack_second_src(pickle_file_name)
        res = check_if_src_match_binary(pickle_file_name, dir_name)
        print(f'res of second src dir: {res}')
    else:
        print(f'src match binary')
    
    #break
    
    ###open the pickle
    print('Open untarred pickle file:{pickle_file}')
    pickle_content = open_pickle(pickle_file.replace('.tar.bz2', ''))
    
    fcn = ''
    fl = ''
    bina = ''
    gdb_func_sign = ''
    ### loop through the pickle-file and get source-code from function
    #print(f'pickle-content: {next(iter(pickle_content))}')
    for funcSign, gdb_ret_type, func_name, file_name, disas_att, disas_intel, package_name, binary in pickle_content:
        print(f'funcSign: {funcSign}')
        #print(f'gdb_ret_type: {gdb_ret_type}')
        print(f'func_name: {func_name}')
        print(f'file_name: {file_name}')
        #print(f'disas_att: {disas_att}')
        #print(f'disas_intel: {disas_intel}')
        print(f'package_name: {package_name}')
        print(f'binary: {binary}')
        fcn = func_name
        fl = file_name
        bina = binary
        gdb_func_sign = funcSign
        #break
    
        ### get source code of function
        pkg_name = pickle_file.replace('.pickle.tar.bz2', '')
        pkg_name = os.path.basename(pkg_name)
        print(f'pkg_name:{pkg_name}')

        pkg_src_name = "/tmp/" + pkg_name + "/" + dir_name
        print(f'pkg_src_name:{pkg_src_name}')

        full_path = get_full_path(pkg_src_name, fl)
        print(f'full-path:{full_path}')

        len_full_path = len(full_path)
        nr_of_empty_src_code = 0

        ### ctags does not get return-type if its located lines above func_name
        ### gdb funcSign got it, we need to check if we need more lines than ctags tells us
        for f in full_path:
            src_code = get_source_code(f, fcn, gdb_func_sign)
            if src_code:
                print(f'src-code:{src_code}')
            else:
                print(f'no src-code found')
                nr_of_empty_src_code += 1

        print(f'nr_of_empty_src_code:{nr_of_empty_src_code}   len_full_path:{len_full_path}')
        if len_full_path == nr_of_empty_src_code+1:
            print('only found one source code, thats good')
        else:
            print('ERROR found more than one source code for a function')
            break

    break
# Out:
# Untar pickle-file:/home/ubu/git/test2/func_sign_prob/ubuntu-20-04-pickles/slapd.pickle.tar.bz2
# Install src pkg of:slapd
# install_source_package: slapd
# Creation of the directory /tmp/slapd failed
# Dir with src is:openldap-2.4.49+dfsg
# found file: ../../../../../servers/slapd/back-ldif/ldif.c:
# found ../ >5< times
# src_file_base:ldif.c:
# src match binary
# Open untarred pickle file:{pickle_file}
# funcSign: unsigned int crc32(const void *, int);
# func_name: crc32
# file_name: ldif.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/servers/slapd/back-ldif/ldif.c', '/tmp/slapd/openldap-2.4.49+dfsg/libraries/libldap/ldif.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/servers/slapd/back-ldif/ldif.c
# func_name:crc32
# base_source_path:unsigned int crc32(const void *, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/servers/slapd/back-ldif/ldif.c func-name: crc32 start:394   end:409
# src-code:['crc32(const void *vbuf, int len)', '{', '\tconst unsigned char\t*buf = vbuf;', '\tber_uint_t\t\tcrc = 0xffffffff;', '', '\twhile (len > 7) {', '\t\tCRC8;', '\t\tlen -= 8;', '\t}', '\twhile (len) {', '\t\tCRC1;', '\t\tlen--;', '\t}', '', '\treturn crc ^ 0xffffffff;', '}']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/libldap/ldif.c
# func_name:crc32
# base_source_path:unsigned int crc32(const void *, int);
# func start-line not found-------------
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/libldap/ldif.c func-name: crc32 start:   end:
# no src-code found
# nr_of_empty_src_code:1   len_full_path:2
# only found one source code, thats good
# funcSign: int ldif_back_initialize(BackendInfo *);
# func_name: ldif_back_initialize
# file_name: ldif.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/servers/slapd/back-ldif/ldif.c', '/tmp/slapd/openldap-2.4.49+dfsg/libraries/libldap/ldif.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/servers/slapd/back-ldif/ldif.c
# func_name:ldif_back_initialize
# base_source_path:int ldif_back_initialize(BackendInfo *);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/servers/slapd/back-ldif/ldif.c func-name: ldif_back_initialize start:1870   end:1936
# src-code:['ldif_back_initialize( BackendInfo *bi )', '{', '\tstatic char *controls[] = {', '\t\tLDAP_CONTROL_MANAGEDSAIT,', '\t\tNULL', '\t};', '\tint rc;', '', '\tbi->bi_flags |=', '\t\tSLAP_BFLAG_INCREMENT |', '\t\tSLAP_BFLAG_REFERRALS;', '', '\tbi->bi_controls = controls;', '', '\tbi->bi_open = 0;', '\tbi->bi_close = 0;', '\tbi->bi_config = 0;', '\tbi->bi_destroy = 0;', '', '\tbi->bi_db_init = ldif_back_db_init;', '\tbi->bi_db_config = config_generic_wrapper;', '\tbi->bi_db_open = ldif_back_db_open;', '\tbi->bi_db_close = 0;', '\tbi->bi_db_destroy = ldif_back_db_destroy;', '', '\tbi->bi_op_bind = ldif_back_bind;', '\tbi->bi_op_unbind = 0;', '\tbi->bi_op_search = ldif_back_search;', '\tbi->bi_op_compare = 0;', '\tbi->bi_op_modify = ldif_back_modify;', '\tbi->bi_op_modrdn = ldif_back_modrdn;', '\tbi->bi_op_add = ldif_back_add;', '\tbi->bi_op_delete = ldif_back_delete;', '\tbi->bi_op_abandon = 0;', '', '\tbi->bi_extended = 0;', '', '\tbi->bi_chk_referrals = ldif_back_referrals;', '', '\tbi->bi_connection_init = 0;', '\tbi->bi_connection_destroy = 0;', '', '\tbi->bi_entry_get_rw = ldif_back_entry_get;', '', '#if 0\t/* NOTE: uncomment to completely disable access control */', '\tbi->bi_access_allowed = slap_access_always_allowed;', '#endif', '', '\tbi->bi_tool_entry_open = ldif_tool_entry_open;', '\tbi->bi_tool_entry_close = ldif_tool_entry_close;', '\tbi->bi_tool_entry_first = backend_tool_entry_first;', '\tbi->bi_tool_entry_first_x = ldif_tool_entry_first_x;', '\tbi->bi_tool_entry_next = ldif_tool_entry_next;', '\tbi->bi_tool_entry_get = ldif_tool_entry_get;', '\tbi->bi_tool_entry_put = ldif_tool_entry_put;', '\tbi->bi_tool_entry_reindex = 0;', '\tbi->bi_tool_sync = 0;', '', '\tbi->bi_tool_dn2id_get = 0;', '\tbi->bi_tool_entry_modify = 0;', '', '\tbi->bi_cf_ocs = ldifocs;', '', '\trc = config_register_schema( ldifcfg, ldifocs );', '\tif ( rc ) return rc;', '\treturn 0;', '}']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/libldap/ldif.c
# func_name:ldif_back_initialize
# base_source_path:int ldif_back_initialize(BackendInfo *);
# func start-line not found-------------
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/libldap/ldif.c func-name: ldif_back_initialize start:   end:
# no src-code found
# nr_of_empty_src_code:1   len_full_path:2
# only found one source code, thats good
# funcSign: int overlay_init(void);
# func_name: overlay_init
# file_name: overlays.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/servers/slapd/overlays/overlays.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/servers/slapd/overlays/overlays.c
# func_name:overlay_init
# base_source_path:int overlay_init(void);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/servers/slapd/overlays/overlays.c func-name: overlay_init start:29   end:44
# src-code:['overlay_init(void)', '{', '\tint i, rc = 0;', '', '\tfor ( i= 0 ; slap_oinfo[i].ov_type; i++ ) {', '\t\trc = slap_oinfo[i].ov_init();', '\t\tif ( rc ) {', '\t\t\tDebug( LDAP_DEBUG_ANY,', '\t\t\t\t"%s overlay setup failed, err %d\\n",', '\t\t\t\tslap_oinfo[i].ov_type, rc, 0 );', '\t\t\tbreak;', '\t\t}', '\t}', '', '\treturn rc;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: struct berval *UTF8bvnormalize(struct berval *, struct berval *, unsigned int, void *);
# func_name: UTF8bvnormalize
# file_name: ucstr.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c
# func_name:UTF8bvnormalize
# base_source_path:struct berval *UTF8bvnormalize(struct berval *, struct berval *, unsigned int, void *);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c func-name: UTF8bvnormalize start:105   end:303
# src-code:['struct berval * UTF8bvnormalize(', '\tstruct berval *bv,', '\tstruct berval *newbv,', '\tunsigned flags,', '\tvoid *ctx )', '{', '\tint i, j, len, clen, outpos, ucsoutlen, outsize, last;', '\tchar *out, *outtmp, *s;', '\tac_uint4 *ucs, *p, *ucsout;', '', '\tstatic unsigned char mask[] = {', '\t\t0, 0x7f, 0x1f, 0x0f, 0x07, 0x03, 0x01 };', '', '\tunsigned casefold = flags & LDAP_UTF8_CASEFOLD;', '\tunsigned approx = flags & LDAP_UTF8_APPROX;', '', '\tif ( bv == NULL ) {', '\t\treturn NULL;', '\t}', '', '\ts = bv->bv_val;', '\tlen = bv->bv_len;', '', '\tif ( len == 0 ) {', '\t\treturn ber_dupbv_x( newbv, bv, ctx );', '\t}', '', '\tif ( !newbv ) {', '\t\tnewbv = ber_memalloc_x( sizeof(struct berval), ctx );', '\t\tif ( !newbv ) return NULL;', '\t}', '', '\t/* Should first check to see if string is already in proper', '\t * normalized form. This is almost as time consuming as', '\t * the normalization though.', '\t */', '', '\t/* finish off everything up to character before first non-ascii */', '\tif ( LDAP_UTF8_ISASCII( s ) ) {', '\t\tif ( casefold ) {', '\t\t\toutsize = len + 7;', '\t\t\tout = (char *) ber_memalloc_x( outsize, ctx );', '\t\t\tif ( out == NULL ) {', '\t\t\t\treturn NULL;', '\t\t\t}', '\t\t\toutpos = 0;', '', '\t\t\tfor ( i = 1; (i < len) && LDAP_UTF8_ISASCII(s + i); i++ ) {', '\t\t\t\tout[outpos++] = TOLOWER( s[i-1] );', '\t\t\t}', '\t\t\tif ( i == len ) {', '\t\t\t\tout[outpos++] = TOLOWER( s[len-1] );', "\t\t\t\tout[outpos] = '\\0';", '\t\t\t\tnewbv->bv_val = out;', '\t\t\t\tnewbv->bv_len = outpos;', '\t\t\t\treturn newbv;', '\t\t\t}', '\t\t} else {', '\t\t\tfor ( i = 1; (i < len) && LDAP_UTF8_ISASCII(s + i); i++ ) {', '\t\t\t\t/* empty */', '\t\t\t}', '', '\t\t\tif ( i == len ) {', '\t\t\t\treturn ber_str2bv_x( s, len, 1, newbv, ctx );', '\t\t\t}', '', '\t\t\toutsize = len + 7;', '\t\t\tout = (char *) ber_memalloc_x( outsize, ctx );', '\t\t\tif ( out == NULL ) {', '\t\t\t\treturn NULL;', '\t\t\t}', '\t\t\toutpos = i - 1;', '\t\t\tmemcpy(out, s, outpos);', '\t\t}', '\t} else {', '\t\toutsize = len + 7;', '\t\tout = (char *) ber_memalloc_x( outsize, ctx );', '\t\tif ( out == NULL ) {', '\t\t\treturn NULL;', '\t\t}', '\t\toutpos = 0;', '\t\ti = 0;', '\t}', '', '\tp = ucs = ber_memalloc_x( len * sizeof(*ucs), ctx );', '\tif ( ucs == NULL ) {', '\t\tber_memfree_x(out, ctx);', '\t\treturn NULL;', '\t}', '', '\t/* convert character before first non-ascii to ucs-4 */', '\tif ( i > 0 ) {', '\t\t*p = casefold ? TOLOWER( s[i-1] ) : s[i-1];', '\t\tp++;', '\t}', '', '\t/* s[i] is now first non-ascii character */', '\tfor (;;) {', '\t\t/* s[i] is non-ascii */', '\t\t/* convert everything up to next ascii to ucs-4 */', '\t\twhile ( i < len ) {', '\t\t\tclen = LDAP_UTF8_CHARLEN2( s + i, clen );', '\t\t\tif ( clen == 0 ) {', '\t\t\t\tber_memfree_x( ucs, ctx );', '\t\t\t\tber_memfree_x( out, ctx );', '\t\t\t\treturn NULL;', '\t\t\t}', '\t\t\tif ( clen == 1 ) {', '\t\t\t\t/* ascii */', '\t\t\t\tbreak;', '\t\t\t}', '\t\t\t*p = s[i] & mask[clen];', '\t\t\ti++;', '\t\t\tfor( j = 1; j < clen; j++ ) {', '\t\t\t\tif ( (s[i] & 0xc0) != 0x80 ) {', '\t\t\t\t\tber_memfree_x( ucs, ctx );', '\t\t\t\t\tber_memfree_x( out, ctx );', '\t\t\t\t\treturn NULL;', '\t\t\t\t}', '\t\t\t\t*p <<= 6;', '\t\t\t\t*p |= s[i] & 0x3f;', '\t\t\t\ti++;', '\t\t\t}', '\t\t\tif ( casefold ) {', '\t\t\t\t*p = uctolower( *p );', '\t\t\t}', '\t\t\tp++;', '\t\t}', '\t\t/* normalize ucs of length p - ucs */', '\t\tuccompatdecomp( ucs, p - ucs, &ucsout, &ucsoutlen, ctx );', '\t\tif ( approx ) {', '\t\t\tfor ( j = 0; j < ucsoutlen; j++ ) {', '\t\t\t\tif ( ucsout[j] < 0x80 ) {', '\t\t\t\t\tout[outpos++] = ucsout[j];', '\t\t\t\t}', '\t\t\t}', '\t\t} else {', '\t\t\tucsoutlen = uccanoncomp( ucsout, ucsoutlen );', '\t\t\t/* convert ucs to utf-8 and store in out */', '\t\t\tfor ( j = 0; j < ucsoutlen; j++ ) {', '\t\t\t\t/* allocate more space if not enough room for', '\t\t\t\t   6 bytes and terminator */', '\t\t\t\tif ( outsize - outpos < 7 ) {', '\t\t\t\t\toutsize  ...
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int UTF8bvnormcmp(struct berval *, struct berval *, unsigned int, void *);
# func_name: UTF8bvnormcmp
# file_name: ucstr.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c
# func_name:UTF8bvnormcmp
# base_source_path:int UTF8bvnormcmp(struct berval *, struct berval *, unsigned int, void *);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c func-name: UTF8bvnormcmp start:307   end:454
# src-code:['int UTF8bvnormcmp(', '\tstruct berval *bv1,', '\tstruct berval *bv2,', '\tunsigned flags,', '\tvoid *ctx )', '{', '\tint i, l1, l2, len, ulen, res = 0;', '\tchar *s1, *s2, *done;', '\tac_uint4 *ucs, *ucsout1, *ucsout2;', '', '\tunsigned casefold = flags & LDAP_UTF8_CASEFOLD;', '\tunsigned norm1 = flags & LDAP_UTF8_ARG1NFC;', '\tunsigned norm2 = flags & LDAP_UTF8_ARG2NFC;', '', '\tif (bv1 == NULL) {', '\t\treturn bv2 == NULL ? 0 : -1;', '', '\t} else if (bv2 == NULL) {', '\t\treturn 1;', '\t}', '', '\tl1 = bv1->bv_len;', '\tl2 = bv2->bv_len;', '', '\tlen = (l1 < l2) ? l1 : l2;', '\tif (len == 0) {', '\t\treturn l1 == 0 ? (l2 == 0 ? 0 : -1) : 1;', '\t}', '', '\ts1 = bv1->bv_val;', '\ts2 = bv2->bv_val;', '\tdone = s1 + len;', '', '\twhile ( (s1 < done) && LDAP_UTF8_ISASCII(s1) && LDAP_UTF8_ISASCII(s2) ) {', '\t\tif (casefold) {', '\t\t\tchar c1 = TOLOWER(*s1);', '\t\t\tchar c2 = TOLOWER(*s2);', '\t\t\tres = c1 - c2;', '\t\t} else {', '\t\t\tres = *s1 - *s2;', '\t\t}', '\t\ts1++;', '\t\ts2++;', '\t\tif (res) {', '\t\t\t/* done unless next character in s1 or s2 is non-ascii */', '\t\t\tif (s1 < done) {', '\t\t\t\tif (!LDAP_UTF8_ISASCII(s1) || !LDAP_UTF8_ISASCII(s2)) {', '\t\t\t\t\tbreak;', '\t\t\t\t}', '\t\t\t} else if (((len < l1) && !LDAP_UTF8_ISASCII(s1)) ||', '\t\t\t\t((len < l2) && !LDAP_UTF8_ISASCII(s2)))', '\t\t\t{', '\t\t\t\tbreak;', '\t\t\t}', '\t\t\treturn res;', '\t\t}', '\t}', '', '\t/* We have encountered non-ascii or strings equal up to len */', '', '\t/* set i to number of iterations */', '\ti = s1 - done + len;', '\t/* passed through loop at least once? */', '\tif (i > 0) {', '\t\tif (!res && (s1 == done) &&', '\t\t    ((len == l1) || LDAP_UTF8_ISASCII(s1)) &&', '\t\t    ((len == l2) || LDAP_UTF8_ISASCII(s2))) {', '\t\t\t/* all ascii and equal up to len */', '\t\t\treturn l1 - l2;', '\t\t}', '', '\t\t/* rewind one char, and do normalized compare from there */', '\t\ts1--;', '\t\ts2--;', '\t\tl1 -= i - 1;', '\t\tl2 -= i - 1;', '\t}', '', '\t/* Should first check to see if strings are already in', '\t * proper normalized form.', '\t */', '\tucs = malloc( ( ( norm1 || l1 > l2 ) ? l1 : l2 ) * sizeof(*ucs) );', '\tif ( ucs == NULL ) {', '\t\treturn l1 > l2 ? 1 : -1; /* what to do??? */', '\t}', '', '\t/*', '\t * XXYYZ: we convert to ucs4 even though -llunicode', '\t * expects ucs2 in an ac_uint4', '\t */', '', '\t/* convert and normalize 1st string */', '\tfor ( i = 0, ulen = 0; i < l1; i += len, ulen++ ) {', '\t\tucs[ulen] = ldap_x_utf8_to_ucs4( s1 + i );', '\t\tif ( ucs[ulen] == LDAP_UCS4_INVALID ) {', '\t\t\tfree( ucs );', '\t\t\treturn -1; /* what to do??? */', '\t\t}', '\t\tlen = LDAP_UTF8_CHARLEN( s1 + i );', '\t}', '', '\tif ( norm1 ) {', '\t\tucsout1 = ucs;', '\t\tl1 = ulen;', '\t\tucs = malloc( l2 * sizeof(*ucs) );', '\t\tif ( ucs == NULL ) {', '\t\t\tfree( ucsout1 );', '\t\t\treturn l1 > l2 ? 1 : -1; /* what to do??? */', '\t\t}', '\t} else {', '\t\tuccompatdecomp( ucs, ulen, &ucsout1, &l1, ctx );', '\t\tl1 = uccanoncomp( ucsout1, l1 );', '\t}', '', '\t/* convert and normalize 2nd string */', '\tfor ( i = 0, ulen = 0; i < l2; i += len, ulen++ ) {', '\t\tucs[ulen] = ldap_x_utf8_to_ucs4( s2 + i );', '\t\tif ( ucs[ulen] == LDAP_UCS4_INVALID ) {', '\t\t\tfree( ucsout1 );', '\t\t\tfree( ucs );', '\t\t\treturn 1; /* what to do??? */', '\t\t}', '\t\tlen = LDAP_UTF8_CHARLEN( s2 + i );', '\t}', '', '\tif ( norm2 ) {', '\t\tucsout2 = ucs;', '\t\tl2 = ulen;', '\t} else {', '\t\tuccompatdecomp( ucs, ulen, &ucsout2, &l2, ctx );', '\t\tl2 = uccanoncomp( ucsout2, l2 );', '\t\tfree( ucs );', '\t}', '', '\tres = casefold', '\t\t? ucstrncasecmp( ucsout1, ucsout2, l1 < l2 ? l1 : l2 )', '\t\t: ucstrncmp( ucsout1, ucsout2, l1 < l2 ? l1 : l2 );', '\tfree( ucsout1 );', '\tfree( ucsout2 );', '', '\tif ( res != 0 ) {', '\t\treturn res;', '\t}', '\tif ( l1 == l2 ) {', '\t\treturn 0;', '\t}', '\treturn l1 > l2 ? 1 : -1;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: void ucstr2upper(ldap_unicode_t *, ber_len_t);
# func_name: ucstr2upper
# file_name: ucstr.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c
# func_name:ucstr2upper
# base_source_path:void ucstr2upper(ldap_unicode_t *, ber_len_t);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c func-name: ucstr2upper start:96   end:103
# src-code:['void ucstr2upper(', '\tldap_unicode_t *u,', '\tber_len_t n )', '{', '\tfor(; 0 < n; ++u, --n ) {', '\t\t*u = uctoupper( *u );', '\t}', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: ldap_unicode_t *ucstrncasechr(const ldap_unicode_t *, ber_len_t, ldap_unicode_t);
# func_name: ucstrncasechr
# file_name: ucstr.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c
# func_name:ucstrncasechr
# base_source_path:ldap_unicode_t *ucstrncasechr(const ldap_unicode_t *, ber_len_t, ldap_unicode_t);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c func-name: ucstrncasechr start:81   end:94
# src-code:['ldap_unicode_t * ucstrncasechr(', '\tconst ldap_unicode_t *u,', '\tber_len_t n,', '\tldap_unicode_t c )', '{', '\tc = uctolower( c );', '\tfor(; 0 < n; ++u, --n ) {', '\t\tif( uctolower( *u ) == c ) {', '\t\t\treturn (ldap_unicode_t *) u;', '\t\t}', '\t}', '', '\treturn NULL;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int ucstrncasecmp(const ldap_unicode_t *, const ldap_unicode_t *, ber_len_t);
# func_name: ucstrncasecmp
# file_name: ucstr.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c
# func_name:ucstrncasecmp
# base_source_path:int ucstrncasecmp(const ldap_unicode_t *, const ldap_unicode_t *, ber_len_t);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c func-name: ucstrncasecmp start:48   end:65
# src-code:['int ucstrncasecmp(', '\tconst ldap_unicode_t *u1,', '\tconst ldap_unicode_t *u2,', '\tber_len_t n )', '{', '\tfor(; 0 < n; ++u1, ++u2, --n ) {', '\t\tldap_unicode_t uu1 = uctolower( *u1 );', '\t\tldap_unicode_t uu2 = uctolower( *u2 );', '', '\t\tif( uu1 != uu2 ) {', '\t\t\treturn uu1 < uu2 ? -1 : +1;', '\t\t}', '\t\tif ( uu1 == 0 ) {', '\t\t\treturn 0;', '\t\t}', '\t}', '\treturn 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: ldap_unicode_t *ucstrnchr(const ldap_unicode_t *, ber_len_t, ldap_unicode_t);
# func_name: ucstrnchr
# file_name: ucstr.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c
# func_name:ucstrnchr
# base_source_path:ldap_unicode_t *ucstrnchr(const ldap_unicode_t *, ber_len_t, ldap_unicode_t);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c func-name: ucstrnchr start:67   end:79
# src-code:['ldap_unicode_t * ucstrnchr(', '\tconst ldap_unicode_t *u,', '\tber_len_t n,', '\tldap_unicode_t c )', '{', '\tfor(; 0 < n; ++u, --n ) {', '\t\tif( *u == c ) {', '\t\t\treturn (ldap_unicode_t *) u;', '\t\t}', '\t}', '', '\treturn NULL;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int ucstrncmp(const ldap_unicode_t *, const ldap_unicode_t *, ber_len_t);
# func_name: ucstrncmp
# file_name: ucstr.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c
# func_name:ucstrncmp
# base_source_path:int ucstrncmp(const ldap_unicode_t *, const ldap_unicode_t *, ber_len_t);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblunicode/ucstr.c func-name: ucstrncmp start:32   end:46
# src-code:['int ucstrncmp(', '\tconst ldap_unicode_t *u1,', '\tconst ldap_unicode_t *u2,', '\tber_len_t n )', '{', '\tfor(; 0 < n; ++u1, ++u2, --n ) {', '\t\tif( *u1 != *u2 ) {', '\t\t\treturn *u1 < *u2 ? -1 : +1;', '\t\t}', '\t\tif ( *u1 == 0 ) {', '\t\t\treturn 0;', '\t\t}', '\t}', '\treturn 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int avl_apply(Avlnode *, AVL_APPLY, void *, int, int);
# func_name: avl_apply
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_apply
# base_source_path:int avl_apply(Avlnode *, AVL_APPLY, void *, int, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_apply start:420   end:435
# src-code:['avl_apply( Avlnode *root, AVL_APPLY fn, void* arg, int stopflag, int type )', '{', '\tswitch ( type ) {', '\tcase AVL_INORDER:', '\t\treturn( avl_inapply( root, fn, arg, stopflag ) );', '\tcase AVL_PREORDER:', '\t\treturn( avl_preapply( root, fn, arg, stopflag ) );', '\tcase AVL_POSTORDER:', '\t\treturn( avl_postapply( root, fn, arg, stopflag ) );', '\tdefault:', '\t\tfprintf( stderr, "Invalid traversal type %d\\n", type );', '\t\treturn( -1 );', '\t}', '', '\t/* NOTREACHED */', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: void *avl_delete(Avlnode **, void *, AVL_CMP);
# func_name: avl_delete
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_delete
# base_source_path:void *avl_delete(Avlnode **, void *, AVL_CMP);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_delete start:181   end:350
# src-code:['avl_delete( Avlnode **root, void* data, AVL_CMP fcmp )', '{', '\tAvlnode *p, *q, *r, *top;', '\tint side, side_bf, shorter, nside;', '', '\t/* parent stack */', '\tAvlnode *pptr[MAX_TREE_DEPTH];', '\tunsigned char pdir[MAX_TREE_DEPTH];', '\tint depth = 0;', '', '\tif ( *root == NULL )', '\t\treturn NULL;', '', '\tp = *root;', '', '\twhile (1) {', '\t\tside = fcmp( data, p->avl_data );', '\t\tif ( !side )', '\t\t\tbreak;', '\t\tside = ( side > 0 );', '\t\tpdir[depth] = side;', '\t\tpptr[depth++] = p;', '', '\t\tp = p->avl_link[side];', '\t\tif ( p == NULL )', '\t\t\treturn p;', '\t}', '  \tdata = p->avl_data;', '', '\t/* If this node has two children, swap so we are deleting a node with', '\t * at most one child.', '\t */', '\tif ( p->avl_link[0] && p->avl_link[1] ) {', '', '\t\t/* find the immediate predecessor <q> */', '\t\tq = p->avl_link[0];', '\t\tside = depth;', '\t\tpdir[depth++] = 0;', '\t\twhile (q->avl_link[1]) {', '\t\t\tpdir[depth] = 1;', '\t\t\tpptr[depth++] = q;', '\t\t\tq = q->avl_link[1];', '\t\t}', '\t\t/* swap links */', '\t\tr = p->avl_link[0];', '\t\tp->avl_link[0] = q->avl_link[0];', '\t\tq->avl_link[0] = r;', '', '\t\tq->avl_link[1] = p->avl_link[1];', '\t\tp->avl_link[1] = NULL;', '', '\t\tq->avl_bf = p->avl_bf;', '', '\t\t/* fix stack positions: old parent of p points to q */', '\t\tpptr[side] = q;', '\t\tif ( side ) {', '\t\t\tr = pptr[side-1];', '\t\t\tr->avl_link[pdir[side-1]] = q;', '\t\t} else {', '\t\t\t*root = q;', '\t\t}', '\t\t/* new parent of p points to p */', '\t\tif ( depth-side > 1 ) {', '\t\t\tr = pptr[depth-1];', '\t\t\tr->avl_link[1] = p;', '\t\t} else {', '\t\t\tq->avl_link[0] = p;', '\t\t}', '\t}', '', '\t/* now <p> has at most one child, get it */', '\tq = p->avl_link[0] ? p->avl_link[0] : p->avl_link[1];', '', '\tber_memfree( p );', '', '\tif ( !depth ) {', '\t\t*root = q;', '\t\treturn data;', '\t}', '', "\t/* set the child into p's parent */", '\tdepth--;', '\tp = pptr[depth];', '\tside = pdir[depth];', '\tp->avl_link[side] = q;', '', '\ttop = NULL;', '\tshorter = 1;', '', '\twhile ( shorter ) {', '\t\tp = pptr[depth];', '\t\tside = pdir[depth];', '\t\tnside = !side;', '\t\tside_bf = avl_bfs[side];', '', '\t\t/* case 1: height unchanged */', '\t\tif ( p->avl_bf == EH ) {', '\t\t\t/* Tree is now heavier on opposite side */', '\t\t\tp->avl_bf = avl_bfs[nside];', '\t\t\tshorter = 0;', '', '\t\t} else if ( p->avl_bf == side_bf ) {', '\t\t/* case 2: taller subtree shortened, height reduced */', '\t\t\tp->avl_bf = EH;', '\t\t} else {', '\t\t/* case 3: shorter subtree shortened */', '\t\t\tif ( depth )', '\t\t\t\ttop = pptr[depth-1]; /* p->parent; */', '\t\t\telse', '\t\t\t\ttop = NULL;', '\t\t\t/* set <q> to the taller of the two subtrees of <p> */', '\t\t\tq = p->avl_link[nside];', '\t\t\tif ( q->avl_bf == EH ) {', '\t\t\t\t/* case 3a: height unchanged, single rotate */', '\t\t\t\tp->avl_link[nside] = q->avl_link[side];', '\t\t\t\tq->avl_link[side] = p;', '\t\t\t\tshorter = 0;', '\t\t\t\tq->avl_bf = side_bf;', '\t\t\t\tp->avl_bf = (- side_bf);', '', '\t\t\t} else if ( q->avl_bf == p->avl_bf ) {', '\t\t\t\t/* case 3b: height reduced, single rotate */', '\t\t\t\tp->avl_link[nside] = q->avl_link[side];', '\t\t\t\tq->avl_link[side] = p;', '\t\t\t\tshorter = 1;', '\t\t\t\tq->avl_bf = EH;', '\t\t\t\tp->avl_bf = EH;', '', '\t\t\t} else {', '\t\t\t\t/* case 3c: height reduced, balance factors opposite */', '\t\t\t\tr = q->avl_link[side];', '\t\t\t\tq->avl_link[side] = r->avl_link[nside];', '\t\t\t\tr->avl_link[nside] = q;', '', '\t\t\t\tp->avl_link[nside] = r->avl_link[side];', '\t\t\t\tr->avl_link[side] = p;', '', '\t\t\t\tif ( r->avl_bf == side_bf ) {', '\t\t\t\t\tq->avl_bf = (- side_bf);', '\t\t\t\t\tp->avl_bf = EH;', '\t\t\t\t} else if ( r->avl_bf == (- side_bf)) {', '\t\t\t\t\tq->avl_bf = EH;', '\t\t\t\t\tp->avl_bf = side_bf;', '\t\t\t\t} else {', '\t\t\t\t\tq->avl_bf = EH;', '\t\t\t\t\tp->avl_bf = EH;', '\t\t\t\t}', '\t\t\t\tr->avl_bf = EH;', '\t\t\t\tq = r;', '\t\t\t}', '\t\t\ ...
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int avl_dup_error(void *, void *);
# func_name: avl_dup_error
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_dup_error
# base_source_path:int avl_dup_error(void *, void *);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_dup_error start:660   end:663
# src-code:['avl_dup_error( void* left, void* right )', '{', '\treturn( -1 );', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int avl_dup_ok(void *, void *);
# func_name: avl_dup_ok
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_dup_ok
# base_source_path:int avl_dup_ok(void *, void *);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_dup_ok start:666   end:669
# src-code:['avl_dup_ok( void* left, void* right )', '{', '\treturn( 0 );', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: void *avl_find(Avlnode *, const void *, AVL_CMP);
# func_name: avl_find
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_find
# base_source_path:void *avl_find(Avlnode *, const void *, AVL_CMP);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_find start:541   end:551
# src-code:['avl_find( Avlnode *root, const void* data, AVL_CMP fcmp )', '{', '\tint\tcmp;', '', '\twhile ( root != 0 && (cmp = (*fcmp)( data, root->avl_data )) != 0 ) {', '\t\tcmp = cmp > 0;', '\t\troot = root->avl_link[cmp];', '\t}', '', '\treturn( root ? root->avl_data : 0 );', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: Avlnode *avl_find2(Avlnode *, const void *, AVL_CMP);
# func_name: avl_find2
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_find2
# base_source_path:Avlnode *avl_find2(Avlnode *, const void *, AVL_CMP);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_find2 start:529   end:538
# src-code:['avl_find2( Avlnode *root, const void *data, AVL_CMP fcmp )', '{', '\tint\tcmp;', '', '\twhile ( root != 0 && (cmp = (*fcmp)( data, root->avl_data )) != 0 ) {', '\t\tcmp = cmp > 0;', '\t\troot = root->avl_link[cmp];', '\t}', '\treturn root;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: void *avl_find_lin(Avlnode *, const void *, AVL_CMP);
# func_name: avl_find_lin
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_find_lin
# base_source_path:void *avl_find_lin(Avlnode *, const void *, AVL_CMP);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_find_lin start:561   end:580
# src-code:['avl_find_lin( Avlnode *root, const void* data, AVL_CMP fcmp )', '{', '\tvoid*\tres;', '', '\tif ( root == 0 )', '\t\treturn( NULL );', '', '\tif ( (*fcmp)( data, root->avl_data ) == 0 )', '\t\treturn( root->avl_data );', '', '\tif ( root->avl_left != 0 )', '\t\tif ( (res = avl_find_lin( root->avl_left, data, fcmp ))', '\t\t    != NULL )', '\t\t\treturn( res );', '', '\tif ( root->avl_right == 0 )', '\t\treturn( NULL );', '\telse', '\t\treturn( avl_find_lin( root->avl_right, data, fcmp ) );', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int avl_free(Avlnode *, AVL_FREE);
# func_name: avl_free
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_free
# base_source_path:int avl_free(Avlnode *, AVL_FREE);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_free start:500   end:519
# src-code:['avl_free( Avlnode *root, AVL_FREE dfree )', '{', '\tint\tnleft, nright;', '', '\tif ( root == 0 )', '\t\treturn( 0 );', '', '\tnleft = nright = 0;', '\tif ( root->avl_left != 0 )', '\t\tnleft = avl_free( root->avl_left, dfree );', '', '\tif ( root->avl_right != 0 )', '\t\tnright = avl_free( root->avl_right, dfree );', '', '\tif ( dfree )', '\t\t(*dfree)( root->avl_data );', '\tber_memfree( root );', '', '\treturn( nleft + nright + 1 );', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: void *avl_getfirst(Avlnode *);
# func_name: avl_getfirst
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_getfirst
# base_source_path:void *avl_getfirst(Avlnode *);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_getfirst start:624   end:639
# src-code:['avl_getfirst( Avlnode *root )', '{', '\tif ( avl_list ) {', '\t\tber_memfree( (char *) avl_list);', '\t\tavl_list = (void* *) 0;', '\t}', '\tavl_maxlist = 0;', '\tavl_nextlist = 0;', '', '\tif ( root == 0 )', '\t\treturn( 0 );', '', '\t(void) avl_apply( root, avl_buildlist, (void*) 0, -1, AVL_INORDER );', '', '\treturn( avl_list[ avl_nextlist++ ] );', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: void *avl_getnext(void);
# func_name: avl_getnext
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_getnext
# base_source_path:void *avl_getnext(void);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_getnext start:642   end:654
# src-code:['avl_getnext( void )', '{', '\tif ( avl_list == 0 )', '\t\treturn( 0 );', '', '\tif ( avl_nextlist == avl_maxlist ) {', '\t\tber_memfree( (void*) avl_list);', '\t\tavl_list = (void* *) 0;', '\t\treturn( 0 );', '\t}', '', '\treturn( avl_list[ avl_nextlist++ ] );', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int avl_insert(Avlnode **, void *, AVL_CMP, AVL_DUP);
# func_name: avl_insert
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_insert
# base_source_path:int avl_insert(Avlnode **, void *, AVL_CMP, AVL_DUP);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_insert start:73   end:178
# src-code:['avl_insert( Avlnode ** root, void *data, AVL_CMP fcmp, AVL_DUP fdup )', '{', '    Avlnode *t, *p, *s, *q, *r;', '    int a, cmp, ncmp;', '', '\tif ( *root == NULL ) {', '\t\tif (( r = (Avlnode *) ber_memalloc( sizeof( Avlnode ))) == NULL ) {', '\t\t\treturn( -1 );', '\t\t}', '\t\tr->avl_link[0] = r->avl_link[1] = NULL;', '\t\tr->avl_data = data;', '\t\tr->avl_bf = EH;', '\t\t*root = r;', '', '\t\treturn( 0 );', '\t}', '', '    t = NULL;', '    s = p = *root;', '', '\t/* find insertion point */', '    while (1) {', '\t\tcmp = fcmp( data, p->avl_data );', '\t\tif ( cmp == 0 )', '\t\t\treturn (*fdup)( p->avl_data, data );', '', '\t\tcmp = (cmp > 0);', '\t\tq = p->avl_link[cmp];', '\t\tif (q == NULL) {', '\t\t\t/* insert */', '\t\t\tif (( q = (Avlnode *) ber_memalloc( sizeof( Avlnode ))) == NULL ) {', '\t\t\t\treturn( -1 );', '\t\t\t}', '\t\t\tq->avl_link[0] = q->avl_link[1] = NULL;', '\t\t\tq->avl_data = data;', '\t\t\tq->avl_bf = EH;', '', '\t\t\tp->avl_link[cmp] = q;', '\t\t\tbreak;', '\t\t} else if ( q->avl_bf ) {', '\t\t\tt = p;', '\t\t\ts = q;', '\t\t}', '\t\tp = q;', '    }', '', '    /* adjust balance factors */', '    cmp = fcmp( data, s->avl_data ) > 0;', '\tr = p = s->avl_link[cmp];', '\ta = avl_bfs[cmp];', '', '\twhile ( p != q ) {', '\t\tcmp = fcmp( data, p->avl_data ) > 0;', '\t\tp->avl_bf = avl_bfs[cmp];', '\t\tp = p->avl_link[cmp];', '\t}', '', '\t/* checks and balances */', '', '\tif ( s->avl_bf == EH ) {', '\t\ts->avl_bf = a;', '\t\treturn 0;', '\t} else if ( s->avl_bf == -a ) {', '\t\ts->avl_bf = EH;', '\t\treturn 0;', '    } else if ( s->avl_bf == a ) {', '\t\tcmp = (a > 0);', '\t\tncmp = !cmp;', '\t\tif ( r->avl_bf == a ) {', '\t\t\t/* single rotation */', '\t\t\tp = r;', '\t\t\ts->avl_link[cmp] = r->avl_link[ncmp];', '\t\t\tr->avl_link[ncmp] = s;', '\t\t\ts->avl_bf = 0;', '\t\t\tr->avl_bf = 0;', '\t\t} else if ( r->avl_bf == -a ) {', '\t\t\t/* double rotation */', '\t\t\tp = r->avl_link[ncmp];', '\t\t\tr->avl_link[ncmp] = p->avl_link[cmp];', '\t\t\tp->avl_link[cmp] = r;', '\t\t\ts->avl_link[cmp] = p->avl_link[ncmp];', '\t\t\tp->avl_link[ncmp] = s;', '', '\t\t\tif ( p->avl_bf == a ) {', '\t\t\t\ts->avl_bf = -a;', '\t\t\t\tr->avl_bf = 0;', '\t\t\t} else if ( p->avl_bf == -a ) {', '\t\t\t\ts->avl_bf = 0;', '\t\t\t\tr->avl_bf = a;', '\t\t\t} else {', '\t\t\t\ts->avl_bf = 0;', '\t\t\t\tr->avl_bf = 0;', '\t\t\t}', '\t\t\tp->avl_bf = 0;', '\t\t}', '\t\t/* Update parent */', '\t\tif ( t == NULL )', '\t\t\t*root = p;', '\t\telse if ( s == t->avl_right )', '\t\t\tt->avl_right = p;', '\t\telse', '\t\t\tt->avl_left = p;', '    }', '', '  return 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int avl_prefixapply(Avlnode *, void *, AVL_CMP, void *, AVL_CMP, void *, int);
# func_name: avl_prefixapply
# file_name: avl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c
# func_name:avl_prefixapply
# base_source_path:int avl_prefixapply(Avlnode *, void *, AVL_CMP, void *, AVL_CMP, void *, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/avl.c func-name: avl_prefixapply start:449   end:491
# src-code:['avl_prefixapply(', '    Avlnode\t*root,', '    void*\tdata,', '    AVL_CMP\t\tfmatch,', '    void*\tmarg,', '    AVL_CMP\t\tfcmp,', '    void*\tcarg,', '    int\t\tstopflag', ')', '{', '\tint\tcmp;', '', '\tif ( root == 0 )', '\t\treturn( AVL_NOMORE );', '', '\tcmp = (*fcmp)( data, root->avl_data /* , carg */);', '\tif ( cmp == 0 ) {', '\t\tif ( (*fmatch)( root->avl_data, marg ) == stopflag )', '\t\t\treturn( stopflag );', '', '\t\tif ( root->avl_left != 0 )', '\t\t\tif ( avl_prefixapply( root->avl_left, data, fmatch,', '\t\t\t    marg, fcmp, carg, stopflag ) == stopflag )', '\t\t\t\treturn( stopflag );', '', '\t\tif ( root->avl_right != 0 )', '\t\t\treturn( avl_prefixapply( root->avl_right, data, fmatch,', '\t\t\t    marg, fcmp, carg, stopflag ) );', '\t\telse', '\t\t\treturn( AVL_NOMORE );', '', '\t} else if ( cmp < 0 ) {', '\t\tif ( root->avl_left != 0 )', '\t\t\treturn( avl_prefixapply( root->avl_left, data, fmatch,', '\t\t\t    marg, fcmp, carg, stopflag ) );', '\t} else {', '\t\tif ( root->avl_right != 0 )', '\t\t\treturn( avl_prefixapply( root->avl_right, data, fmatch,', '\t\t\t    marg, fcmp, carg, stopflag ) );', '\t}', '', '\treturn( AVL_NOMORE );', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_b64_ntop(const u_char *, size_t, char *, size_t);
# func_name: lutil_b64_ntop
# file_name: base64.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/base64.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/base64.c
# func_name:lutil_b64_ntop
# base_source_path:int lutil_b64_ntop(const u_char *, size_t, char *, size_t);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/base64.c func-name: lutil_b64_ntop start:118   end:180
# src-code:['lutil_b64_ntop(', '\tu_char const *src,', '\tsize_t srclength,', '\tchar *target,', '\tsize_t targsize)', '{', '\tsize_t datalength = 0;', '\tu_char input[3];', '\tu_char output[4];', '\tsize_t i;', '', '\twhile (2 < srclength) {', '\t\tinput[0] = *src++;', '\t\tinput[1] = *src++;', '\t\tinput[2] = *src++;', '\t\tsrclength -= 3;', '', '\t\toutput[0] = input[0] >> 2;', '\t\toutput[1] = ((input[0] & 0x03) << 4) + (input[1] >> 4);', '\t\toutput[2] = ((input[1] & 0x0f) << 2) + (input[2] >> 6);', '\t\toutput[3] = input[2] & 0x3f;', '\t\tassert(output[0] < 64);', '\t\tassert(output[1] < 64);', '\t\tassert(output[2] < 64);', '\t\tassert(output[3] < 64);', '', '\t\tif (datalength + 4 > targsize)', '\t\t\treturn (-1);', '\t\ttarget[datalength++] = Base64[output[0]];', '\t\ttarget[datalength++] = Base64[output[1]];', '\t\ttarget[datalength++] = Base64[output[2]];', '\t\ttarget[datalength++] = Base64[output[3]];', '\t}', '', '\t/* Now we worry about padding. */', '\tif (0 != srclength) {', "\t\t/* Get what's left. */", "\t\tinput[0] = input[1] = input[2] = '\\0';", '\t\tfor (i = 0; i < srclength; i++)', '\t\t\tinput[i] = *src++;', '', '\t\toutput[0] = input[0] >> 2;', '\t\toutput[1] = ((input[0] & 0x03) << 4) + (input[1] >> 4);', '\t\toutput[2] = ((input[1] & 0x0f) << 2) + (input[2] >> 6);', '\t\tassert(output[0] < 64);', '\t\tassert(output[1] < 64);', '\t\tassert(output[2] < 64);', '', '\t\tif (datalength + 4 > targsize)', '\t\t\treturn (-1);', '\t\ttarget[datalength++] = Base64[output[0]];', '\t\ttarget[datalength++] = Base64[output[1]];', '\t\tif (srclength == 1)', '\t\t\ttarget[datalength++] = Pad64;', '\t\telse', '\t\t\ttarget[datalength++] = Base64[output[2]];', '\t\ttarget[datalength++] = Pad64;', '\t}', '\tif (datalength >= targsize)', '\t\treturn (-1);', "\ttarget[datalength] = '\\0';\t/* Returned value doesn't count \\0. */", '\treturn (datalength);', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_b64_pton(const char *, u_char *, size_t);
# func_name: lutil_b64_pton
# file_name: base64.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/base64.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/base64.c
# func_name:lutil_b64_pton
# base_source_path:int lutil_b64_pton(const char *, u_char *, size_t);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/base64.c func-name: lutil_b64_pton start:189   end:308
# src-code:['lutil_b64_pton(', '\tchar const *src,', '\tu_char *target,', '\tsize_t targsize)', '{', '\tint tarindex, state, ch;', '\tchar *pos;', '', '\tstate = 0;', '\ttarindex = 0;', '', "\twhile ((ch = *src++) != '\\0') {", '\t\tif (isascii(ch) && isspace(ch))\t/* Skip whitespace anywhere. */', '\t\t\tcontinue;', '', '\t\tif (ch == Pad64)', '\t\t\tbreak;', '', '\t\tpos = strchr(Base64, ch);', '\t\tif (pos == 0) \t\t/* A non-base64 character. */', '\t\t\treturn (-1);', '', '\t\tswitch (state) {', '\t\tcase 0:', '\t\t\tif (target) {', '\t\t\t\tif ((size_t)tarindex >= targsize)', '\t\t\t\t\treturn (-1);', '\t\t\t\ttarget[tarindex] = (pos - Base64) << 2;', '\t\t\t}', '\t\t\tstate = 1;', '\t\t\tbreak;', '\t\tcase 1:', '\t\t\tif (target) {', '\t\t\t\tif ((size_t)tarindex + 1 >= targsize)', '\t\t\t\t\treturn (-1);', '\t\t\t\ttarget[tarindex]   |=  (pos - Base64) >> 4;', '\t\t\t\ttarget[tarindex+1]  = ((pos - Base64) & 0x0f)', '\t\t\t\t\t\t\t<< 4 ;', '\t\t\t}', '\t\t\ttarindex++;', '\t\t\tstate = 2;', '\t\t\tbreak;', '\t\tcase 2:', '\t\t\tif (target) {', '\t\t\t\tif ((size_t)tarindex + 1 >= targsize)', '\t\t\t\t\treturn (-1);', '\t\t\t\ttarget[tarindex]   |=  (pos - Base64) >> 2;', '\t\t\t\ttarget[tarindex+1]  = ((pos - Base64) & 0x03)', '\t\t\t\t\t\t\t<< 6;', '\t\t\t}', '\t\t\ttarindex++;', '\t\t\tstate = 3;', '\t\t\tbreak;', '\t\tcase 3:', '\t\t\tif (target) {', '\t\t\t\tif ((size_t)tarindex >= targsize)', '\t\t\t\t\treturn (-1);', '\t\t\t\ttarget[tarindex] |= (pos - Base64);', '\t\t\t}', '\t\t\ttarindex++;', '\t\t\tstate = 0;', '\t\t\tbreak;', '\t\tdefault:', '\t\t\tabort();', '\t\t}', '\t}', '', '\t/*', "\t * We are done decoding Base-64 chars.  Let's see if we ended", '\t * on a byte boundary, and/or with erroneous trailing characters.', '\t */', '', '\tif (ch == Pad64) {\t\t/* We got a pad char. */', '\t\tch = *src++;\t\t/* Skip it, get next. */', '\t\tswitch (state) {', '\t\tcase 0:\t\t/* Invalid = in first position */', '\t\tcase 1:\t\t/* Invalid = in second position */', '\t\t\treturn (-1);', '', '\t\tcase 2:\t\t/* Valid, means one byte of info */', '\t\t\t/* Skip any number of spaces. */', "\t\t\tfor ((void)NULL; ch != '\\0'; ch = *src++)", '\t\t\t\tif (! (isascii(ch) && isspace(ch)))', '\t\t\t\t\tbreak;', '\t\t\t/* Make sure there is another trailing = sign. */', '\t\t\tif (ch != Pad64)', '\t\t\t\treturn (-1);', '\t\t\tch = *src++;\t\t/* Skip the = */', '\t\t\t/* Fall through to "single trailing =" case. */', '\t\t\t/* FALLTHROUGH */', '', '\t\tcase 3:\t\t/* Valid, means two bytes of info */', '\t\t\t/*', '\t\t\t * We know this char is an =.  Is there anything but', '\t\t\t * whitespace after it?', '\t\t\t */', "\t\t\tfor ((void)NULL; ch != '\\0'; ch = *src++)", '\t\t\t\tif (! (isascii(ch) && isspace(ch)))', '\t\t\t\t\treturn (-1);', '', '\t\t\t/*', '\t\t\t * Now make sure for cases 2 and 3 that the "extra"', '\t\t\t * bits that slopped past the last full byte were', "\t\t\t * zeros.  If we don't check them, they become a", '\t\t\t * subliminal channel.', '\t\t\t */', '\t\t\tif (target && target[tarindex] != 0)', '\t\t\t\treturn (-1);', '\t\t}', '\t} else {', '\t\t/*', '\t\t * We ended by seeing the end of the string.  Make sure we', '\t\t * have no partial bytes lying around.', '\t\t */', '\t\tif (state != 0)', '\t\t\treturn (-1);', '\t}', '', '\treturn (tarindex);', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_detach(int, int);
# func_name: lutil_detach
# file_name: detach.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/detach.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/detach.c
# func_name:lutil_detach
# base_source_path:int lutil_detach(int, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/detach.c func-name: lutil_detach start:53   end:144
# src-code:['lutil_detach( int debug, int do_close )', '{', '\tint\t\ti, sd, nbits, pid;', '', '#ifdef HAVE_SYSCONF', '\tnbits = sysconf( _SC_OPEN_MAX );', '#elif defined(HAVE_GETDTABLESIZE)', '\tnbits = getdtablesize();', '#else', '\tnbits = FD_SETSIZE;', '#endif', '', '#ifdef FD_SETSIZE', '\tif ( nbits > FD_SETSIZE ) {', '\t\tnbits = FD_SETSIZE;', '\t}', '#endif /* FD_SETSIZE */', '', '\tif ( debug == 0 ) {', '\t\tfor ( i = 0; i < 5; i++ ) {', '#ifdef HAVE_THR', '\t\t\tpid = fork1();', '#else', '\t\t\tpid = fork();', '#endif', '\t\t\tswitch ( pid )', '\t\t\t{', '\t\t\tcase -1:', '\t\t\t\tsleep( 5 );', '\t\t\t\tcontinue;', '', '\t\t\tcase 0:', '\t\t\t\tbreak;', '', '\t\t\tdefault:', '\t\t\t\treturn pid;', '\t\t\t}', '\t\t\tbreak;', '\t\t}', '', '\t\tif ( (sd = open( "/dev/null", O_RDWR   )) == -1 &&', '\t\t\t (sd = open( "/dev/null", O_RDONLY )) == -1 &&', '\t\t\t /* Panic -- open *something* */', '\t\t\t (sd = open( "/",         O_RDONLY )) == -1    ) {', '\t\t\tperror("/dev/null");', '\t\t} else {', '\t\t\t/* redirect stdin, stdout, stderr to /dev/null */', '\t\t\tdup2( sd, STDIN_FILENO );', '\t\t\tdup2( sd, STDOUT_FILENO );', '\t\t\tdup2( sd, STDERR_FILENO );', '', '\t\t\tswitch( sd ) {', '\t\t\tdefault:', '\t\t\t\tclose( sd );', '\t\t\tcase STDIN_FILENO:', '\t\t\tcase STDOUT_FILENO:', '\t\t\tcase STDERR_FILENO:', '\t\t\t\tbreak;', '\t\t\t}', '\t\t}', '', '\t\tif ( do_close ) {', '\t\t\t/* close everything else */', '\t\t\tfor ( i = 0; i < nbits; i++ ) {', '\t\t\t\tif( i != STDIN_FILENO &&', '\t\t\t\t\ti != STDOUT_FILENO &&', '\t\t\t\t\ti != STDERR_FILENO )', '\t\t\t\t{', '\t\t\t\t\tclose( i );', '\t\t\t\t}', '\t\t\t}', '\t\t}', '', '#ifdef CHDIR_TO_ROOT', '\t\t(void) chdir( "/" );', '#endif', '', '#ifdef HAVE_SETSID', '\t\t(void) setsid();', '#elif defined(TIOCNOTTY)', '\t\tif ( (sd = open( "/dev/tty", O_RDWR )) != -1 ) {', '\t\t\t(void) ioctl( sd, TIOCNOTTY, NULL );', '\t\t\t(void) close( sd );', '\t\t}', '#endif', '\t}', '', '#ifdef SIGPIPE', '\t(void) SIGNAL( SIGPIPE, SIG_IGN );', '#endif', '\treturn 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_entropy(unsigned char *, ber_len_t);
# func_name: lutil_entropy
# file_name: entropy.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/entropy.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/entropy.c
# func_name:lutil_entropy
# base_source_path:int lutil_entropy(unsigned char *, ber_len_t);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/entropy.c func-name: lutil_entropy start:49   end:170
# ...
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/tavl.c func-name: tavl_free start:427   end:443
# src-code:['tavl_free( Avlnode *root, AVL_FREE dfree )', '{', '\tint\tnleft, nright;', '', '\tif ( root == 0 )', '\t\treturn( 0 );', '', '\tnleft = tavl_free( avl_lchild( root ), dfree );', '', '\tnright = tavl_free( avl_rchild( root ), dfree );', '', '\tif ( dfree )', '\t\t(*dfree)( root->avl_data );', '\tber_memfree( root );', '', '\treturn( nleft + nright + 1 );', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int tavl_insert(Avlnode **, void *, AVL_CMP, AVL_DUP);
# func_name: tavl_insert
# file_name: tavl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/tavl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/tavl.c
# func_name:tavl_insert
# base_source_path:int tavl_insert(Avlnode **, void *, AVL_CMP, AVL_DUP);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/tavl.c func-name: tavl_insert start:63   end:187
# src-code:['tavl_insert( Avlnode ** root, void *data, AVL_CMP fcmp, AVL_DUP fdup )', '{', '    Avlnode *t, *p, *s, *q, *r;', '    int a, cmp, ncmp;', '', '\tif ( *root == NULL ) {', '\t\tif (( r = (Avlnode *) ber_memalloc( sizeof( Avlnode ))) == NULL ) {', '\t\t\treturn( -1 );', '\t\t}', '\t\tr->avl_link[0] = r->avl_link[1] = NULL;', '\t\tr->avl_data = data;', '\t\tr->avl_bf = EH;', '\t\tr->avl_bits[0] = r->avl_bits[1] = AVL_THREAD;', '\t\t*root = r;', '', '\t\treturn( 0 );', '\t}', '', '    t = NULL;', '    s = p = *root;', '', '\t/* find insertion point */', '    while (1) {', '\t\tcmp = fcmp( data, p->avl_data );', '\t\tif ( cmp == 0 )', '\t\t\treturn (*fdup)( p->avl_data, data );', '', '\t\tcmp = (cmp > 0);', '\t\tq = avl_child( p, cmp );', '\t\tif (q == NULL) {', '\t\t\t/* insert */', '\t\t\tif (( q = (Avlnode *) ber_memalloc( sizeof( Avlnode ))) == NULL ) {', '\t\t\t\treturn( -1 );', '\t\t\t}', '\t\t\tq->avl_link[cmp] = p->avl_link[cmp];', '\t\t\tq->avl_link[!cmp] = p;', '\t\t\tq->avl_data = data;', '\t\t\tq->avl_bf = EH;', '\t\t\tq->avl_bits[0] = q->avl_bits[1] = AVL_THREAD;', '', '\t\t\tp->avl_link[cmp] = q;', '\t\t\tp->avl_bits[cmp] = AVL_CHILD;', '\t\t\tbreak;', '\t\t} else if ( q->avl_bf ) {', '\t\t\tt = p;', '\t\t\ts = q;', '\t\t}', '\t\tp = q;', '    }', '', '    /* adjust balance factors */', '    cmp = fcmp( data, s->avl_data ) > 0;', '\tr = p = s->avl_link[cmp];', '\ta = avl_bfs[cmp];', '', '\twhile ( p != q ) {', '\t\tcmp = fcmp( data, p->avl_data ) > 0;', '\t\tp->avl_bf = avl_bfs[cmp];', '\t\tp = p->avl_link[cmp];', '\t}', '', '\t/* checks and balances */', '', '\tif ( s->avl_bf == EH ) {', '\t\ts->avl_bf = a;', '\t\treturn 0;', '\t} else if ( s->avl_bf == -a ) {', '\t\ts->avl_bf = EH;', '\t\treturn 0;', '    } else if ( s->avl_bf == a ) {', '\t\tcmp = (a > 0);', '\t\tncmp = !cmp;', '\t\tif ( r->avl_bf == a ) {', '\t\t\t/* single rotation */', '\t\t\tp = r;', '\t\t\tif ( r->avl_bits[ncmp] == AVL_THREAD ) {', '\t\t\t\tr->avl_bits[ncmp] = AVL_CHILD;', '\t\t\t\ts->avl_bits[cmp] = AVL_THREAD;', '\t\t\t} else {', '\t\t\t\ts->avl_link[cmp] = r->avl_link[ncmp];', '\t\t\t\tr->avl_link[ncmp] = s;', '\t\t\t}', '\t\t\ts->avl_bf = 0;', '\t\t\tr->avl_bf = 0;', '\t\t} else if ( r->avl_bf == -a ) {', '\t\t\t/* double rotation */', '\t\t\tp = r->avl_link[ncmp];', '\t\t\tif ( p->avl_bits[cmp] == AVL_THREAD ) {', '\t\t\t\tp->avl_bits[cmp] = AVL_CHILD;', '\t\t\t\tr->avl_bits[ncmp] = AVL_THREAD;', '\t\t\t} else {', '\t\t\t\tr->avl_link[ncmp] = p->avl_link[cmp];', '\t\t\t\tp->avl_link[cmp] = r;', '\t\t\t}', '\t\t\tif ( p->avl_bits[ncmp] == AVL_THREAD ) {', '\t\t\t\tp->avl_bits[ncmp] = AVL_CHILD;', '\t\t\t\ts->avl_link[cmp] = p;', '\t\t\t\ts->avl_bits[cmp] = AVL_THREAD;', '\t\t\t} else {', '\t\t\t\ts->avl_link[cmp] = p->avl_link[ncmp];', '\t\t\t\tp->avl_link[ncmp] = s;', '\t\t\t}', '\t\t\tif ( p->avl_bf == a ) {', '\t\t\t\ts->avl_bf = -a;', '\t\t\t\tr->avl_bf = 0;', '\t\t\t} else if ( p->avl_bf == -a ) {', '\t\t\t\ts->avl_bf = 0;', '\t\t\t\tr->avl_bf = a;', '\t\t\t} else {', '\t\t\t\ts->avl_bf = 0;', '\t\t\t\tr->avl_bf = 0;', '\t\t\t}', '\t\t\tp->avl_bf = 0;', '\t\t}', '\t\t/* Update parent */', '\t\tif ( t == NULL )', '\t\t\t*root = p;', '\t\telse if ( s == t->avl_right )', '\t\t\tt->avl_right = p;', '\t\telse', '\t\t\tt->avl_left = p;', '    }', '', '  return 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: Avlnode *tavl_next(Avlnode *, int);
# func_name: tavl_next
# file_name: tavl.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/tavl.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/tavl.c
# func_name:tavl_next
# base_source_path:Avlnode *tavl_next(Avlnode *, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/tavl.c func-name: tavl_next start:510   end:523
# src-code:['tavl_next( Avlnode *root, int dir )', '{', '\tif ( root ) {', '\t\tint c = root->avl_bits[dir];', '', '\t\troot = root->avl_link[dir];', '\t\tif ( c == AVL_CHILD ) {', '\t\t\tdir ^= 1;', '\t\t\twhile ( root->avl_bits[dir] == AVL_CHILD )', '\t\t\t\troot = root->avl_link[dir];', '\t\t}', '\t}', '\treturn root;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_atoix(int *, const char *, int);
# func_name: lutil_atoix
# file_name: utils.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c
# func_name:lutil_atoix
# base_source_path:int lutil_atoix(int *, const char *, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c func-name: lutil_atoix start:466   end:486
# src-code:['lutil_atoix( int *v, const char *s, int x )', '{', '\tchar\t\t*next;', '\tlong\t\ti;', '', '\tassert( s != NULL );', '\tassert( v != NULL );', '', '\ti = strtol( s, &next, x );', "\tif ( next == s || next[ 0 ] != '\\0' ) {", '\t\treturn -1;', '\t}', '', '\tif ( (long)(int)i != i ) {', '\t\treturn 1;', '\t}', '', '\t*v = (int)i;', '', '\treturn 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_atollx(long long *, const char *, int);
# func_name: lutil_atollx
# file_name: utils.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c
# func_name:lutil_atollx
# base_source_path:int lutil_atollx(long long *, const char *, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c func-name: lutil_atollx start:580   end:614
# src-code:['lutil_atollx( long long *v, const char *s, int x )', '{', '\tchar *next;', '\tlong long ll;', '\tint save_errno;', '', '\tassert( s != NULL );', '\tassert( v != NULL );', '', '\tif ( isspace( s[ 0 ] ) ) {', '\t\treturn -1;', '\t}', '', '\terrno = 0;', '#ifdef HAVE_STRTOLL', '\tll = strtoll( s, &next, x );', '#else /* HAVE_STRTOQ */', '\tll = (unsigned long long)strtoq( s, &next, x );', '#endif /* HAVE_STRTOQ */', '\tsave_errno = errno;', "\tif ( next == s || next[ 0 ] != '\\0' ) {", '\t\treturn -1;', '\t}', '', '\t/* LLONG_MIN, LLONG_MAX are C99 only */', '#if defined (LLONG_MIN) && defined(LLONG_MAX)', '\tif ( ( ll == LLONG_MIN || ll == LLONG_MAX ) && save_errno != 0 ) {', '\t\treturn -1;', '\t}', '#endif /* LLONG_MIN && LLONG_MAX */', '', '\t*v = ll;', '', '\treturn 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_atolx(long *, const char *, int);
# func_name: lutil_atolx
# file_name: utils.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c
# func_name:lutil_atolx
# base_source_path:int lutil_atolx(long *, const char *, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c func-name: lutil_atolx start:517   end:544
# src-code:['lutil_atolx( long *v, const char *s, int x )', '{', '\tchar *next;', '\tlong l;', '\tint save_errno;', '', '\tassert( s != NULL );', '\tassert( v != NULL );', '', '\tif ( isspace( s[ 0 ] ) ) {', '\t\treturn -1;', '\t}', '', '\terrno = 0;', '\tl = strtol( s, &next, x );', '\tsave_errno = errno;', "\tif ( next == s || next[ 0 ] != '\\0' ) {", '\t\treturn -1;', '\t}', '', '\tif ( ( l == LONG_MIN || l == LONG_MAX ) && save_errno != 0 ) {', '\t\treturn -1;', '\t}', '', '\t*v = l;', '', '\treturn 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_atoullx(unsigned long long *, const char *, int);
# func_name: lutil_atoullx
# file_name: utils.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c
# func_name:lutil_atoullx
# base_source_path:int lutil_atoullx(unsigned long long *, const char *, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c func-name: lutil_atoullx start:619   end:654
# src-code:['lutil_atoullx( unsigned long long *v, const char *s, int x )', '{', '\tchar *next;', '\tunsigned long long ull;', '\tint save_errno;', '', '\tassert( s != NULL );', '\tassert( v != NULL );', '', '\t/* strtoull() has an odd interface */', "\tif ( s[ 0 ] == '-' || isspace( s[ 0 ] ) ) {", '\t\treturn -1;', '\t}', '', '\terrno = 0;', '#ifdef HAVE_STRTOULL', '\tull = strtoull( s, &next, x );', '#else /* HAVE_STRTOUQ */', '\tull = (unsigned long long)strtouq( s, &next, x );', '#endif /* HAVE_STRTOUQ */', '\tsave_errno = errno;', "\tif ( next == s || next[ 0 ] != '\\0' ) {", '\t\treturn -1;', '\t}', '', '\t/* ULLONG_MAX is C99 only */', '#if defined(ULLONG_MAX)', '\tif ( ( ull == 0 || ull == ULLONG_MAX ) && save_errno != 0 ) {', '\t\treturn -1;', '\t}', '#endif /* ULLONG_MAX */', '', '\t*v = ull;', '', '\treturn 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_atoulx(unsigned long *, const char *, int);
# func_name: lutil_atoulx
# file_name: utils.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c
# func_name:lutil_atoulx
# base_source_path:int lutil_atoulx(unsigned long *, const char *, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c func-name: lutil_atoulx start:547   end:575
# src-code:['lutil_atoulx( unsigned long *v, const char *s, int x )', '{', '\tchar *next;', '\tunsigned long ul;', '\tint save_errno;', '', '\tassert( s != NULL );', '\tassert( v != NULL );', '', '\t/* strtoul() has an odd interface */', "\tif ( s[ 0 ] == '-' || isspace( s[ 0 ] ) ) {", '\t\treturn -1;', '\t}', '', '\terrno = 0;', '\tul = strtoul( s, &next, x );', '\tsave_errno = errno;', "\tif ( next == s || next[ 0 ] != '\\0' ) {", '\t\treturn -1;', '\t}', '', '\tif ( ( ul == 0 || ul == ULONG_MAX ) && save_errno != 0 ) {', '\t\treturn -1;', '\t}', '', '\t*v = ul;', '', '\treturn 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: int lutil_atoux(unsigned int *, const char *, int);
# func_name: lutil_atoux
# file_name: utils.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c
# func_name:lutil_atoux
# base_source_path:int lutil_atoux(unsigned int *, const char *, int);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c func-name: lutil_atoux start:489   end:514
# src-code:['lutil_atoux( unsigned *v, const char *s, int x )', '{', '\tchar\t\t*next;', '\tunsigned long\tu;', '', '\tassert( s != NULL );', '\tassert( v != NULL );', '', '\t/* strtoul() has an odd interface */', "\tif ( s[ 0 ] == '-' ) {", '\t\treturn -1;', '\t}', '', '\tu = strtoul( s, &next, x );', "\tif ( next == s || next[ 0 ] != '\\0' ) {", '\t\treturn -1;', '\t}', '', '\tif ( (unsigned long)(unsigned)u != u ) {', '\t\treturn 1;', '\t}', '', '\t*v = u;', '', '\treturn 0;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: size_t lutil_localtime(char *, size_t, const struct tm *, long);
# func_name: lutil_localtime
# file_name: utils.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c
# func_name:lutil_localtime
# base_source_path:size_t lutil_localtime(char *, size_t, const struct tm *, long);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c func-name: lutil_localtime start:110   end:152
# src-code:['size_t lutil_localtime( char *s, size_t smax, const struct tm *tm, long delta )', '{', '\tsize_t\tret;', '\tchar\t*p;', '', '\tif ( smax < 16 ) {\t/* YYYYmmddHHMMSSZ */', '\t\treturn 0;', '\t}', '', '#ifdef HAVE_EBCDIC', "/* We've been compiling in ASCII so far, but we want EBCDIC now since", ' * strftime only understands EBCDIC input.', ' */', '#pragma convlit(suspend)', '#endif', '\tret = strftime( s, smax, "%Y%m%d%H%M%SZ", tm );', '#ifdef HAVE_EBCDIC', '#pragma convlit(resume)', '\t__etoa( s );', '#endif', '\tif ( delta == 0 || ret == 0 ) {', '\t\treturn ret;', '\t}', '', '\tif ( smax < 20 ) {\t/* YYYYmmddHHMMSS+HHMM */', '\t\treturn 0;', '\t}', '', '\tp = s + 14;', '', '\tif ( delta < 0 ) {', "\t\tp[ 0 ] = '-';", '\t\tdelta = -delta;', '\t} else {', "\t\tp[ 0 ] = '+';", '\t}', '\tp++;', '', '\tsnprintf( p, smax - 15, "%02ld%02ld", delta / 3600,', '\t\t\t( delta % 3600 ) / 60 );', '', '\treturn ret + 4;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: char *lutil_memcopy(char *, const char *, size_t);
# func_name: lutil_memcopy
# file_name: utils.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c
# func_name:lutil_memcopy
# base_source_path:char *lutil_memcopy(char *, const char *, size_t);
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c func-name: lutil_memcopy start:326   end:334
# src-code:['lutil_memcopy(', '\tchar *a,', '\tconst char *b,', '\tsize_t n', ')', '{', '\tAC_MEMCPY(a, b, n);', '\treturn a + n;', '}']
# nr_of_empty_src_code:0   len_full_path:1
# only found one source code, thats good
# funcSign: void *lutil_memrchr(const void *, int, size_t);
# func_name: lutil_memrchr
# file_name: utils.c
# package_name: slapd
# binary: /usr/sbin/slapacl
# pkg_name:slapd
# pkg_src_name:/tmp/slapd/openldap-2.4.49+dfsg
# full-path:['/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c']
# src_file:/tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c
# func_name:lutil_memrchr
# base_source_path:void *lutil_memrchr(const void *, int, size_t);
# func start-line not found-------------
# source-file: /tmp/slapd/openldap-2.4.49+dfsg/libraries/liblutil/utils.c func-name: lutil_memrchr start:   end:
# no src-code found
# nr_of_empty_src_code:1   len_full_path:1
# ERROR found more than one source code for a function
